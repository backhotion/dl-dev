# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client

# %%
class CpEvent:
    instance = None
 
    def OnReceived(self):
        # time = CpEvent.instance.GetHeaderValue(3)  # 시간
        timess = CpEvent.instance.GetHeaderValue(18)  # 초
        exFlag = CpEvent.instance.GetHeaderValue(19)  # 예상체결 플래그
        cprice = CpEvent.instance.GetHeaderValue(13)  # 현재가
        diff = CpEvent.instance.GetHeaderValue(2)  # 대비
        cVol = CpEvent.instance.GetHeaderValue(17)  # 순간체결수량
        vol = CpEvent.instance.GetHeaderValue(9)  # 거래량
 
        if (exFlag == ord('1')):  # 동시호가 시간 (예상체결)
            print("실시간(예상체결)", timess, "*", cprice, "대비", diff, "체결량", cVol, "거래량", vol)
        elif (exFlag == ord('2')):  # 장중(체결)
            print("실시간(장중 체결)", timess, cprice, "대비", diff, "체결량", cVol, "거래량", vol)
 
 
class CpStockCur:
    def Subscribe(self, code):
        self.objStockCur = win32com.client.Dispatch("DsCbo1.StockCur")
        win32com.client.WithEvents(self.objStockCur, CpEvent)
        self.objStockCur.SetInputValue(0, code)
        CpEvent.instance = self.objStockCur
        self.objStockCur.Subscribe()
 
    def Unsubscribe(self):
        self.objStockCur.Unsubscribe()
 
 
 
class CpStockMst:
    def Request(self, code):
        # 연결 여부 체크
        objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
        bConnect = objCpCybos.IsConnect
        if (bConnect == 0):
            print("PLUS가 정상적으로 연결되지 않음. ")
            return False
 
        # 현재가 객체 구하기
        objStockMst = win32com.client.Dispatch("DsCbo1.StockMst")
        objStockMst.SetInputValue(0, code)  # 종목 코드 - 삼성전자
        objStockMst.BlockRequest()
 
        # 현재가 통신 및 통신 에러 처리
        rqStatus = objStockMst.GetDibStatus()
        rqRet = objStockMst.GetDibMsg1()
        print("통신상태", rqStatus, rqRet)
        if rqStatus != 0:
            return False
 
        # 현재가 정보 조회
        code = objStockMst.GetHeaderValue(0)  # 종목코드
        name = objStockMst.GetHeaderValue(1)  # 종목명
        time = objStockMst.GetHeaderValue(4)  # 시간
        cprice = objStockMst.GetHeaderValue(11)  # 종가
        diff = objStockMst.GetHeaderValue(12)  # 대비
        open = objStockMst.GetHeaderValue(13)  # 시가
        high = objStockMst.GetHeaderValue(14)  # 고가
        low = objStockMst.GetHeaderValue(15)  # 저가
        offer = objStockMst.GetHeaderValue(16)  # 매도호가
        bid = objStockMst.GetHeaderValue(17)  # 매수호가
        vol = objStockMst.GetHeaderValue(18)  # 거래량
        vol_value = objStockMst.GetHeaderValue(19)  # 거래대금
 
        print("코드 이름 시간 현재가 대비 시가 고가 저가 매도호가 매수호가 거래량 거래대금")
        print(code, name, time, cprice, diff, open, high, low, offer, bid, vol, vol_value)
        return True
 
 
class MyWindow(QMainWindow):
 
    def __init__(self):
        super().__init__()
        self.setWindowTitle("PLUS API TEST")
        self.setGeometry(300, 300, 300, 150)
        self.isRq = False
        self.objStockMst = CpStockMst()
        self.objStockCur = CpStockCur()
 
        btn1 = QPushButton("요청 시작", self)
        btn1.move(20, 20)
        btn1.clicked.connect(self.btn1_clicked)
 
        btn2 = QPushButton("요청 종료", self)
        btn2.move(20, 70)
        btn2.clicked.connect(self.btn2_clicked)
 
        btn3 = QPushButton("종료", self)
        btn3.move(20, 120)
        btn3.clicked.connect(self.btn3_clicked)
 
    def StopSubscribe(self):
        if self.isRq:
            self.objStockCur.Unsubscribe()
        self.isRq = False
 
    def btn1_clicked(self):
        testCode = "A000660"
        if (self.objStockMst.Request(testCode) == False):
            exit()
 
        # 하이닉스 실시간 현재가 요청
        self.objStockCur.Subscribe(testCode)
 
        print("빼기빼기================-")
        print("실시간 현재가 요청 시작")
        self.isRq = True
 
    def btn2_clicked(self):
        self.StopSubscribe()
 
 
    def btn3_clicked(self):
        self.StopSubscribe()
        exit()
 
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()
# Out:
# 통신상태 0 0027 조회가 완료되었습니다.(stock.new.mst)
# 코드 이름 시간 현재가 대비 시가 고가 저가 매도호가 매수호가 거래량 거래대금
# A000660 SK하이닉스 1151 115200 400 114000 115900 113200 115200 115100 1596339 18303076
# 빼기빼기================-
# 실시간 현재가 요청 시작
# 실시간(장중 체결) 115132 115100 대비 300 체결량 1 거래량 1596340
# 실시간(장중 체결) 115134 115200 대비 400 체결량 8 거래량 1596348
# 실시간(장중 체결) 115134 115200 대비 400 체결량 2 거래량 1596350
# 실시간(장중 체결) 115135 115200 대비 400 체결량 14 거래량 1596364
# 실시간(장중 체결) 115135 115100 대비 300 체결량 1 거래량 1596365
# 실시간(장중 체결) 115135 115100 대비 300 체결량 1 거래량 1596366
# 실시간(장중 체결) 115135 115200 대비 400 체결량 10 거래량 1596376
# 실시간(장중 체결) 115136 115100 대비 300 체결량 1 거래량 1596377
# 실시간(장중 체결) 115138 115200 대비 400 체결량 1 거래량 1596378
# 실시간(장중 체결) 115139 115200 대비 400 체결량 3 거래량 1596381
# 실시간(장중 체결) 115140 115200 대비 400 체결량 1 거래량 1596382
# 실시간(장중 체결) 115141 115200 대비 400 체결량 4 거래량 1596386
# 실시간(장중 체결) 115141 115200 대비 400 체결량 2 거래량 1596388
# 실시간(장중 체결) 115141 115200 대비 400 체결량 3 거래량 1596394
# 실시간(장중 체결) 115141 115200 대비 400 체결량 4 거래량 1596398
# 실시간(장중 체결) 115141 115100 대비 300 체결량 10 거래량 1596408
# 실시간(장중 체결) 115144 115100 대비 300 체결량 1 거래량 1596409
# 실시간(장중 체결) 115146 115200 대비 400 체결량 1 거래량 1596410
# 실시간(장중 체결) 115146 115100 대비 300 체결량 4 거래량 1596414
# 실시간(장중 체결) 115148 115200 대비 400 체결량 2 거래량 1596416
# 실시간(장중 체결) 115148 115200 대비 400 체결량 4 거래량 1596420
# 실시간(장중 체결) 115153 115200 대비 400 체결량 1 거래량 1596421
# 실시간(장중 체결) 115153 115200 대비 400 체결량 1 거래량 1596422
# 실시간(장중 체결) 115155 115200 대비 400 체결량 1 거래량 1596423
# 실시간(장중 체결) 115155 115100 대비 300 체결량 4 거래량 1596427
# 실시간(장중 체결) 115155 115200 대비 400 체결량 1 거래량 1596428
# 실시간(장중 체결) 115155 115100 대비 300 체결량 51 거래량 1596479
# 실시간(장중 체결) 115156 115100 대비 300 체결량 8 거래량 1596487
# 실시간(장중 체결) 115156 115200 대비 400 체결량 1 거래량 1596488
# 실시간(장중 체결) 115156 115200 대비 400 체결량 3 거래량 1596491
# 실시간(장중 체결) 115158 115200 대비 400 체결량 1 거래량 1596492
# 실시간(장중 체결) 115159 115200 대비 400 체결량 1 거래량 1596493
# 실시간(장중 체결) 115200 115200 대비 400 체결량 1 거래량 1596494
# 실시간(장중 체결) 115200 115100 대비 300 체결량 10 거래량 1596504
# 실시간(장중 체결) 115205 115200 대비 400 체결량 2 거래량 1596506
# 실시간(장중 체결) 115205 115200 대비 400 체결량 6 거래량 1596512
# 실시간(장중 체결) 115206 115200 대비 400 체결량 1 거래량 1596513
# 실시간(장중 체결) 115206 115200 대비 400 체결량 4 거래량 1596517
# 실시간(장중 체결) 115207 115100 대비 300 체결량 8 거래량 1596525
# 실시간(장중 체결) 115207 115100 대비 300 체결량 15 거래량 1596543
# 실시간(장중 체결) 115208 115100 대비 300 체결량 10 거래량 1596553
# 실시간(장중 체결) 115209 115200 대비 400 체결량 1 거래량 1596554
# 실시간(장중 체결) 115209 115200 대비 400 체결량 1 거래량 1596555
# 실시간(장중 체결) 115210 115200 대비 400 체결량 1 거래량 1596556
# 실시간(장중 체결) 115212 115200 대비 400 체결량 10 거래량 1596566
# 실시간(장중 체결) 115212 115200 대비 400 체결량 1 거래량 1596567
# 실시간(장중 체결) 115213 115100 대비 300 체결량 1 거래량 1596568
# 실시간(장중 체결) 115214 115100 대비 300 체결량 1 거래량 1596569
# 실시간(장중 체결) 115215 115200 대비 400 체결량 145 거래량 1596714
# 실시간(장중 체결) 115219 115200 대비 400 체결량 7 거래량 1596721
# 실시간(장중 체결) 115219 115200 대비 400 체결량 5 거래량 1596726
# 실시간(장중 체결) 115220 115100 대비 300 체결량 30 거래량 1596756
# 실시간(장중 체결) 115221 115100 대비 300 체결량 1 거래량 1596757
# 실시간(장중 체결) 115221 115100 대비 300 체결량 1 거래량 1596758
# 실시간(장중 체결) 115225 115100 대비 300 체결량 2 거래량 1596760
# 실시간(장중 체결) 115225 115100 대비 300 체결량 40 거래량 1596800
# 실시간(장중 체결) 115227 115100 대비 300 체결량 12 거래량 1596812
# 실시간(장중 체결) 115229 115200 대비 400 체결량 1 거래량 1596813
# 실시간(장중 체결) 115230 115200 대비 400 체결량 50 거래량 1596863
# 실시간(장중 체결) 115232 115200 대비 400 체결량 5 거래량 1596868
# 실시간(장중 체결) 115232 115200 대비 400 체결량 2 거래량 1596872
# 실시간(장중 체결) 115234 115200 대비 400 체결량 5 거래량 1596877
# 실시간(장중 체결) 115236 115200 대비 400 체결량 8 거래량 1596885
# 실시간(장중 체결) 115239 115100 대비 300 체결량 53 거래량 1596938
# 실시간(장중 체결) 115240 115200 대비 400 체결량 1 거래량 1596939
# 실시간(장중 체결) 115240 115200 대비 400 체결량 15 거래량 1596954
# 실시간(장중 체결) 115242 115200 대비 400 체결량 73 거래량 1597027
# 실시간(장중 체결) 115247 115200 대비 400 체결량 1 거래량 1597028
# 실시간(장중 체결) 115249 115100 대비 300 체결량 10 거래량 1597038
# 실시간(장중 체결) 115251 115200 대비 400 체결량 255 거래량 1597293
# 실시간(장중 체결) 115253 115200 대비 400 체결량 3 거래량 1597296
# 실시간(장중 체결) 115256 115200 대비 400 체결량 100 거래량 1597396
# 실시간(장중 체결) 115300 115100 대비 300 체결량 1 거래량 1597397
# 실시간(장중 체결) 115302 115100 대비 300 체결량 10 거래량 1597407
# 실시간(장중 체결) 115302 115200 대비 400 체결량 3 거래량 1597410
# 실시간(장중 체결) 115302 115200 대비 400 체결량 8 거래량 1597418
# 실시간(장중 체결) 115306 115200 대비 400 체결량 9 거래량 1597427
# 실시간(장중 체결) 115306 115200 대비 400 체결량 22 거래량 1597451
# 실시간(장중 체결) 115307 115200 대비 400 체결량 8 거래량 1597459
# 실시간(장중 체결) 115307 115200 대비 400 체결량 3 거래량 1597462
# 실시간(장중 체결) 115307 115200 대비 400 체결량 3 거래량 1597465
# 실시간(장중 체결) 115307 115200 대비 400 체결량 1 거래량 1597466
# 실시간(장중 체결) 115308 115200 대비 400 체결량 1 거래량 1597467
# 실시간(장중 체결) 115308 115200 대비 400 체결량 1 거래량 1597468
# 실시간(장중 체결) 115309 115100 대비 300 체결량 1 거래량 1597469
# 실시간(장중 체결) 115310 115100 대비 300 체결량 6 거래량 1597475
# 실시간(장중 체결) 115310 115200 대비 400 체결량 2 거래량 1597477
# 실시간(장중 체결) 115313 115100 대비 300 체결량 16 거래량 1597493
# 실시간(장중 체결) 115313 115100 대비 300 체결량 47 거래량 1597540
# 실시간(장중 체결) 115315 115200 대비 400 체결량 518 거래량 1598058
# 실시간(장중 체결) 115318 115200 대비 400 체결량 5 거래량 1598063
# 실시간(장중 체결) 115319 115200 대비 400 체결량 7 거래량 1598070
# 실시간(장중 체결) 115319 115200 대비 400 체결량 14 거래량 1598084
# 실시간(장중 체결) 115319 115100 대비 300 체결량 1 거래량 1598085
# 실시간(장중 체결) 115320 115100 대비 300 체결량 31 거래량 1598116
# 실시간(장중 체결) 115321 115200 대비 400 체결량 1 거래량 1598117
# 실시간(장중 체결) 115321 115100 대비 300 체결량 1973 거래량 1600090
# 실시간(장중 체결) 115321 115200 대비 400 체결량 52 거래량 1600142
# 실시간(장중 체결) 115322 115200 대비 400 체결량 492 거래량 1600634
# 실시간(장중 체결) 115325 115200 대비 400 체결량 1 거래량 1600635
# 실시간(장중 체결) 115327 115200 대비 400 체결량 2 거래량 1600637
# 실시간(장중 체결) 115327 115200 대비 400 체결량 3 거래량 1600640
# 실시간(장중 체결) 115327 115200 대비 400 체결량 3 거래량 1600643
# 실시간(장중 체결) 115329 115200 대비 400 체결량 1 거래량 1600644
# 실시간(장중 체결) 115330 115100 대비 300 체결량 1 거래량 1600645
# 실시간(장중 체결) 115331 115200 대비 400 체결량 1 거래량 1600646
# 실시간(장중 체결) 115331 115200 대비 400 체결량 11 거래량 1600657
# 실시간(장중 체결) 115331 115200 대비 400 체결량 1 거래량 1600658
# 실시간(장중 체결) 115333 115100 대비 300 체결량 1 거래량 1600659
# 실시간(장중 체결) 115333 115100 대비 300 체결량 1 거래량 1600661
# 실시간(장중 체결) 115333 115100 대비 300 체결량 13 거래량 1600674
# 실시간(장중 체결) 115335 115100 대비 300 체결량 51 거래량 1600725
# 실시간(장중 체결) 115335 115200 대비 400 체결량 1 거래량 1600726
# 실시간(장중 체결) 115336 115200 대비 400 체결량 27 거래량 1600753
# 실시간(장중 체결) 115337 115100 대비 300 체결량 2 거래량 1600755
# 실시간(장중 체결) 115337 115100 대비 300 체결량 3 거래량 1600758
# 실시간(장중 체결) 115337 115100 대비 300 체결량 37 거래량 1600795
# 실시간(장중 체결) 115339 115200 대비 400 체결량 1 거래량 1600796
# 실시간(장중 체결) 115341 115100 대비 300 체결량 60 거래량 1600856
# 실시간(장중 체결) 115343 115200 대비 400 체결량 2 거래량 1600858
# 실시간(장중 체결) 115343 115100 대비 300 체결량 2 거래량 1600860
# 실시간(장중 체결) 115344 115200 대비 400 체결량 5 거래량 1600865
# 실시간(장중 체결) 115344 115200 대비 400 체결량 1 거래량 1600866
# 실시간(장중 체결) 115345 115200 대비 400 체결량 2 거래량 1600868
# 실시간(장중 체결) 115345 115100 대비 300 체결량 5 거래량 1600873
# 실시간(장중 체결) 115347 115200 대비 400 체결량 2 거래량 1600875
# 실시간(장중 체결) 115347 115200 대비 400 체결량 3 거래량 1600891
# 실시간(장중 체결) 115347 115200 대비 400 체결량 16 거래량 1600907
# 실시간(장중 체결) 115347 115200 대비 400 체결량 3 거래량 1600916
# 실시간(장중 체결) 115348 115200 대비 400 체결량 2 거래량 1600918
# 실시간(장중 체결) 115348 115200 대비 400 체결량 8 거래량 1600926
# 실시간(장중 체결) 115348 115200 대비 400 체결량 4 거래량 1600930
# 실시간(장중 체결) 115348 115200 대비 400 체결량 4 거래량 1600934
# 실시간(장중 체결) 115349 115200 대비 400 체결량 2 거래량 1600936
# 실시간(장중 체결) 115349 115200 대비 400 체결량 9 거래량 1600945
# 실시간(장중 체결) 115352 115200 대비 400 체결량 7 거래량 1600952
# 실시간(장중 체결) 115353 115200 대비 400 체결량 10 거래량 1600962
# 실시간(장중 체결) 115355 115200 대비 400 체결량 9 거래량 1600971
# 실시간(장중 체결) 115358 115200 대비 400 체결량 1 거래량 1600972
# 실시간(장중 체결) 115359 115200 대비 400 체결량 1 거래량 1600973
# 실시간(장중 체결) 115359 115200 대비 400 체결량 3 거래량 1600976
# 실시간(장중 체결) 115359 115100 대비 300 체결량 300 거래량 1601276
# 실시간(장중 체결) 115359 115100 대비 300 체결량 36 거래량 1601312
# 실시간(장중 체결) 115400 115100 대비 300 체결량 38 거래량 1601350
# 실시간(장중 체결) 115403 115100 대비 300 체결량 1 거래량 1601351
# 실시간(장중 체결) 115405 115100 대비 300 체결량 10 거래량 1601361
# 실시간(장중 체결) 115407 115200 대비 400 체결량 1 거래량 1601362
# 실시간(장중 체결) 115407 115200 대비 400 체결량 1 거래량 1601363
# 실시간(장중 체결) 115407 115100 대비 300 체결량 8 거래량 1601371
# 실시간(장중 체결) 115411 115200 대비 400 체결량 1 거래량 1601372
# 실시간(장중 체결) 115416 115100 대비 300 체결량 30 거래량 1601402
# 실시간(장중 체결) 115416 115100 대비 300 체결량 20 거래량 1601422
# 실시간(장중 체결) 115417 115200 대비 400 체결량 1 거래량 1601423
# 실시간(장중 체결) 115417 115200 대비 400 체결량 2 거래량 1601425
# 실시간(장중 체결) 115417 115200 대비 400 체결량 6 거래량 1601431
# 실시간(장중 체결) 115419 115200 대비 400 체결량 5 거래량 1601436
# 실시간(장중 체결) 115423 115200 대비 400 체결량 3 거래량 1601439
# 실시간(장중 체결) 115426 115100 대비 300 체결량 8 거래량 1601447
# 실시간(장중 체결) 115426 115100 대비 300 체결량 3 거래량 1601450
# 실시간(장중 체결) 115426 115200 대비 400 체결량 15 거래량 1601465
# 실시간(장중 체결) 115432 115200 대비 400 체결량 1 거래량 1601466
# 실시간(장중 체결) 115433 115100 대비 300 체결량 8 거래량 1601474
# 실시간(장중 체결) 115434 115200 대비 400 체결량 4 거래량 1601478
# 실시간(장중 체결) 115436 115200 대비 400 체결량 1 거래량 1601479
# 실시간(장중 체결) 115436 115200 대비 400 체결량 10 거래량 1601489
# 실시간(장중 체결) 115437 115100 대비 300 체결량 20 거래량 1601509
# 실시간(장중 체결) 115438 115200 대비 400 체결량 6 거래량 1601515
# 실시간(장중 체결) 115438 115200 대비 400 체결량 8 거래량 1601536
# 실시간(장중 체결) 115438 115200 대비 400 체결량 2 거래량 1601538
# 실시간(장중 체결) 115439 115200 대비 400 체결량 4 거래량 1601542
# 실시간(장중 체결) 115439 115100 대비 300 체결량 29 거래량 1601571
# 실시간(장중 체결) 115439 115200 대비 400 체결량 200 거래량 1601771
# 실시간(장중 체결) 115439 115200 대비 400 체결량 1 거래량 1601772
# 실시간(장중 체결) 115439 115200 대비 400 체결량 1 거래량 1601773
# 실시간(장중 체결) 115439 115200 대비 400 체결량 1 거래량 1601774
# 실시간(장중 체결) 115440 115100 대비 300 체결량 34 거래량 1601808
# 실시간(장중 체결) 115441 115200 대비 400 체결량 3 거래량 1601811
# 실시간(장중 체결) 115444 115100 대비 300 체결량 1 거래량 1601812
# 실시간(장중 체결) 115444 115100 대비 300 체결량 1 거래량 1601813
# 실시간(장중 체결) 115445 115100 대비 300 체결량 10 거래량 1601823
# 실시간(장중 체결) 115446 115100 대비 300 체결량 8 거래량 1601831
# 실시간(장중 체결) 115447 115100 대비 300 체결량 1 거래량 1601832
# 실시간(장중 체결) 115448 115100 대비 300 체결량 37 거래량 1601869
# 실시간(장중 체결) 115451 115200 대비 400 체결량 1 거래량 1601870
# 실시간(장중 체결) 115451 115100 대비 300 체결량 1 거래량 1601871
# 실시간(장중 체결) 115451 115200 대비 400 체결량 1 거래량 1601872
# 실시간(장중 체결) 115451 115200 대비 400 체결량 1 거래량 1601873
# 실시간(장중 체결) 115453 115100 대비 300 체결량 33 거래량 1601906
# 실시간(장중 체결) 115454 115200 대비 400 체결량 9 거래량 1601915
# 실시간(장중 체결) 115454 115100 대비 300 체결량 50 거래량 1601965
# 실시간(장중 체결) 115455 115100 대비 300 체결량 5 거래량 1601970
# 실시간(장중 체결) 115457 115100 대비 300 체결량 1 거래량 1601971
# 실시간(장중 체결) 115458 115100 대비 300 체결량 1 거래량 1601972
# 실시간(장중 체결) 115459 115100 대비 300 체결량 1 거래량 1601973
# 실시간(장중 체결) 115459 115100 대비 300 체결량 17 거래량 1601990
# 실시간(장중 체결) 115459 115200 대비 400 체결량 1 거래량 1601991
# 실시간(장중 체결) 115459 115100 대비 300 체결량 1 거래량 1601992
# 실시간(장중 체결) 115500 115100 대비 300 체결량 1 거래량 1601993
# 실시간(장중 체결) 115501 115100 대비 300 체결량 1 거래량 1601994
# 실시간(장중 체결) 115501 115200 대비 400 체결량 12 거래량 1602006
# 실시간(장중 체결) 115502 115100 대비 300 체결량 1 거래량 1602007
# 실시간(장중 체결) 115502 115200 대비 400 체결량 1 거래량 1602008
# 실시간(장중 체결) 115502 115200 대비 400 체결량 57 거래량 1602065
# 실시간(장중 체결) 115504 115200 대비 400 체결량 1 거래량 1602066
# 실시간(장중 체결) 115504 115100 대비 300 체결량 8 거래량 1602074
# 실시간(장중 체결) 115504 115200 대비 400 체결량 1 거래량 1602075
# 실시간(장중 체결) 115504 115200 대비 400 체결량 1 거래량 1602076
# 실시간(장중 체결) 115505 115100 대비 300 체결량 5 거래량 1602081
# 실시간(장중 체결) 115512 115200 대비 400 체결량 27 거래량 1602108
# 실시간(장중 체결) 115513 115200 대비 400 체결량 8 거래량 1602116
# 실시간(장중 체결) 115513 115100 대비 300 체결량 38 거래량 1602154
# 실시간(장중 체결) 115515 115100 대비 300 체결량 50 거래량 1602204
# 실시간(장중 체결) 115515 115100 대비 300 체결량 51 거래량 1602255
# 실시간(장중 체결) 115516 115100 대비 300 체결량 27 거래량 1602282
# 실시간(장중 체결) 115516 115200 대비 400 체결량 4 거래량 1602286
# 실시간(장중 체결) 115519 115100 대비 300 체결량 1 거래량 1602287
# 실시간(장중 체결) 115519 115200 대비 400 체결량 1 거래량 1602288
# 실시간(장중 체결) 115523 115200 대비 400 체결량 1 거래량 1602289
# 실시간(장중 체결) 115524 115200 대비 400 체결량 60 거래량 1602349
# 실시간(장중 체결) 115525 115200 대비 400 체결량 51 거래량 1602400
# 실시간(장중 체결) 115525 115100 대비 300 체결량 37 거래량 1602437
# 실시간(장중 체결) 115526 115100 대비 300 체결량 3 거래량 1602440
# 실시간(장중 체결) 115526 115100 대비 300 체결량 100 거래량 1602540
# 실시간(장중 체결) 115526 115200 대비 400 체결량 2 거래량 1602542
# 실시간(장중 체결) 115528 115200 대비 400 체결량 1 거래량 1602543
# 실시간(장중 체결) 115531 115200 대비 400 체결량 1 거래량 1602544
# 실시간(장중 체결) 115532 115100 대비 300 체결량 1 거래량 1602545
# 실시간(장중 체결) 115532 115100 대비 300 체결량 1 거래량 1602546
# 실시간(장중 체결) 115533 115100 대비 300 체결량 1 거래량 1602547
# 실시간(장중 체결) 115533 115100 대비 300 체결량 1 거래량 1602548
# 실시간(장중 체결) 115534 115200 대비 400 체결량 10 거래량 1602558
# 실시간(장중 체결) 115537 115100 대비 300 체결량 2 거래량 1602560
# 실시간(장중 체결) 115539 115100 대비 300 체결량 2 거래량 1602562
# 실시간(장중 체결) 115539 115100 대비 300 체결량 52 거래량 1602614
# 실시간(장중 체결) 115546 115100 대비 300 체결량 1 거래량 1602615
# 실시간(장중 체결) 115552 115100 대비 300 체결량 1 거래량 1602616
# 실시간(장중 체결) 115553 115200 대비 400 체결량 1 거래량 1602617
# 실시간(장중 체결) 115554 115100 대비 300 체결량 19 거래량 1602636
# 실시간(장중 체결) 115554 115100 대비 300 체결량 1 거래량 1602637
# 실시간(장중 체결) 115554 115200 대비 400 체결량 2 거래량 1602639
# 실시간(장중 체결) 115555 115200 대비 400 체결량 1 거래량 1602640
# 실시간(장중 체결) 115555 115100 대비 300 체결량 2 거래량 1602642
# 실시간(장중 체결) 115555 115100 대비 300 체결량 1 거래량 1602643
# 실시간(장중 체결) 115556 115200 대비 400 체결량 1 거래량 1602644
# 실시간(장중 체결) 115556 115200 대비 400 체결량 1 거래량 1602645
# 실시간(장중 체결) 115557 115200 대비 400 체결량 100 거래량 1602745
# 실시간(장중 체결) 115557 115100 대비 300 체결량 34 거래량 1602779
# 실시간(장중 체결) 115600 115200 대비 400 체결량 1 거래량 1602780
# 실시간(장중 체결) 115601 115100 대비 300 체결량 30 거래량 1602810
# 실시간(장중 체결) 115602 115100 대비 300 체결량 10 거래량 1602820
# 실시간(장중 체결) 115602 115200 대비 400 체결량 36 거래량 1602856
# 실시간(장중 체결) 115603 115100 대비 300 체결량 10 거래량 1602866
# 실시간(장중 체결) 115604 115100 대비 300 체결량 1 거래량 1602867
# 실시간(장중 체결) 115604 115100 대비 300 체결량 5 거래량 1602872
# 실시간(장중 체결) 115604 115200 대비 400 체결량 3 거래량 1602875
# 실시간(장중 체결) 115604 115200 대비 400 체결량 8 거래량 1602883
# 실시간(장중 체결) 115605 115200 대비 400 체결량 1 거래량 1602884
# 실시간(장중 체결) 115608 115100 대비 300 체결량 5 거래량 1602889
# 실시간(장중 체결) 115608 115100 대비 300 체결량 13 거래량 1602902
# 실시간(장중 체결) 115608 115200 대비 400 체결량 4 거래량 1602906
# 실시간(장중 체결) 115608 115200 대비 400 체결량 2 거래량 1602908
# 실시간(장중 체결) 115608 115200 대비 400 체결량 5 거래량 1602913
# 실시간(장중 체결) 115608 115200 대비 400 체결량 1 거래량 1602914
# 실시간(장중 체결) 115609 115200 대비 400 체결량 8 거래량 1602922
# 실시간(장중 체결) 115609 115200 대비 400 체결량 4 거래량 1602926
# 실시간(장중 체결) 115609 115200 대비 400 체결량 1 거래량 1602927
# 실시간(장중 체결) 115609 115200 대비 400 체결량 271 거래량 1603198
# 실시간(장중 체결) 115610 115100 대비 300 체결량 1 거래량 1603199
# 실시간(장중 체결) 115610 115100 대비 300 체결량 37 거래량 1603236
# 실시간(장중 체결) 115610 115200 대비 400 체결량 1 거래량 1603237
# 실시간(장중 체결) 115610 115200 대비 400 체결량 4 거래량 1603241
# 실시간(장중 체결) 115610 115200 대비 400 체결량 9 거래량 1603250
# 실시간(장중 체결) 115610 115200 대비 400 체결량 2 거래량 1603252
# 실시간(장중 체결) 115611 115100 대비 300 체결량 37 거래량 1603289
# 실시간(장중 체결) 115611 115200 대비 400 체결량 16 거래량 1603305
# 실시간(장중 체결) 115612 115200 대비 400 체결량 3 거래량 1603308
# 실시간(장중 체결) 115612 115100 대비 300 체결량 46 거래량 1603354
# 실시간(장중 체결) 115614 115200 대비 400 체결량 390 거래량 1603744
# 실시간(장중 체결) 115614 115100 대비 300 체결량 37 거래량 1603781
# 실시간(장중 체결) 115614 115200 대비 400 체결량 1 거래량 1603782
# 실시간(장중 체결) 115615 115200 대비 400 체결량 1 거래량 1603783
# 실시간(장중 체결) 115615 115200 대비 400 체결량 1 거래량 1603784
# 실시간(장중 체결) 115615 115100 대비 300 체결량 38 거래량 1603822
# 실시간(장중 체결) 115616 115100 대비 300 체결량 66 거래량 1603888
# 실시간(장중 체결) 115617 115100 대비 300 체결량 2 거래량 1603890
# 실시간(장중 체결) 115617 115200 대비 400 체결량 2 거래량 1603892
# 실시간(장중 체결) 115620 115200 대비 400 체결량 10 거래량 1603902
# 실시간(장중 체결) 115620 115200 대비 400 체결량 100 거래량 1604002
# 실시간(장중 체결) 115623 115200 대비 400 체결량 4 거래량 1604006
# 실시간(장중 체결) 115625 115100 대비 300 체결량 1 거래량 1604007
# 실시간(장중 체결) 115625 115200 대비 400 체결량 3 거래량 1604010
# 실시간(장중 체결) 115626 115200 대비 400 체결량 34 거래량 1604044
# 실시간(장중 체결) 115626 115100 대비 300 체결량 36 거래량 1604080
# 실시간(장중 체결) 115626 115100 대비 300 체결량 56 거래량 1604136
# 실시간(장중 체결) 115628 115200 대비 400 체결량 8 거래량 1604144
# 실시간(장중 체결) 115628 115200 대비 400 체결량 15 거래량 1604159
# 실시간(장중 체결) 115630 115100 대비 300 체결량 10 거래량 1604169
# 실시간(장중 체결) 115631 115100 대비 300 체결량 51 거래량 1604220
# 실시간(장중 체결) 115632 115200 대비 400 체결량 9 거래량 1604229
# 실시간(장중 체결) 115632 115100 대비 300 체결량 1 거래량 1604230
# 실시간(장중 체결) 115633 115100 대비 300 체결량 12 거래량 1604242
# 실시간(장중 체결) 115633 115200 대비 400 체결량 1 거래량 1604243
# 실시간(장중 체결) 115634 115200 대비 400 체결량 1 거래량 1604244
# 실시간(장중 체결) 115634 115200 대비 400 체결량 200 거래량 1604444
# 실시간(장중 체결) 115634 115200 대비 400 체결량 1 거래량 1604445
# 실시간(장중 체결) 115634 115200 대비 400 체결량 44 거래량 1604489
# 실시간(장중 체결) 115634 115200 대비 400 체결량 1 거래량 1604490
# 실시간(장중 체결) 115635 115100 대비 300 체결량 33 거래량 1604523
# 실시간(장중 체결) 115637 115100 대비 300 체결량 2 거래량 1604525
# 실시간(장중 체결) 115637 115100 대비 300 체결량 79 거래량 1604604
# 실시간(장중 체결) 115638 115200 대비 400 체결량 10 거래량 1604614
# 실시간(장중 체결) 115638 115100 대비 300 체결량 32 거래량 1604646
# 실시간(장중 체결) 115641 115100 대비 300 체결량 10 거래량 1604656
# 실시간(장중 체결) 115645 115100 대비 300 체결량 3 거래량 1604659
# 실시간(장중 체결) 115645 115100 대비 300 체결량 7 거래량 1604666
# 실시간(장중 체결) 115646 115100 대비 300 체결량 1 거래량 1604667
# 실시간(장중 체결) 115647 115200 대비 400 체결량 6 거래량 1604673
# 실시간(장중 체결) 115647 115100 대비 300 체결량 1 거래량 1604674
# 실시간(장중 체결) 115647 115100 대비 300 체결량 19 거래량 1604693
# 실시간(장중 체결) 115648 115200 대비 400 체결량 1 거래량 1604694
# 실시간(장중 체결) 115650 115200 대비 400 체결량 4 거래량 1604698
# 실시간(장중 체결) 115650 115200 대비 400 체결량 5 거래량 1604703
# 실시간(장중 체결) 115650 115200 대비 400 체결량 4 거래량 1604707
# 실시간(장중 체결) 115650 115200 대비 400 체결량 3 거래량 1604710
# 실시간(장중 체결) 115650 115200 대비 400 체결량 8 거래량 1604718
# 실시간(장중 체결) 115650 115200 대비 400 체결량 4 거래량 1604722
# 실시간(장중 체결) 115650 115200 대비 400 체결량 4 거래량 1604726
# 실시간(장중 체결) 115651 115200 대비 400 체결량 5 거래량 1604731
# 실시간(장중 체결) 115651 115200 대비 400 체결량 4 거래량 1604735
# 실시간(장중 체결) 115652 115200 대비 400 체결량 2 거래량 1604737
# 실시간(장중 체결) 115652 115200 대비 400 체결량 8 거래량 1604745
# 실시간(장중 체결) 115652 115200 대비 400 체결량 1 거래량 1604746
# 실시간(장중 체결) 115652 115200 대비 400 체결량 1 거래량 1604754
# 실시간(장중 체결) 115653 115100 대비 300 체결량 2 거래량 1604756
# 실시간(장중 체결) 115653 115200 대비 400 체결량 6 거래량 1604762
# 실시간(장중 체결) 115653 115200 대비 400 체결량 5 거래량 1604767
# 실시간(장중 체결) 115654 115200 대비 400 체결량 1 거래량 1604768
# 실시간(장중 체결) 115654 115100 대비 300 체결량 2 거래량 1604770
# 실시간(장중 체결) 115655 115100 대비 300 체결량 51 거래량 1604821
# 실시간(장중 체결) 115656 115100 대비 300 체결량 37 거래량 1604858
# 실시간(장중 체결) 115656 115100 대비 300 체결량 2 거래량 1604860
# 실시간(장중 체결) 115657 115200 대비 400 체결량 4 거래량 1604864
# 실시간(장중 체결) 115657 115200 대비 400 체결량 7059 거래량 1611923
# 실시간(장중 체결) 115657 115300 대비 500 체결량 100 거래량 1612023
# 실시간(장중 체결) 115657 115300 대비 500 체결량 1225 거래량 1613248
# 실시간(장중 체결) 115658 115300 대비 500 체결량 30 거래량 1613278
# 실시간(장중 체결) 115658 115400 대비 600 체결량 1063 거래량 1614341
# 실시간(장중 체결) 115658 115400 대비 600 체결량 88 거래량 1614429
# 실시간(장중 체결) 115658 115300 대비 500 체결량 20 거래량 1614449
# 실시간(장중 체결) 115659 115300 대비 500 체결량 200 거래량 1614649
# 실시간(장중 체결) 115659 115300 대비 500 체결량 250 거래량 1614899
# 실시간(장중 체결) 115659 115300 대비 500 체결량 280 거래량 1615179
# 실시간(장중 체결) 115701 115300 대비 500 체결량 6 거래량 1615185
# 실시간(장중 체결) 115704 115400 대비 600 체결량 1 거래량 1615186
# 실시간(장중 체결) 115704 115400 대비 600 체결량 1 거래량 1615187
# 실시간(장중 체결) 115704 115400 대비 600 체결량 22 거래량 1615209
# 실시간(장중 체결) 115705 115400 대비 600 체결량 19 거래량 1615228
# 실시간(장중 체결) 115705 115400 대비 600 체결량 1 거래량 1615229
# 실시간(장중 체결) 115706 115400 대비 600 체결량 906 거래량 1616135
# 실시간(장중 체결) 115706 115300 대비 500 체결량 1 거래량 1616136
# 실시간(장중 체결) 115706 115300 대비 500 체결량 1 거래량 1616137
# 실시간(장중 체결) 115709 115300 대비 500 체결량 1 거래량 1616138
# 실시간(장중 체결) 115710 115300 대비 500 체결량 9 거래량 1616147
# 실시간(장중 체결) 115710 115400 대비 600 체결량 3 거래량 1616150
# 실시간(장중 체결) 115710 115400 대비 600 체결량 6 거래량 1616156
# 실시간(장중 체결) 115711 115400 대비 600 체결량 4 거래량 1616160
# 실시간(장중 체결) 115712 115400 대비 600 체결량 3 거래량 1616163
# 실시간(장중 체결) 115714 115400 대비 600 체결량 10 거래량 1616173
# 실시간(장중 체결) 115714 115400 대비 600 체결량 1 거래량 1616174
# 실시간(장중 체결) 115714 115300 대비 500 체결량 1 거래량 1616175
# 실시간(장중 체결) 115714 115300 대비 500 체결량 2 거래량 1616177
# 실시간(장중 체결) 115715 115300 대비 500 체결량 60 거래량 1616237
# 실시간(장중 체결) 115715 115400 대비 600 체결량 150 거래량 1616387
# 실시간(장중 체결) 115716 115300 대비 500 체결량 11 거래량 1616398
# 실시간(장중 체결) 115716 115300 대비 500 체결량 200 거래량 1616598
# 실시간(장중 체결) 115716 115300 대비 500 체결량 9 거래량 1616607
# 실시간(장중 체결) 115717 115400 대비 600 체결량 1 거래량 1616608
# 실시간(장중 체결) 115718 115300 대비 500 체결량 1 거래량 1616609
# 실시간(장중 체결) 115720 115300 대비 500 체결량 10 거래량 1616619
# 실시간(장중 체결) 115720 115400 대비 600 체결량 2 거래량 1616621
# 실시간(장중 체결) 115720 115400 대비 600 체결량 5 거래량 1616627
# 실시간(장중 체결) 115721 115300 대비 500 체결량 29 거래량 1616656
# 실시간(장중 체결) 115721 115400 대비 600 체결량 87 거래량 1616743
# 실시간(장중 체결) 115721 115300 대비 500 체결량 1 거래량 1616744
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
