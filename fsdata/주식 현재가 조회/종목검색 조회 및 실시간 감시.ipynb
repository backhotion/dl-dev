# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client
import pandas as pd
import os

# %%
g_objCodeMgr = win32com.client.Dispatch('CpUtil.CpStockCode')
g_objCpStatus = win32com.client.Dispatch('CpUtil.CpCybos')
g_objCpTrade = win32com.client.Dispatch('CpTrade.CpTdUtil')

# %%
# CpEvent: 실시간 이벤트 수신 클래스
class CpEvent:
    def set_params(self, client, name, caller):
        self.client = client  # CP 실시간 통신 object
        self.name = name  # 서비스가 다른 이벤트를 구분하기 위한 이름
        self.caller = caller  # callback 을 위해 보관

    def OnReceived(self):
        pbData = {}
        # 실시간 종목검색 감시 처리 
        if self.name == 'cssalert':
            pbData['전략ID'] = self.client.GetHeaderValue(0)
            pbData['감시일련번호'] = self.client.GetHeaderValue(1) 
            code = pbData['code'] = self.client.GetHeaderValue(2)
            pbData['종목명'] = name = g_objCodeMgr.CodeToName(code)

            inoutflag = self.client.GetHeaderValue(3)
            if (ord('1') == inoutflag) :
                pbData['INOUT'] = '진입'
            elif (ord('2') == inoutflag) :
                pbData['INOUT'] = '퇴출'
            pbData['시각'] = self.client.GetHeaderValue(4)
            pbData['현재가'] = self.client.GetHeaderValue(5)
            self.caller.checkRealtimeStg(pbData)

# %%
class CpPublish:
    def __init__(self, name, serviceID):
        self.name = name
        self.obj = win32com.client.Dispatch(serviceID)
        self.bIsSB = False

    def Subscribe(self, var, caller):
        if self.bIsSB:
            self.Unsubscribe()

        if (len(var) > 0):
            self.obj.SetInputValue(0, var)

        handler = win32com.client.WithEvents(self.obj, CpEvent)
        handler.set_params(self.obj, self.name, caller)
        self.obj.Subscribe()
        self.bIsSB = True

    def Unsubscribe(self):
        if self.bIsSB:
            self.obj.Unsubscribe()
        self.bIsSB = False

# %%
# CpPBCssAlert: 종목검색 실시간 PB 클래스 
class CpPBCssAlert(CpPublish):
    def __init__(self):
        super().__init__('cssalert', 'CpSysDib.CssAlert')

# %%
# Cp8537 : 종목검색 전략 조회
class Cp8537:
    def __init__(self):
        self.objpb = CpPBCssAlert()
        self.bisSB = False
        self.monList = {}

    def __del__(self):
        self.Clear()

    def Clear(self):
        self.stopAllStgControl()
        if self.bisSB:
            self.objpb.Unsubscribe()
            self.bisSB = False

    def requestList(self, sel):
        retStgList = {}
        objRq = win32com.client.Dispatch("CpSysDib.CssStgList")

        # 예제 전략에서 전략 리스트를 가져옵니다.
        if (sel == '예제') :
            objRq.SetInputValue(0, ord('0'))   # '0' : 예제전략, '1': 나의전략
        else :
            objRq.SetInputValue(0, ord('1'))  # '0' : 예제전략, '1': 나의전략
        objRq.BlockRequest()

        # 통신 및 통신 에러 처리
        rqStatus = objRq.GetDibStatus()
        if rqStatus != 0:
            rqRet = objRq.GetDibMsg1()
            print("통신상태", rqStatus, rqRet)
            return (False, retStgList)

        cnt = objRq.GetHeaderValue(0) # 0 - (long) 전략 목록 수
        flag = objRq.GetHeaderValue(1) # 1 - (char) 요청구분
        print('종목검색 전략수:', cnt)


        for i in range(cnt):
            item = {}
            item['전략명'] = objRq.GetDataValue(0, i)
            item['ID'] = objRq.GetDataValue(1, i)
            item['전략등록일시'] = objRq.GetDataValue(2, i)
            item['작성자필명'] = objRq.GetDataValue(3, i)
            item['평균종목수'] = objRq.GetDataValue(4, i)
            item['평균승률'] = objRq.GetDataValue(5, i)
            item['평균수익'] = objRq.GetDataValue(6, i)
            retStgList[item['전략명']] = item
            print(item)
            
        return (True, retStgList)

    def requestStgID(self, id):
        retStgList = []
        objRq = None
        objRq = win32com.client.Dispatch("CpSysDib.CssStgFind")
        objRq.SetInputValue(0, id) # 전략 id 요청
        objRq.BlockRequest()
        # 통신 및 통신 에러 처리
        rqStatus = objRq.GetDibStatus()
        if rqStatus != 0:
            rqRet = objRq.GetDibMsg1()
            print("통신상태", rqStatus, rqRet)
            return (False, retStgList)

        cnt = objRq.GetHeaderValue(0)  # 0 - (long) 검색된 결과 종목 수
        totcnt = objRq.GetHeaderValue(1)  # 1 - (long) 총 검색 종목 수
        stime = objRq.GetHeaderValue(2)  # 2 - (string) 검색시간
        print('검색된 종목수:', cnt, '전체종목수:', totcnt, '검색시간:', stime)

        for i in range(cnt):
            item = {}
            item['code'] = objRq.GetDataValue(0, i)
            item['종목명'] = g_objCodeMgr.CodeToName(item['code'])
            retStgList.append(item)

        return (True, retStgList)

    def requestMonitorID(self, id):
        objRq = win32com.client.Dispatch("CpSysDib.CssWatchStgSubscribe")
        objRq.SetInputValue(0, id) # 전략 id 요청
        objRq.BlockRequest()


        # 통신 및 통신 에러 처리
        rqStatus = objRq.GetDibStatus()
        if rqStatus != 0:
            rqRet = objRq.GetDibMsg1()
            print("통신상태", rqStatus, rqRet)
            return (False, 0)

        monID = objRq.GetHeaderValue(0)
        if  monID == 0:
            print('감시 일련번호 구하기 실패')
            return (False, 0)

        # monID - 전략 감시를 위한 일련번호를 구해온다.
        # 현재 감시되는 전략이 없다면 감시일련번호로 1을 리턴하고,
        # 현재 감시되는 전략이 있다면 각 통신 ID에 대응되는 새로운 일련번호를 리턴한다.
        return (True, monID)

    def requestStgControl(self, id, monID, bStart):
        objRq = win32com.client.Dispatch("CpSysDib.CssWatchStgControl")
        objRq.SetInputValue(0, id) # 전략 id 요청
        objRq.SetInputValue(1, monID)  # 감시일련번호


        if bStart == True:
            objRq.SetInputValue(2, ord('1'))  # 감시시작
            print('전략감시 시작 요청 ', '전략 ID:', id, '감시일련번호',monID)
        else:
            objRq.SetInputValue(2, ord('3'))  # 감시취소
            print('전략감시 취소 요청 ', '전략 ID:', id, '감시일련번호', monID)
        objRq.BlockRequest()


        # 통신 및 통신 에러 처리
        rqStatus = objRq.GetDibStatus()
        if rqStatus != 0:
            rqRet = objRq.GetDibMsg1()
            print("통신상태", rqStatus, rqRet)
            return (False, '')

        status = objRq.GetHeaderValue(0)

        if status == 0 :
            print('전략감시상태: 초기상태')
        elif status == 1 :
            print('전략감시상태: 감시중')
        elif status == 2 :
            print('전략감시상태: 감시중단')
        elif status == 3 :
            print('전략감시상태: 등록취소')


        # event 수신 요청 - 요청 중이 아닌 경우에만 요청
        if self.bisSB == False:
            self.objpb.Subscribe('', self)
            self.bisSB = True

        # 진행 중인 전략들 저장
        if bStart == True:
            self.monList[id] = monID
        else:
            if id in self.monList :
                del self.monList[id]


        return (True, status)

    def stopAllStgControl(self):
        delitem = []
        for id, monId in self.monList.items() :
            delitem.append((id,monId))

        for item in delitem:
            self.requestStgControl(item[0], item[1], False)

        print(len(self.monList))

    def checkRealtimeStg(self, pbData):
        # 감시중인 전략인 경우만 체크
        id = pbData['전략ID']
        monid = pbData['감시일련번호']
        if not (id in self.monList) :
            return

        if (monid != self.monList[id]) :
            return

        print(pbData)

# %%
class MyWindow(QMainWindow):
    def __init__(self):
        super().__init__()

        self.setWindowTitle("종목검색 예제")
        self.setGeometry(300, 300, 500, 180)

        self.obj8537 = Cp8537()
        self.dataStg = []

        nH = 20
        self.comboStg = QComboBox(self)
        self.comboStg.move(20, nH)
        self.comboStg.currentIndexChanged.connect(self.comboChanged)
        self.comboStg.resize(400, 30)
        nH += 50

        btnExit = QPushButton('종료', self)
        btnExit.move(20, nH)
        btnExit.clicked.connect(self.btnExit_clicked)
        nH += 50
        self.setGeometry(300, 300, 500, nH)

        self.listAllStrategy()


    def __del__(self):
        self.obj8537.Clear()


    # 전략리스트 조회
    def listAllStrategy(self):
        self.comboStg.addItem('VI 근접 종목(상승)')
        self.data8537 = {}
        ret, self.data8537 = self.obj8537.requestList('예제')

        for k, v in self.data8537.items():
            self.comboStg.addItem(k)
        return



    def comboChanged(self):
        stgName = self.comboStg.currentText()
        print(stgName)
        if (stgName == 'VI 근접 종목(상승)') :
            return

        # 1: 기존 감시 중단 (중요)
        # 종목검색 실시간 감시 개수 제한이 있어, 불필요한 감시는 중단이 필요
        self.obj8537.Clear()

        # 2 - 종목검색 조회: CpSysDib.CssStgFind
        item = self.data8537[stgName]
        id = item['ID']
        name = item['전략명']

        ret, self.dataStg = self.obj8537.requestStgID(id)
        if ret == False :
            return

        for item in self.dataStg:
            print(item)
        print('검색전략:', id, '전략명:', name, '검색종목수:', len(self.dataStg))

        if (len(self.dataStg) >= 200) :
            print('검색종목이 200 을 초과할 경우 실시간 감시 불가 ')
            return

        #####################################################
        # 실시간 요청
        # 3 - 전략의 감시 일련번호 요청 : CssWatchStgSubscribe
        ret, monid = self.obj8537.requestMonitorID(id)
        if (False == ret):
            return
        print('감시일련번호', monid)

        # 4 - 전략 감시 시작 요청 - CpSysDib.CssWatchStgControl
        ret, status = self.obj8537.requestStgControl(id, monid, True)
        if (False == ret):
            return

        return



    def btnExit_clicked(self):
        self.obj8537.Clear()
        exit()
        return

# %%
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()
# Out:
# VI 근접 종목(상승)
# 종목검색 전략수: 180
# {'전략명': '시간외단일가매매 하락률 상위종목', 'ID': 'B6TuaR0AT2qDOOE9i2/KUQ', '전략등록일시': '2022/03/22 07:47', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명':
'작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '외국인 기간보유율 증가순 - 최근 5일간', 'ID': 'cKEYrEeOSh27DeUMhuJIPw', '전략등록일시': '2015/11/25 14:58', '작성자필명': '8537_예제전략', '평균종목수': 48, '평균승률': 0.4679, '평균수익': -0.0001}
# {'전략명': '외국인 기간보유율 감소순 - 최근 5일간', 'ID': '4gH8ignzShCu1Cv0eKAmWQ', '전략등록일시': '2015/11/25 14:58', '작성자필명': '8537_예제전략', '평균종목수': 53, '평균승률': 0.4314, '평균수익': 0.0001}
# {'전략명': '기관 순매수 상위종목(수량) - 금일기준', 'ID': 'OPS16RXETFiRnHnPCsok9Q', '전략등록일시': '2015/11/25 14:57', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매수 상위종목(수량) - 전일기준', 'ID': 'f4FL6l73SFivfy+ZDnmuZw', '전략등록일시': '2015/11/25 14:57', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매수 상위종목(금액) - 전일기준', 'ID': 'FaITlmpLTXmROyO7nXcEXg', '전략등록일시': '2015/11/25 14:57', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매도 상위종목(수량) - 전일기준', 'ID': '43k5sOAFTxCgZgLIve5ofw', '전략등록일시': '2015/11/25 14:56', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매수 상위종목(금액) - 금일기준', 'ID': 'dTdrMzG4Soy2dsD6HcLPWA', '전략등록일시': '2015/11/25 14:56', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매도 상위종목(수량) - 금일기준', 'ID': '9CqGtJlLSiGm8zWwI8Jy+A', '전략등록일시': '2015/11/25 14:55', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매도 상위종목(금액) - 전일기준', 'ID': '1cL9fQRXRcqIcQnnsx2E3A', '전략등록일시': '2015/11/25 14:55', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 순매도 상위종목(금액) - 금일기준', 'ID': 'JemSeTISQHm54WbuU00IhA', '전략등록일시': '2015/11/25 14:55', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 보유주식수 증가순 - 최근 5일간', 'ID': 'K+0oRqJPSduLb5Z2K6lhHw', '전략등록일시': '2015/11/25 14:54', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 보유금액 증가순 - 최근 5일간', 'ID': 'WjRyIQCPQ5qXEST7eD0jYg', '전략등록일시': '2015/11/25 14:53', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 보유주식수 감소순 - 최근 5일간', 'ID': 'ZgISyjDlTkC5iRsAzudWjg', '전략등록일시': '2015/11/25 14:53', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 보유금액 감소순 - 최근 5일간', 'ID': 'kpOm6D2SS7q5a6+VQO7ghQ', '전략등록일시': '2015/11/25 14:52', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 기간보유율 증가순 - 최근 5일간', 'ID': 'A3gUCjWXSQyT/JWIk27zkg', '전략등록일시': '2015/11/25 14:52', '작성자필명': '8537_예제전략', '평균종목수': 56, '평균승률': 0.47259999999999996, '평균수익': -0.0002}
# {'전략명': '기관 기간보유율 감소순 - 최근 5일간', 'ID': 'AuISlUo5SGy3dUdmseUnfw', '전략등록일시': '2015/11/25 14:52', '작성자필명': '8537_예제전략', '평균종목수': 85, '평균승률': 0.49079999999999996, '평균수익': 0.0004}
# {'전략명': '최근 5일 첫상한가', 'ID': 'FJeKoAuJTzS69NXQYr8GXg', '전략등록일시': '2015/11/25 14:51', '작성자필명': '8537_예제전략', '평균종목수': 2, '평균승률': 0.7989, '평균수익': 0.1024}
# {'전략명': '전일 상한가 종목', 'ID': 'aZfPubP1STqT3gjRl3gUJA', '전략등록일시': '2015/11/25 14:50', '작성자필명': '8537_예제전략', '평균종목수': 4, '평균승률': 0.3132, '평균수익': -0.0209}
# {'전략명': '장중 상한가 형성후 이탈종목', 'ID': 'JWdvXGSbT7yCIl5qHciIog', '전략등록일시': '2015/11/25 14:50', '작성자필명': '8537_예제전략', '평균종목수': 2, '평균승률': 0.3019, '평균수익': -0.0271}
# {'전략명': '상한가 임박종목', 'ID': 'tvg/C8PbSnWFFpW+8gubpA', '전략등록일시': '2015/11/25 14:50', '작성자필명': '8537_예제전략', '평균종목수': 1, '평균승률': 0.4167, '평균수익': -0.0246}
# {'전략명': '2일이상 연속 상한가 종목', 'ID': 'WXvbFkraRZeFkk7dcEMu9w', '전략등록일시': '2015/11/25 14:50', '작성자필명': '8537_예제전략', '평균종목수': 1, '평균승률': 0.6667000000000001, '평균수익': 0.0779}
# {'전략명': '이격도 반전', 'ID': '8uWkHsY5TICeOUDC2bzvsA', '전략등록일시': '2015/11/25 14:49', '작성자필명': '8537_예제전략', '평균종목수': 70, '평균승률': 0.4143, '평균수익': 0.002}
# {'전략명': '파워스펙트럼 상승 1단계', 'ID': 'pTDPjeERRkeO7oliydKeDA', '전략등록일시': '2015/11/25 14:49', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '하락추세선 상향돌파', 'ID': 'qjYLy+g+Tta+TiaY5mdjbg', '전략등록일시': '2015/11/25 14:49', '작성자필명': '8537_예제전략', '평균종목수': 44, '평균승률': 0.4539, '평균수익': 0.0004}
# {'전략명': '박스차트 상단 돌파', 'ID': 'gx+ZDHemRjWonGweaU6nXw', '전략등록일시': '2015/11/25 14:48', '작성자필명': '8537_예제전략', '평균종목수': 16, '평균승률': 0.4253, '평균수익': -0.0058}
# {'전략명': '그물망 바닥 탈피', 'ID': 'Ea2D32b6S4a6iI/wJN1jWg', '전략등록일시': '2015/11/25 14:48', '작성자필명': '8537_예제전략', '평균종목수': 43, '평균승률': 0.47300000000000003, '평균수익': 0.0012}
# {'전략명': '볼린져밴드 과매도', 'ID': '504igmGuQVG7Q9v3Y4o7bQ', '전략등록일시': '2015/11/25 14:48', '작성자필명': '8537_예제전략', '평균종목수': 42, '평균승률': 0.4595, '평균수익': -0.0005}
# {'전략명': "WILLIAM'S %R 돌파", 'ID': 'hu0h4CvRRvuf7dQgoZks0A', '전략등록일시': '2015/11/25 14:47', '작성자필명': '8537_예제전략', '평균종목수': 3, '평균승률': 0.4928, '평균수익': 0.0068000000000000005}
# {'전략명': 'TSF 추세 지속', 'ID': '2wesodTGRVy9V9Vjm0ursg', '전략등록일시': '2015/11/25 14:47', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': 'TREND POWER 단기추세 상승 전환', 'ID': 'ri5m31eQSTui44Oo/keRGA', '전략등록일시': '2015/11/25 14:47', '작성자필명': '8537_예제전략', '평균종목수': 125, '평균승률': 0.414, '평균수익': 0.0005}
# {'전략명': 'STOCHASTIC 상승 반전', 'ID': 'XtcpNBR5S4+IAy/ZDb6Rvg', '전략등록일시': '2015/11/25 14:47', '작성자필명': '8537_예제전략', '평균종목수': 8, '평균승률': 0.45020000000000004, '평균수익': -0.0001}
# {'전략명': 'SIGMA 상향 돌파', 'ID': 'DEQiZs+lQ46NEQvz9nT+9Q', '전략등록일시': '2015/11/25 14:47', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': 'RSI 상승 반전', 'ID': 'af3EWdloQKCT0LYmICNcGA', '전략등록일시': '2015/11/25 14:46', '작성자필명': '8537_예제전략', '평균종목수': 102, '평균승률': 0.4066, '평균수익': 0.0027}
# {'전략명': 'PIVOT 급등', 'ID': 'LSSYLP+5TbG4YVlXVGhPQw', '전략등록일시': '2015/11/25 14:46', '작성자필명': '8537_예제전략', '평균종목수': 68, '평균승률': 0.4531, '평균수익': 0.0017000000000000001}
# {'전략명': 'PRICE CHANNEL 단기 반등', 'ID': 'Cbwr5f1pTwi0w7FPgNNISw', '전략등록일시': '2015/11/25 14:46', '작성자필명': '8537_예제전략', '평균종목수': 9, '평균승률': 0.4439, '평균수익': -0.0011}
# {'전략명': 'RSI STOCHASTIC 반전', 'ID': 'Cj+G2//sTauRdWHHzHgj4w', '전략등록일시': '2015/11/25 14:46', '작성자필명': '8537_예제전략', '평균종목수': 112, '평균승률': 0.36340000000000006, '평균수익': -0.0029}
# {'전략명': 'MFI 상향돌파 + CO 상승 반전', 'ID': 'BggYDSAfT2KfyhjZecU6yQ', '전략등록일시': '2015/11/25 14:45', '작성자필명': '8537_예제전략', '평균종목수': 14, '평균승률': 0.48829999999999996, '평균수익': 0.0016}
# {'전략명': 'NET POWER 기준선 상향 돌파', 'ID': '5VmxJMkkRuOc+CrOaGDqjA', '전략등록일시': '2015/11/25 14:45', '작성자필명': '8537_예제전략', '평균종목수': 108, '평균승률': 0.4249, '평균수익': 0.0017000000000000001}
# {'전략명': 'LRS 상향돌파', 'ID': 'ac5dkql6SieTcQITzS43MQ', '전략등록일시': '2015/11/25 14:45', '작성자필명': '8537_예제전략', '평균종목수': 4, '평균승률': 0.4804, '평균수익': 0.0041}
# {'전략명': 'MACD 상승초기', 'ID': 'kYaCb+nPT86XxoPryiS7Tw', '전략등록일시': '2015/11/25 14:45', '작성자필명': '8537_예제전략', '평균종목수': 30, '평균승률': 0.5107, '평균수익': 0.0035000000000000005}
# {'전략명': 'DMI 합성', 'ID': 'bfT+958sQh6RsjARd6v3qw', '전략등록일시': '2015/11/25 14:44', '작성자필명': '8537_예제전략', '평균종목수': 1, '평균승률': 0.2333, '평균수익': -0.028999999999999998}
# {'전략명': 'CCI 눌림목탈피', 'ID': 'b0/0xMV8RiaO2jgVzl3wPA', '전략등록일시': '2015/11/25 14:44', '작성자필명': '8537_예제전략', '평균종목수': 38, '평균승률': 0.41700000000000004, '평균수익': -0.0001}
# {'전략명': 'ENERGY 상향돌파', 'ID': 'u8G+M9r6RxqxymGfkYHUxg', '전략등록일시': '2015/11/25 14:44', '작성자필명': '8537_예제전략', '평균종목수': 49, '평균승률': 0.4661, '평균수익': 0.0014000000000000002}
# {'전략명': 'GOLDEN POWER 상승 전환', 'ID': 'BPxpM33bT1CXd8sjNC+dRg', '전략등록일시': '2015/11/25 14:44', '작성자필명': '8537_예제전략', '평균종목수': 103, '평균승률': 0.3954, '평균수익': 0.0026}
# {'전략명': '캔들 연속양봉(10분)', 'ID': 'kAtMDMc0SLWhc+BlfRq54w', '전략등록일시': '2015/11/25 14:43', '작성자필명': '8537_예제전략', '평균종목수': 36, '평균승률': 0.4094, '평균수익': -0.0003}
# {'전략명': '캔들분석-상승반전형(10분)', 'ID': 'aPnC8283S/GM+OcJFbVchA', '전략등록일시': '2015/11/25 14:43', '작성자필명': '8537_예제전략', '평균종목수': 95, '평균승률': 0.48310000000000003, '평균수익': 0.001}
# {'전략명': '최근 20봉 횡보종목-2%이내(10분)', 'ID': 'dx6EV6yUQp6kkR6CQhKtng', '전략등록일시': '2015/11/25 14:43', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '첫 상한가(5일MA 돌파)', 'ID': 'XHv1q4aKSsGVLzjk2V0UDw', '전략등록일시': '2015/11/25 14:42', '작성자필명': '8537_예제전략', '평균종목수': 1, '평균승률': 0.7417, '평균수익': 0.0842}
# {'전략명': '직전봉대비 가격급등(10분)', 'ID': 'nmzkGiAMRsao5/e1NryfQQ', '전략등록일시': '2015/11/25 14:42', '작성자필명': '8537_예제전략', '평균종목수': 15, '평균승률': 0.3628, '평균수익': -0.0063}
# {'전략명': '주가이평(5,20) 골든크로스(10분)', 'ID': 'UuCN60x6RRWu3DyXl5VdJg', '전략등록일시': '2015/11/25 14:42', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '주가 5MA 돌파-정배열(일간)', 'ID': '1vbqhIIJSN2N/ZtgC07Pnw', '전략등록일시': '2015/11/25 14:41', '작성자필명': '8537_예제전략', '평균종목수': 36, '평균승률': 0.458, '평균수익': 0.0015}
# {'전략명': '주가 이평지지-5MA(10분)', 'ID': 'OeIIR8q7SM+9+esigO/X1A', '전략등록일시': '2015/11/25 14:41', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '주가 이동평균선 정배열(10분)', 'ID': 'S+XifSYKRzaCvWUlul2RRA', '전략등록일시': '2015/11/25 14:41', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '우선주 괴리율 상위종목', 'ID': 'c24PXGaHT/m62zXmFhSqgg', '전략등록일시': '2015/11/25 14:40', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '외국인2일이상연속순매수(전일)', 'ID': 'RdcLUo8VS4CGxR9NBbjDaQ', '전략등록일시': '2015/11/25 14:40', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '전일외국인첫매수', 'ID': 'CAuAH9FcQBSuoM2Ru68AQg', '전략등록일시': '2015/11/25 14:40', '작성자필명': '8537_예제전략', '평균종목수': 58, '평균승률': 0.4989, '평균수익': 0.0014000000000000002}
# {'전략명': '이동평균 밀집(일간)', 'ID': 'Tm/Xyj9DTiOdffEuKJZojQ', '전략등록일시': '2015/11/25 14:40', '작성자필명': '8537_예제전략', '평균종목수': 8, '평균승률': 0.44170000000000004, '평균수익': -0.0016}
# {'전략명': '전일기관첫매수', 'ID': '1vpkvTtYQ6Smdgz6a4FnKw', '전략등록일시': '2015/11/25 14:40', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '단기급락후 5MA상향돌파', 'ID': 'UmeceEh0SP+NdDOhhF6y5g', '전략등록일시': '2015/11/25 14:39', '작성자필명': '8537_예제전략', '평균종목수': 4, '평균승률': 0.4475, '평균수익': 0.0192}
# {'전략명': '오늘외국계첫매수', 'ID': 'r+H6ACHqRkCeA/l/Nf++eg', '전략등록일시': '2015/11/25 14:39', '작성자필명': '8537_예제전략', '평균종목수': 1, '평균승률': 0.5, '평균수익': -0.0195}
# {'전략명': '기관2일이상연속순매수(전일)', 'ID': 'bc8IifzIRuy+IVvE15hMGA', '전략등록일시': '2015/11/25 14:39', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '상승 갭(5분)', 'ID': '4z0VU9l4SKOyk7ES7j/guw', '전략등록일시': '2015/11/25 14:39', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 외국인 동시순매수(전일)', 'ID': 'u/8OPXCCQni+FqPw/+b3OA', '전략등록일시': '2015/11/25 14:38', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': 'MACD Signal선 상향돌파(10분)', 'ID': 'E50pwvZzQwiGKWl1B/mOyQ', '전략등록일시': '2015/11/25 14:37', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '거래량 5MA 대비 급등(5분)', 'ID': 'b3Ql2VqsRcSZJlUOq4i8sg', '전략등록일시': '2015/11/25 14:37', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '기관 외국인 동시순매도(전일)', 'ID': 'H5HgbO9hSU2SfCAMxOjKsw', '전략등록일시': '2015/11/25 14:37', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '이평 이격도(5,20) 과열(일간)', 'ID': '4KSvaYFLSKu+QpGpTm3agw', '전략등록일시': '2015/11/25 14:36', '작성자필명': '8537_예제전략', '평균종목수': 39, '평균승률': 0.40509999999999996, '평균수익': -0.0023}
# {'전략명': '캔들분석-하락반전형(10분)', 'ID': 'tdzLqrMVQtC7KMOiLP9BQQ', '전략등록일시': '2015/11/25 14:36', '작성자필명': '8537_예제전략', '평균종목수': 144, '평균승률': 0.4861, '평균수익': 0.0003}
# {'전략명': 'MACD Signal선 하향돌파(10분)', 'ID': 'jdh+UOgiRyWcTQUmu6I6OA', '전략등록일시': '2015/11/25 14:36', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '주가이평(5,20)데드크로스(10분)', 'ID': 'sC98JZT7ReaKZNxdqzG6IQ', '전략등록일시': '2015/11/25 14:36', '작성자필명': '8537_예제전략', '평균종목수': 81, '평균승률': 0.43090000000000006, '평균수익': 0.002}
# {'전략명': '캔들 연속음봉(10분)', 'ID': 'lOA9+WJGSYSrQ0q2uSUSmg', '전략등록일시': '2015/11/25 14:36', '작성자필명': '8537_예제전략', '평균종목수': 21, '평균승률': 0.43060000000000004, '평균수익': -0.0028000000000000004}
# {'전략명': '하락 갭(5분)', 'ID': 'cV7lbkpzQKOAzL1VmSGUhQ', '전략등록일시': '2015/11/25 14:35', '작성자필명': '8537_예제전략', '평균종목수': 0, '평균승률': -999.99, '평균수익': -999.99}
# {'전략명': '단기급등후 5MA하향돌파(일간)', 'ID': 'Ea6U6sWFRiSlHpeGZVrptg', '전략등록일시': '2015/11/25 14:34', '작성자필명': '8537_예제전략', '평균종목수': 3, '평균승률': 0.4347, '평균수익': 0.0017000000000000001}
# 0
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
