# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client

# %%
# 복수 종목 실시간 조회 샘플 (조회는 없고 실시간만 있음)
class CpEvent:
    def set_params(self, client):
        self.client = client
 
    def OnReceived(self):
        code = self.client.GetHeaderValue(0)  # 초
        name = self.client.GetHeaderValue(1)  # 초
        timess = self.client.GetHeaderValue(18)  # 초
        exFlag = self.client.GetHeaderValue(19)  # 예상체결 플래그
        cprice = self.client.GetHeaderValue(13)  # 현재가
        diff = self.client.GetHeaderValue(2)  # 대비
        cVol = self.client.GetHeaderValue(17)  # 순간체결수량
        vol = self.client.GetHeaderValue(9)  # 거래량
 
        if (exFlag == ord('1')):  # 동시호가 시간 (예상체결)
            print("실시간(예상체결)", name, timess, "*", cprice, "대비", diff, "체결량", cVol, "거래량", vol)
        elif (exFlag == ord('2')):  # 장중(체결)
            print("실시간(장중 체결)", name, timess, cprice, "대비", diff, "체결량", cVol, "거래량", vol)

# %%
class CpStockCur:
    def Subscribe(self, code):
        self.objStockCur = win32com.client.Dispatch("DsCbo1.StockCur")
        handler = win32com.client.WithEvents(self.objStockCur, CpEvent)
        self.objStockCur.SetInputValue(0, code)
        handler.set_params(self.objStockCur)
        self.objStockCur.Subscribe()
 
    def Unsubscribe(self):
        self.objStockCur.Unsubscribe()

# %%
class CpMarketEye:
    def Request(self, codes, rqField):
        # 연결 여부 체크
        objCpCybos = win32com.client.Dispatch("CpUtil.CpCybos")
        bConnect = objCpCybos.IsConnect
        if (bConnect == 0):
            print("PLUS가 정상적으로 연결되지 않음. ")
            return False
 
        # 관심종목 객체 구하기
        objRq = win32com.client.Dispatch("CpSysDib.MarketEye")
        # 요청 필드 세팅 - 종목코드, 종목명, 시간, 대비부호, 대비, 현재가, 거래량
        # rqField = [0,17, 1,2,3,4,10]
        objRq.SetInputValue(0, rqField) # 요청 필드
        objRq.SetInputValue(1, codes)  # 종목코드 or 종목코드 리스트
        objRq.BlockRequest()
 
 
        # 현재가 통신 및 통신 에러 처리
        rqStatus = objRq.GetDibStatus()
        rqRet = objRq.GetDibMsg1()
        print("통신상태", rqStatus, rqRet)
        if rqStatus != 0:
            return False
 
        cnt  = objRq.GetHeaderValue(2)
 
        for i in range(cnt):
            rpCode = objRq.GetDataValue(0, i)  # 코드
            rpName = objRq.GetDataValue(1, i)  # 종목명
            rpTime= objRq.GetDataValue(2, i)  # 시간
            rpDiffFlag = objRq.GetDataValue(3, i)  # 대비부호
            rpDiff = objRq.GetDataValue(4, i)  # 대비
            rpCur = objRq.GetDataValue(5, i)  # 현재가
            rpVol = objRq.GetDataValue(6, i)  # 거래량
            print(rpCode, rpName, rpTime,  rpDiffFlag, rpDiff, rpCur, rpVol)
 
        return True

# %%
class MyWindow(QMainWindow):
 
    def __init__(self):
        super().__init__()
        self.setWindowTitle("PLUS API TEST")
        self.setGeometry(300, 300, 300, 150)
        self.isSB = False
        self.objCur = []
 
        btnStart = QPushButton("요청 시작", self)
        btnStart.move(20, 20)
        btnStart.clicked.connect(self.btnStart_clicked)
 
        btnStop = QPushButton("요청 종료", self)
        btnStop.move(20, 70)
        btnStop.clicked.connect(self.btnStop_clicked)
 
        btnExit = QPushButton("종료", self)
        btnExit.move(20, 120)
        btnExit.clicked.connect(self.btnExit_clicked)
 
    def StopSubscribe(self):
        if self.isSB:
            cnt = len(self.objCur)
            for i in range(cnt):
                self.objCur[i].Unsubscribe()
            print(cnt, "종목 실시간 해지되었음")
        self.isSB = False
 
        self.objCur = []
 
    def btnStart_clicked(self):
        self.StopSubscribe();
 
        # 요청 종목 배열
        codes = ["A079970", "A108860", "A300080", "A338220", "A347860", "A095910"]
        # 요청 필드 배열 - 종목코드, 시간, 대비부호 대비, 현재가, 거래량, 종목명
        rqField = [0, 1, 2, 3, 4, 10, 17]  #요청 필드
        objMarkeyeye = CpMarketEye()
        if (objMarkeyeye.Request(codes, rqField) == False):
            exit()
 
        cnt = len(codes)
        for i in range(cnt):
            self.objCur.append(CpStockCur())
            self.objCur[i].Subscribe(codes[i])
 
        print("빼기빼기================-")
        print(cnt , "종목 실시간 현재가 요청 시작")
        self.isSB = True
 
    def btnStop_clicked(self):
        self.StopSubscribe()
 
 
    def btnExit_clicked(self):
        self.StopSubscribe()
        exit()
 
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exit()
    gExcelFile = '주식 복수종목 실시간.csv'
# Out:
# 통신상태 0 0027 조회가 완료되었습니다.(market.eye)
# A079970 1121 53 -10 1085 423501 투비소프트
# A108860 1121 50 20 17780 194548 셀바스AI
# A300080 1121 50 350 30900 15217 플리토
# A338220 1121 50 550 33500 449922 뷰노
# A347860 1121 51 0 10310 29841 알체라
# A095910 1121 50 10 2755 32308 에스에너지
# 빼기빼기================-
# 6 종목 실시간 현재가 요청 시작
# 실시간(장중 체결) 뷰노 112150 33500 대비 550 체결량 12 거래량 449934
# 실시간(장중 체결) 뷰노 112150 33550 대비 600 체결량 38 거래량 449972
# 실시간(장중 체결) 뷰노 112155 33500 대비 550 체결량 30 거래량 450002
# 실시간(장중 체결) 뷰노 112156 33500 대비 550 체결량 1 거래량 450003
# 실시간(장중 체결) 뷰노 112159 33500 대비 550 체결량 2 거래량 450005
# 실시간(장중 체결) 셀바스AI 112200 17790 대비 30 체결량 17 거래량 194565
# 실시간(장중 체결) 뷰노 112202 33500 대비 550 체결량 55 거래량 450060
# 실시간(장중 체결) 뷰노 112202 33550 대비 600 체결량 45 거래량 450105
# 실시간(장중 체결) 셀바스AI 112204 17790 대비 30 체결량 20 거래량 194585
# 실시간(장중 체결) 플리토 112206 30900 대비 350 체결량 2 거래량 15219
# 실시간(장중 체결) 뷰노 112208 33550 대비 600 체결량 3 거래량 450108
# 실시간(장중 체결) 뷰노 112208 33550 대비 600 체결량 15 거래량 450123
# 실시간(장중 체결) 뷰노 112209 33500 대비 550 체결량 3 거래량 450126
# 실시간(장중 체결) 셀바스AI 112211 17790 대비 30 체결량 1 거래량 194586
# 실시간(장중 체결) 뷰노 112219 33500 대비 550 체결량 10 거래량 450136
# 실시간(장중 체결) 뷰노 112224 33450 대비 500 체결량 136 거래량 450272
# 실시간(장중 체결) 뷰노 112231 33450 대비 500 체결량 39 거래량 450311
# 실시간(장중 체결) 뷰노 112232 33450 대비 500 체결량 100 거래량 450411
# 실시간(장중 체결) 뷰노 112232 33500 대비 550 체결량 1 거래량 450412
# 실시간(장중 체결) 뷰노 112233 33450 대비 500 체결량 8 거래량 450420
# 실시간(장중 체결) 셀바스AI 112238 17790 대비 30 체결량 20 거래량 194606
# 실시간(장중 체결) 뷰노 112240 33450 대비 500 체결량 47 거래량 450467
# 실시간(장중 체결) 뷰노 112241 33400 대비 450 체결량 400 거래량 450867
# 실시간(장중 체결) 뷰노 112244 33400 대비 450 체결량 2 거래량 450869
# 실시간(장중 체결) 뷰노 112244 33400 대비 450 체결량 1 거래량 450870
# 실시간(장중 체결) 뷰노 112244 33400 대비 450 체결량 7 거래량 450877
# 실시간(장중 체결) 뷰노 112244 33450 대비 500 체결량 1 거래량 450878
# 실시간(장중 체결) 뷰노 112247 33350 대비 400 체결량 60 거래량 450938
# 실시간(장중 체결) 셀바스AI 112248 17790 대비 30 체결량 4 거래량 194610
# 실시간(장중 체결) 뷰노 112254 33450 대비 500 체결량 1 거래량 450939
# 실시간(장중 체결) 뷰노 112258 33450 대비 500 체결량 1 거래량 450940
# 실시간(장중 체결) 셀바스AI 112307 17790 대비 30 체결량 380 거래량 194990
# 실시간(장중 체결) 뷰노 112308 33400 대비 450 체결량 6 거래량 450946
# 실시간(장중 체결) 뷰노 112309 33400 대비 450 체결량 36 거래량 450982
# 실시간(장중 체결) 뷰노 112313 33400 대비 450 체결량 8 거래량 450990
# 실시간(장중 체결) 뷰노 112318 33400 대비 450 체결량 5 거래량 450995
# 실시간(장중 체결) 뷰노 112319 33400 대비 450 체결량 1 거래량 450996
# 실시간(장중 체결) 뷰노 112325 33400 대비 450 체결량 2 거래량 450998
# 실시간(장중 체결) 뷰노 112325 33400 대비 450 체결량 2 거래량 451000
# 실시간(장중 체결) 알체라 112333 10310 대비 0 체결량 1 거래량 29842
# 실시간(장중 체결) 뷰노 112336 33400 대비 450 체결량 1 거래량 451001
# 실시간(장중 체결) 뷰노 112339 33350 대비 400 체결량 1123 거래량 452124
# 실시간(장중 체결) 뷰노 112339 33350 대비 400 체결량 50 거래량 452174
# 실시간(장중 체결) 뷰노 112340 33350 대비 400 체결량 15 거래량 452189
# 실시간(장중 체결) 뷰노 112343 33400 대비 450 체결량 1 거래량 452190
# 실시간(장중 체결) 뷰노 112343 33350 대비 400 체결량 7 거래량 452197
# 실시간(장중 체결) 뷰노 112343 33350 대비 400 체결량 2 거래량 452199
# 실시간(장중 체결) 뷰노 112346 33350 대비 400 체결량 30 거래량 452229
# 실시간(장중 체결) 뷰노 112346 33350 대비 400 체결량 16 거래량 452245
# 실시간(장중 체결) 뷰노 112346 33400 대비 450 체결량 4 거래량 452249
# 실시간(장중 체결) 뷰노 112347 33350 대비 400 체결량 1 거래량 452250
# 실시간(장중 체결) 뷰노 112349 33400 대비 450 체결량 1 거래량 452251
# 실시간(장중 체결) 뷰노 112354 33400 대비 450 체결량 1 거래량 452252
# 실시간(장중 체결) 뷰노 112354 33400 대비 450 체결량 1 거래량 452253
# 실시간(장중 체결) 뷰노 112357 33400 대비 450 체결량 1 거래량 452254
# 실시간(장중 체결) 뷰노 112357 33350 대비 400 체결량 39 거래량 452293
# 실시간(장중 체결) 뷰노 112401 33400 대비 450 체결량 20 거래량 452313
# 실시간(장중 체결) 뷰노 112401 33400 대비 450 체결량 3 거래량 452316
# 실시간(장중 체결) 뷰노 112402 33350 대비 400 체결량 56 거래량 452372
# 실시간(장중 체결) 뷰노 112402 33300 대비 350 체결량 13 거래량 452385
# 실시간(장중 체결) 뷰노 112403 33300 대비 350 체결량 1 거래량 452386
# 실시간(장중 체결) 셀바스AI 112405 17790 대비 30 체결량 5 거래량 194995
# 실시간(장중 체결) 뷰노 112407 33350 대비 400 체결량 1 거래량 452387
# 실시간(장중 체결) 뷰노 112407 33300 대비 350 체결량 9 거래량 452396
# 실시간(장중 체결) 뷰노 112407 33300 대비 350 체결량 150 거래량 452546
# 실시간(장중 체결) 뷰노 112410 33300 대비 350 체결량 3 거래량 452549
# 실시간(장중 체결) 뷰노 112411 33350 대비 400 체결량 1 거래량 452550
# 실시간(장중 체결) 뷰노 112411 33300 대비 350 체결량 49 거래량 452599
# 실시간(장중 체결) 뷰노 112412 33300 대비 350 체결량 80 거래량 452679
# 실시간(장중 체결) 뷰노 112412 33300 대비 350 체결량 5 거래량 452684
# 실시간(장중 체결) 뷰노 112415 33300 대비 350 체결량 80 거래량 452764
# 실시간(장중 체결) 뷰노 112415 33350 대비 400 체결량 2 거래량 452766
# 실시간(장중 체결) 뷰노 112416 33300 대비 350 체결량 250 거래량 453016
# 실시간(장중 체결) 셀바스AI 112417 17790 대비 30 체결량 100 거래량 195095
# 실시간(장중 체결) 뷰노 112418 33350 대비 400 체결량 1 거래량 453017
# 실시간(장중 체결) 알체라 112419 10300 대비 -10 체결량 121 거래량 29963
# 실시간(장중 체결) 셀바스AI 112419 17790 대비 30 체결량 10 거래량 195105
# 실시간(장중 체결) 뷰노 112422 33300 대비 350 체결량 69 거래량 453086
# 실시간(장중 체결) 셀바스AI 112424 17790 대비 30 체결량 2 거래량 195107
# 실시간(장중 체결) 뷰노 112424 33300 대비 350 체결량 1 거래량 453087
# 실시간(장중 체결) 셀바스AI 112424 17790 대비 30 체결량 43 거래량 195150
# 실시간(장중 체결) 셀바스AI 112429 17790 대비 30 체결량 90 거래량 195240
# 실시간(장중 체결) 뷰노 112431 33300 대비 350 체결량 200 거래량 453287
# 실시간(장중 체결) 뷰노 112431 33300 대비 350 체결량 1 거래량 453288
# 실시간(장중 체결) 뷰노 112431 33300 대비 350 체결량 5 거래량 453293
# 실시간(장중 체결) 에스에너지 112435 2755 대비 10 체결량 112 거래량 32420
# 실시간(장중 체결) 에스에너지 112435 2755 대비 10 체결량 88 거래량 32508
# 실시간(장중 체결) 뷰노 112436 33250 대비 300 체결량 36 거래량 453329
# 실시간(장중 체결) 뷰노 112437 33250 대비 300 체결량 1 거래량 453330
# 실시간(장중 체결) 뷰노 112440 33300 대비 350 체결량 1 거래량 453331
# 실시간(장중 체결) 에스에너지 112441 2760 대비 15 체결량 1 거래량 32509
# 실시간(장중 체결) 셀바스AI 112443 17780 대비 20 체결량 71 거래량 195311
# 실시간(장중 체결) 뷰노 112444 33300 대비 350 체결량 89 거래량 453420
# 실시간(장중 체결) 셀바스AI 112444 17790 대비 30 체결량 100 거래량 195411
# 실시간(장중 체결) 뷰노 112448 33350 대비 400 체결량 11 거래량 453431
# 실시간(장중 체결) 뷰노 112449 33350 대비 400 체결량 221 거래량 453652
# 실시간(장중 체결) 뷰노 112451 33400 대비 450 체결량 2 거래량 453654
# 실시간(장중 체결) 셀바스AI 112453 17780 대비 20 체결량 1 거래량 195412
# 실시간(장중 체결) 뷰노 112455 33350 대비 400 체결량 5 거래량 453659
# 실시간(장중 체결) 뷰노 112457 33350 대비 400 체결량 3 거래량 453662
# 실시간(장중 체결) 뷰노 112459 33400 대비 450 체결량 2 거래량 453664
# 실시간(장중 체결) 뷰노 112503 33400 대비 450 체결량 2 거래량 453666
# 실시간(장중 체결) 뷰노 112506 33350 대비 400 체결량 26 거래량 453692
# 실시간(장중 체결) 뷰노 112506 33400 대비 450 체결량 1 거래량 453693
# 실시간(장중 체결) 뷰노 112513 33400 대비 450 체결량 2 거래량 453695
# 실시간(장중 체결) 뷰노 112513 33350 대비 400 체결량 87 거래량 453782
# 실시간(장중 체결) 셀바스AI 112514 17780 대비 20 체결량 50 거래량 195462
# 실시간(장중 체결) 셀바스AI 112515 17780 대비 20 체결량 100 거래량 195562
# 실시간(장중 체결) 뷰노 112515 33400 대비 450 체결량 10 거래량 453792
# 실시간(장중 체결) 뷰노 112516 33350 대비 400 체결량 90 거래량 453882
# 실시간(장중 체결) 뷰노 112517 33350 대비 400 체결량 7 거래량 453889
# 실시간(장중 체결) 뷰노 112519 33400 대비 450 체결량 13 거래량 453902
# 실시간(장중 체결) 셀바스AI 112524 17780 대비 20 체결량 40 거래량 195602
# 실시간(장중 체결) 셀바스AI 112525 17780 대비 20 체결량 50 거래량 195652
# 실시간(장중 체결) 뷰노 112533 33400 대비 450 체결량 1 거래량 453903
# 실시간(장중 체결) 뷰노 112539 33350 대비 400 체결량 60 거래량 453963
# 실시간(장중 체결) 뷰노 112539 33350 대비 400 체결량 60 거래량 454023
# 실시간(장중 체결) 플리토 112539 30900 대비 350 체결량 97 거래량 15316
# 실시간(장중 체결) 플리토 112539 30800 대비 250 체결량 64 거래량 15380
# 실시간(장중 체결) 뷰노 112540 33400 대비 450 체결량 1 거래량 454024
# 실시간(장중 체결) 셀바스AI 112547 17780 대비 20 체결량 20 거래량 195672
# 실시간(장중 체결) 뷰노 112550 33400 대비 450 체결량 6 거래량 454030
# 실시간(장중 체결) 알체라 112552 10300 대비 -10 체결량 20 거래량 29983
# 실시간(장중 체결) 뷰노 112552 33350 대비 400 체결량 8 거래량 454038
# 실시간(장중 체결) 알체라 112553 10290 대비 -20 체결량 34 거래량 30017
# 실시간(장중 체결) 뷰노 112554 33400 대비 450 체결량 1 거래량 454039
# 실시간(장중 체결) 뷰노 112554 33350 대비 400 체결량 190 거래량 454229
# 실시간(장중 체결) 뷰노 112554 33400 대비 450 체결량 1 거래량 454230
# 실시간(장중 체결) 뷰노 112558 33350 대비 400 체결량 10 거래량 454240
# 실시간(장중 체결) 뷰노 112558 33400 대비 450 체결량 3 거래량 454243
# 실시간(장중 체결) 뷰노 112601 33400 대비 450 체결량 523 거래량 454766
# 실시간(장중 체결) 뷰노 112607 33350 대비 400 체결량 10 거래량 454776
# 실시간(장중 체결) 뷰노 112608 33350 대비 400 체결량 4 거래량 454780
# 실시간(장중 체결) 뷰노 112609 33350 대비 400 체결량 89 거래량 454869
# 실시간(장중 체결) 셀바스AI 112616 17780 대비 20 체결량 112 거래량 195784
# 실시간(장중 체결) 뷰노 112616 33400 대비 450 체결량 3 거래량 454872
# 실시간(장중 체결) 뷰노 112616 33400 대비 450 체결량 2 거래량 454874
# 실시간(장중 체결) 알체라 112617 10290 대비 -20 체결량 2 거래량 30019
# 실시간(장중 체결) 뷰노 112620 33350 대비 400 체결량 10 거래량 454884
# 실시간(장중 체결) 뷰노 112629 33350 대비 400 체결량 438 거래량 455322
# 실시간(장중 체결) 뷰노 112629 33400 대비 450 체결량 10 거래량 455332
# 실시간(장중 체결) 뷰노 112631 33400 대비 450 체결량 2 거래량 455334
# 실시간(장중 체결) 뷰노 112632 33350 대비 400 체결량 100 거래량 455434
# 실시간(장중 체결) 뷰노 112633 33350 대비 400 체결량 3 거래량 455437
# 실시간(장중 체결) 뷰노 112634 33400 대비 450 체결량 2 거래량 455439
# 실시간(장중 체결) 셀바스AI 112640 17780 대비 20 체결량 54 거래량 195838
# 실시간(장중 체결) 뷰노 112643 33350 대비 400 체결량 1 거래량 455440
# 실시간(장중 체결) 뷰노 112643 33350 대비 400 체결량 1 거래량 455441
# 실시간(장중 체결) 뷰노 112646 33400 대비 450 체결량 2 거래량 455443
# 실시간(장중 체결) 뷰노 112646 33400 대비 450 체결량 2 거래량 455445
# 실시간(장중 체결) 뷰노 112647 33400 대비 450 체결량 100 거래량 455545
# 실시간(장중 체결) 셀바스AI 112647 17780 대비 20 체결량 158 거래량 195996
# 실시간(장중 체결) 알체라 112647 10290 대비 -20 체결량 1 거래량 30020
# 실시간(장중 체결) 뷰노 112649 33400 대비 450 체결량 1 거래량 455546
# 실시간(장중 체결) 뷰노 112650 33350 대비 400 체결량 103 거래량 455649
# 실시간(장중 체결) 뷰노 112652 33400 대비 450 체결량 8 거래량 455657
# 실시간(장중 체결) 뷰노 112654 33400 대비 450 체결량 2 거래량 455659
# 실시간(장중 체결) 뷰노 112656 33350 대비 400 체결량 20 거래량 455679
# 실시간(장중 체결) 셀바스AI 112656 17780 대비 20 체결량 357 거래량 196353
# 실시간(장중 체결) 뷰노 112656 33400 대비 450 체결량 4 거래량 455683
# 실시간(장중 체결) 뷰노 112658 33400 대비 450 체결량 2 거래량 455685
# 실시간(장중 체결) 셀바스AI 112702 17780 대비 20 체결량 90 거래량 196443
# 실시간(장중 체결) 셀바스AI 112705 17780 대비 20 체결량 7 거래량 196450
# 실시간(장중 체결) 뷰노 112706 33400 대비 450 체결량 50 거래량 455735
# 실시간(장중 체결) 뷰노 112711 33400 대비 450 체결량 11 거래량 455746
# 실시간(장중 체결) 알체라 112715 10280 대비 -30 체결량 11 거래량 30031
# 실시간(장중 체결) 뷰노 112715 33400 대비 450 체결량 11 거래량 455757
# 실시간(장중 체결) 투비소프트 112716 1085 대비 -10 체결량 1 거래량 423502
# 실시간(장중 체결) 셀바스AI 112717 17780 대비 20 체결량 1 거래량 196451
# 실시간(장중 체결) 셀바스AI 112717 17780 대비 20 체결량 10 거래량 196461
# 실시간(장중 체결) 에스에너지 112718 2760 대비 15 체결량 36 거래량 32545
# 실시간(장중 체결) 뷰노 112720 33400 대비 450 체결량 5 거래량 455762
# 실시간(장중 체결) 뷰노 112720 33400 대비 450 체결량 2 거래량 455764
# 실시간(장중 체결) 셀바스AI 112721 17780 대비 20 체결량 1 거래량 196462
# 실시간(장중 체결) 뷰노 112723 33350 대비 400 체결량 26 거래량 455790
# 실시간(장중 체결) 뷰노 112724 33400 대비 450 체결량 10 거래량 455800
# 실시간(장중 체결) 뷰노 112724 33400 대비 450 체결량 1 거래량 455801
# 실시간(장중 체결) 뷰노 112725 33350 대비 400 체결량 15 거래량 455816
# 실시간(장중 체결) 뷰노 112726 33400 대비 450 체결량 15 거래량 455831
# 실시간(장중 체결) 셀바스AI 112726 17770 대비 10 체결량 1016 거래량 197478
# 실시간(장중 체결) 뷰노 112728 33400 대비 450 체결량 1 거래량 455832
# 실시간(장중 체결) 뷰노 112730 33400 대비 450 체결량 162 거래량 455994
# 실시간(장중 체결) 뷰노 112730 33400 대비 450 체결량 100 거래량 456094
# 실시간(장중 체결) 뷰노 112730 33400 대비 450 체결량 8 거래량 456102
# 실시간(장중 체결) 뷰노 112730 33400 대비 450 체결량 120 거래량 456222
# 실시간(장중 체결) 뷰노 112732 33400 대비 450 체결량 5 거래량 456227
# 실시간(장중 체결) 뷰노 112732 33450 대비 500 체결량 40 거래량 456267
# 실시간(장중 체결) 뷰노 112732 33450 대비 500 체결량 449 거래량 456716
# 실시간(장중 체결) 뷰노 112736 33500 대비 550 체결량 1016 거래량 457732
# 실시간(장중 체결) 뷰노 112736 33500 대비 550 체결량 283 거래량 458015
# 실시간(장중 체결) 뷰노 112736 33550 대비 600 체결량 162 거래량 458177
# 실시간(장중 체결) 뷰노 112736 33550 대비 600 체결량 1224 거래량 459401
# 실시간(장중 체결) 뷰노 112737 33600 대비 650 체결량 44 거래량 459445
# 실시간(장중 체결) 뷰노 112738 33600 대비 650 체결량 100 거래량 459545
# 실시간(장중 체결) 뷰노 112748 33550 대비 600 체결량 215 거래량 459760
# 실시간(장중 체결) 뷰노 112749 33550 대비 600 체결량 46 거래량 459806
# 실시간(장중 체결) 투비소프트 112749 1085 대비 -10 체결량 1 거래량 423503
# 실시간(장중 체결) 뷰노 112750 33550 대비 600 체결량 1 거래량 459807
# 실시간(장중 체결) 뷰노 112750 33550 대비 600 체결량 3 거래량 459810
# 실시간(장중 체결) 뷰노 112750 33550 대비 600 체결량 104 거래량 459914
# 실시간(장중 체결) 에스에너지 112753 2760 대비 15 체결량 23 거래량 32568
# 실시간(장중 체결) 뷰노 112753 33550 대비 600 체결량 110 거래량 460024
# 실시간(장중 체결) 뷰노 112753 33550 대비 600 체결량 1 거래량 460025
# 실시간(장중 체결) 뷰노 112754 33550 대비 600 체결량 5 거래량 460030
# 실시간(장중 체결) 뷰노 112754 33550 대비 600 체결량 20 거래량 460050
# 실시간(장중 체결) 뷰노 112756 33550 대비 600 체결량 2 거래량 460052
# 실시간(장중 체결) 뷰노 112757 33550 대비 600 체결량 2 거래량 460054
# 실시간(장중 체결) 뷰노 112758 33550 대비 600 체결량 5 거래량 460059
# 실시간(장중 체결) 뷰노 112800 33550 대비 600 체결량 25 거래량 460084
# 실시간(장중 체결) 뷰노 112803 33550 대비 600 체결량 10 거래량 460094
# 실시간(장중 체결) 뷰노 112803 33550 대비 600 체결량 2 거래량 460096
# 실시간(장중 체결) 뷰노 112803 33550 대비 600 체결량 88 거래량 460184
# 실시간(장중 체결) 뷰노 112805 33600 대비 650 체결량 150 거래량 460334
# 실시간(장중 체결) 뷰노 112805 33600 대비 650 체결량 146 거래량 460480
# 실시간(장중 체결) 알체라 112807 10280 대비 -30 체결량 1 거래량 30032
# 실시간(장중 체결) 뷰노 112807 33600 대비 650 체결량 155 거래량 460635
# 실시간(장중 체결) 셀바스AI 112807 17770 대비 10 체결량 1 거래량 197479
# 실시간(장중 체결) 셀바스AI 112808 17770 대비 10 체결량 20 거래량 197499
# 실시간(장중 체결) 뷰노 112807 33600 대비 650 체결량 67 거래량 460702
# 실시간(장중 체결) 뷰노 112808 33550 대비 600 체결량 120 거래량 460822
# 실시간(장중 체결) 뷰노 112808 33650 대비 700 체결량 1 거래량 460823
# 실시간(장중 체결) 투비소프트 112809 1085 대비 -10 체결량 400 거래량 423903
# 실시간(장중 체결) 뷰노 112809 33650 대비 700 체결량 5 거래량 460828
# 실시간(장중 체결) 알체라 112809 10280 대비 -30 체결량 1 거래량 30033
# 실시간(장중 체결) 알체라 112811 10280 대비 -30 체결량 1 거래량 30034
# 실시간(장중 체결) 뷰노 112812 33650 대비 700 체결량 1 거래량 460829
# 실시간(장중 체결) 뷰노 112812 33650 대비 700 체결량 1 거래량 460830
# 실시간(장중 체결) 뷰노 112813 33650 대비 700 체결량 1 거래량 460831
# 실시간(장중 체결) 뷰노 112814 33650 대비 700 체결량 1 거래량 460832
# 실시간(장중 체결) 셀바스AI 112819 17770 대비 10 체결량 7 거래량 197506
# 실시간(장중 체결) 뷰노 112819 33650 대비 700 체결량 130 거래량 460962
# 실시간(장중 체결) 뷰노 112819 33550 대비 600 체결량 6 거래량 460968
# 실시간(장중 체결) 뷰노 112820 33550 대비 600 체결량 47 거래량 461015
# 실시간(장중 체결) 셀바스AI 112821 17770 대비 10 체결량 148 거래량 197654
# 실시간(장중 체결) 투비소프트 112823 1087 대비 -8 체결량 54 거래량 423957
# 실시간(장중 체결) 셀바스AI 112833 17770 대비 10 체결량 1 거래량 197655
# 실시간(장중 체결) 뷰노 112833 33650 대비 700 체결량 2 거래량 461017
# 실시간(장중 체결) 뷰노 112834 33650 대비 700 체결량 1 거래량 461018
# 실시간(장중 체결) 셀바스AI 112835 17770 대비 10 체결량 1 거래량 197656
# 실시간(장중 체결) 뷰노 112836 33600 대비 650 체결량 2 거래량 461020
# 실시간(장중 체결) 알체라 112836 10280 대비 -30 체결량 215 거래량 30249
# 실시간(장중 체결) 셀바스AI 112837 17770 대비 10 체결량 1 거래량 197657
# 실시간(장중 체결) 알체라 112837 10280 대비 -30 체결량 35 거래량 30284
# 실시간(장중 체결) 셀바스AI 112838 17770 대비 10 체결량 1 거래량 197658
# 실시간(장중 체결) 플리토 112839 30800 대비 250 체결량 56 거래량 15436
# 실시간(장중 체결) 플리토 112839 30750 대비 200 체결량 244 거래량 15680
# 실시간(장중 체결) 뷰노 112842 33600 대비 650 체결량 5 거래량 461025
# 실시간(장중 체결) 뷰노 112842 33600 대비 650 체결량 7 거래량 461032
# 실시간(장중 체결) 알체라 112842 10290 대비 -20 체결량 48 거래량 30332
# 실시간(장중 체결) 셀바스AI 112844 17770 대비 10 체결량 1 거래량 197659
# 실시간(장중 체결) 뷰노 112845 33600 대비 650 체결량 4 거래량 461036
# 실시간(장중 체결) 뷰노 112845 33600 대비 650 체결량 340 거래량 461376
# 실시간(장중 체결) 뷰노 112846 33600 대비 650 체결량 1 거래량 461377
# 실시간(장중 체결) 뷰노 112846 33600 대비 650 체결량 50 거래량 461427
# 실시간(장중 체결) 셀바스AI 112846 17770 대비 10 체결량 1 거래량 197660
# 실시간(장중 체결) 알체라 112849 10280 대비 -30 체결량 1 거래량 30333
# 실시간(장중 체결) 뷰노 112850 33600 대비 650 체결량 34 거래량 461461
# 실시간(장중 체결) 셀바스AI 112855 17780 대비 20 체결량 5 거래량 197665
# 실시간(장중 체결) 뷰노 112855 33550 대비 600 체결량 202 거래량 461663
# 실시간(장중 체결) 뷰노 112856 33550 대비 600 체결량 10 거래량 461673
# 실시간(장중 체결) 뷰노 112857 33550 대비 600 체결량 1 거래량 461674
# 실시간(장중 체결) 알체라 112900 10290 대비 -20 체결량 2 거래량 30335
# 실시간(장중 체결) 뷰노 112901 33500 대비 550 체결량 10 거래량 461684
# 실시간(장중 체결) 뷰노 112904 33550 대비 600 체결량 99 거래량 461783
# 실시간(장중 체결) 뷰노 112904 33600 대비 650 체결량 158 거래량 461941
# 실시간(장중 체결) 뷰노 112907 33550 대비 600 체결량 3 거래량 461944
# 실시간(장중 체결) 뷰노 112907 33550 대비 600 체결량 2 거래량 461946
# 실시간(장중 체결) 뷰노 112908 33600 대비 650 체결량 2 거래량 461948
# 실시간(장중 체결) 뷰노 112910 33600 대비 650 체결량 30 거래량 461978
# 실시간(장중 체결) 뷰노 112913 33600 대비 650 체결량 1 거래량 461979
# 실시간(장중 체결) 뷰노 112913 33600 대비 650 체결량 78 거래량 462057
# 실시간(장중 체결) 뷰노 112915 33600 대비 650 체결량 30 거래량 462087
# 실시간(장중 체결) 뷰노 112916 33600 대비 650 체결량 89 거래량 462176
# 실시간(장중 체결) 투비소프트 112917 1088 대비 -7 체결량 494 거래량 424451
# 실시간(장중 체결) 뷰노 112918 33600 대비 650 체결량 220 거래량 462396
# 실시간(장중 체결) 뷰노 112918 33600 대비 650 체결량 149 거래량 462545
# 실시간(장중 체결) 투비소프트 112917 1088 대비 -7 체결량 631 거래량 425082
# 실시간(장중 체결) 뷰노 112920 33600 대비 650 체결량 6 거래량 462551
# 실시간(장중 체결) 뷰노 112920 33550 대비 600 체결량 69 거래량 462620
# 실시간(장중 체결) 셀바스AI 112923 17780 대비 20 체결량 300 거래량 197965
# 실시간(장중 체결) 뷰노 112923 33600 대비 650 체결량 1 거래량 462621
# 실시간(장중 체결) 뷰노 112925 33650 대비 700 체결량 1 거래량 462622
# 실시간(장중 체결) 뷰노 112929 33600 대비 650 체결량 33 거래량 462655
# 실시간(장중 체결) 뷰노 112929 33550 대비 600 체결량 13 거래량 462668
# 실시간(장중 체결) 뷰노 112937 33650 대비 700 체결량 1 거래량 462669
# 실시간(장중 체결) 뷰노 112940 33650 대비 700 체결량 2 거래량 462671
# 실시간(장중 체결) 뷰노 112943 33650 대비 700 체결량 2 거래량 462673
# 실시간(장중 체결) 뷰노 112947 33650 대비 700 체결량 3 거래량 462676
# 실시간(장중 체결) 뷰노 112949 33650 대비 700 체결량 1 거래량 462677
# 실시간(장중 체결) 뷰노 112950 33600 대비 650 체결량 2 거래량 462679
# 실시간(장중 체결) 뷰노 112950 33650 대비 700 체결량 1 거래량 462680
# 실시간(장중 체결) 뷰노 112952 33650 대비 700 체결량 1 거래량 462681
# 실시간(장중 체결) 뷰노 112952 33650 대비 700 체결량 10 거래량 462691
# 실시간(장중 체결) 뷰노 112956 33650 대비 700 체결량 5 거래량 462696
# 실시간(장중 체결) 셀바스AI 112957 17780 대비 20 체결량 120 거래량 198085
# 실시간(장중 체결) 뷰노 112958 33650 대비 700 체결량 5 거래량 462701
# 실시간(장중 체결) 투비소프트 113000 1091 대비 -4 체결량 1 거래량 425083
# 실시간(장중 체결) 투비소프트 113000 1093 대비 -2 체결량 1 거래량 425084
# 실시간(장중 체결) 투비소프트 113000 1095 대비 0 체결량 3 거래량 425087
# 실시간(장중 체결) 셀바스AI 113003 17770 대비 10 체결량 2 거래량 198087
# 실시간(장중 체결) 뷰노 113006 33650 대비 700 체결량 30 거래량 462731
# 실시간(장중 체결) 알체라 113008 10290 대비 -20 체결량 10 거래량 30345
# 실시간(장중 체결) 뷰노 113008 33650 대비 700 체결량 20 거래량 462751
# 실시간(장중 체결) 뷰노 113011 33600 대비 650 체결량 30 거래량 462781
# 실시간(장중 체결) 뷰노 113013 33650 대비 700 체결량 2 거래량 462783
# 실시간(장중 체결) 뷰노 113013 33650 대비 700 체결량 58 거래량 462841
# 실시간(장중 체결) 뷰노 113013 33650 대비 700 체결량 12 거래량 462853
# 실시간(장중 체결) 뷰노 113013 33600 대비 650 체결량 3 거래량 462856
# 실시간(장중 체결) 뷰노 113013 33650 대비 700 체결량 185 거래량 463041
# 실시간(장중 체결) 뷰노 113013 33600 대비 650 체결량 190 거래량 463231
# 실시간(장중 체결) 뷰노 113015 33600 대비 650 체결량 251 거래량 463482
# 실시간(장중 체결) 뷰노 113015 33600 대비 650 체결량 34 거래량 463516
# 실시간(장중 체결) 셀바스AI 113021 17770 대비 10 체결량 1 거래량 198088
# 실시간(장중 체결) 뷰노 113023 33600 대비 650 체결량 1 거래량 463517
# 실시간(장중 체결) 뷰노 113023 33550 대비 600 체결량 45 거래량 463562
# 실시간(장중 체결) 뷰노 113023 33550 대비 600 체결량 103 거래량 463665
# 실시간(장중 체결) 뷰노 113025 33600 대비 650 체결량 2 거래량 463667
# 실시간(장중 체결) 뷰노 113026 33600 대비 650 체결량 2 거래량 463669
# 실시간(장중 체결) 뷰노 113030 33600 대비 650 체결량 2 거래량 463671
# 실시간(장중 체결) 뷰노 113031 33600 대비 650 체결량 5 거래량 463676
# 실시간(장중 체결) 뷰노 113031 33600 대비 650 체결량 12 거래량 463688
# 실시간(장중 체결) 뷰노 113032 33600 대비 650 체결량 1 거래량 463689
# 실시간(장중 체결) 뷰노 113039 33550 대비 600 체결량 2 거래량 463691
# 실시간(장중 체결) 셀바스AI 113042 17770 대비 10 체결량 47 거래량 198135
# 실시간(장중 체결) 알체라 113042 10290 대비 -20 체결량 50 거래량 30395
# 실시간(장중 체결) 뷰노 113046 33550 대비 600 체결량 82 거래량 463773
# 실시간(장중 체결) 뷰노 113046 33550 대비 600 체결량 67 거래량 463840
# 실시간(장중 체결) 뷰노 113047 33550 대비 600 체결량 2 거래량 463842
# 실시간(장중 체결) 뷰노 113048 33550 대비 600 체결량 8 거래량 463850
# 실시간(장중 체결) 뷰노 113048 33550 대비 600 체결량 12 거래량 463862
# 실시간(장중 체결) 뷰노 113053 33600 대비 650 체결량 16 거래량 463878
# 실시간(장중 체결) 뷰노 113056 33550 대비 600 체결량 1 거래량 463879
# 실시간(장중 체결) 뷰노 113056 33550 대비 600 체결량 7 거래량 463886
# 실시간(장중 체결) 뷰노 113056 33550 대비 600 체결량 53 거래량 463939
# 실시간(장중 체결) 뷰노 113056 33600 대비 650 체결량 2 거래량 463941
# 실시간(장중 체결) 뷰노 113100 33600 대비 650 체결량 9 거래량 463950
# 실시간(장중 체결) 뷰노 113101 33500 대비 550 체결량 49 거래량 463999
# 실시간(장중 체결) 알체라 113102 10280 대비 -30 체결량 215 거래량 30610
# 실시간(장중 체결) 알체라 113103 10270 대비 -40 체결량 37 거래량 30647
# 실시간(장중 체결) 뷰노 113104 33600 대비 650 체결량 379 거래량 464378
# 실시간(장중 체결) 셀바스AI 113107 17780 대비 20 체결량 5 거래량 198140
# 실시간(장중 체결) 셀바스AI 113109 17780 대비 20 체결량 5 거래량 198145
# 실시간(장중 체결) 뷰노 113115 33600 대비 650 체결량 1 거래량 464379
# 실시간(장중 체결) 셀바스AI 113117 17770 대비 10 체결량 20 거래량 198165
# 실시간(장중 체결) 뷰노 113120 33550 대비 600 체결량 4 거래량 464383
# 실시간(장중 체결) 셀바스AI 113121 17770 대비 10 체결량 60 거래량 198225
# 실시간(장중 체결) 알체라 113122 10270 대비 -40 체결량 50 거래량 30697
# 실시간(장중 체결) 알체라 113123 10270 대비 -40 체결량 35 거래량 30732
# 실시간(장중 체결) 뷰노 113127 33500 대비 550 체결량 1 거래량 464384
# 실시간(장중 체결) 뷰노 113132 33550 대비 600 체결량 33 거래량 464417
# 실시간(장중 체결) 뷰노 113132 33600 대비 650 체결량 67 거래량 464484
# 실시간(장중 체결) 셀바스AI 113135 17770 대비 10 체결량 4 거래량 198229
# 실시간(장중 체결) 투비소프트 113137 1097 대비 2 체결량 42 거래량 425129
# 실시간(장중 체결) 투비소프트 113137 1099 대비 4 체결량 1 거래량 425130
# 실시간(장중 체결) 투비소프트 113137 1101 대비 6 체결량 1 거래량 425131
# 실시간(장중 체결) 투비소프트 113137 1102 대비 7 체결량 440 거래량 425571
# 실시간(장중 체결) 투비소프트 113137 1102 대비 7 체결량 18 거래량 425589
# 실시간(장중 체결) 투비소프트 113137 1102 대비 7 체결량 1807 거래량 427396
# 실시간(장중 체결) 뷰노 113137 33550 대비 600 체결량 2 거래량 464486
# 실시간(장중 체결) 뷰노 113139 33550 대비 600 체결량 12 거래량 464498
# 실시간(장중 체결) 뷰노 113142 33550 대비 600 체결량 3 거래량 464501
# 실시간(장중 체결) 뷰노 113145 33550 대비 600 체결량 5 거래량 464506
# 실시간(장중 체결) 뷰노 113147 33550 대비 600 체결량 110 거래량 464616
# 실시간(장중 체결) 뷰노 113149 33550 대비 600 체결량 5 거래량 464621
# 실시간(장중 체결) 알체라 113149 10280 대비 -30 체결량 2 거래량 30734
# 실시간(장중 체결) 알체라 113149 10280 대비 -30 체결량 3 거래량 30737
# 실시간(장중 체결) 뷰노 113152 33500 대비 550 체결량 787 거래량 465408
# 실시간(장중 체결) 뷰노 113157 33500 대비 550 체결량 2 거래량 465410
# 실시간(장중 체결) 뷰노 113158 33500 대비 550 체결량 2 거래량 465412
# 실시간(장중 체결) 뷰노 113158 33500 대비 550 체결량 2 거래량 465414
# 실시간(장중 체결) 뷰노 113200 33500 대비 550 체결량 1 거래량 465415
# 실시간(장중 체결) 뷰노 113202 33500 대비 550 체결량 7 거래량 465422
# 실시간(장중 체결) 뷰노 113207 33500 대비 550 체결량 3 거래량 465425
# 실시간(장중 체결) 뷰노 113209 33450 대비 500 체결량 150 거래량 465575
# 실시간(장중 체결) 뷰노 113212 33500 대비 550 체결량 1 거래량 465576
# 실시간(장중 체결) 뷰노 113213 33450 대비 500 체결량 3 거래량 465579
# 실시간(장중 체결) 알체라 113214 10280 대비 -30 체결량 10 거래량 30747
# 실시간(장중 체결) 알체라 113215 10280 대비 -30 체결량 13 거래량 30760
# 실시간(장중 체결) 뷰노 113216 33500 대비 550 체결량 1 거래량 465580
# 실시간(장중 체결) 셀바스AI 113216 17770 대비 10 체결량 10 거래량 198239
# 실시간(장중 체결) 뷰노 113219 33500 대비 550 체결량 2 거래량 465582
# 실시간(장중 체결) 알체라 113220 10270 대비 -40 체결량 1 거래량 30761
# 실시간(장중 체결) 뷰노 113220 33450 대비 500 체결량 1 거래량 465583
# 실시간(장중 체결) 알체라 113222 10280 대비 -30 체결량 4 거래량 30765
# 실시간(장중 체결) 셀바스AI 113223 17770 대비 10 체결량 30 거래량 198269
# 실시간(장중 체결) 셀바스AI 113223 17780 대비 20 체결량 34 거래량 198303
# 실시간(장중 체결) 뷰노 113226 33450 대비 500 체결량 201 거래량 465784
# 실시간(장중 체결) 뷰노 113227 33450 대비 500 체결량 7 거래량 465791
# 실시간(장중 체결) 뷰노 113228 33450 대비 500 체결량 2 거래량 465793
# 실시간(장중 체결) 뷰노 113228 33450 대비 500 체결량 50 거래량 465843
# 실시간(장중 체결) 뷰노 113231 33450 대비 500 체결량 1 거래량 465844
# 실시간(장중 체결) 셀바스AI 113232 17780 대비 20 체결량 50 거래량 198353
# 실시간(장중 체결) 셀바스AI 113233 17780 대비 20 체결량 56 거래량 198409
# 실시간(장중 체결) 에스에너지 113233 2750 대비 5 체결량 1 거래량 32569
# 실시간(장중 체결) 셀바스AI 113233 17780 대비 20 체결량 1 거래량 198410
# 실시간(장중 체결) 뷰노 113233 33450 대비 500 체결량 2 거래량 465846
# 실시간(장중 체결) 뷰노 113235 33400 대비 450 체결량 12 거래량 465858
# 실시간(장중 체결) 셀바스AI 113239 17770 대비 10 체결량 25 거래량 198435
# 실시간(장중 체결) 뷰노 113240 33450 대비 500 체결량 1 거래량 465859
# 실시간(장중 체결) 뷰노 113240 33450 대비 500 체결량 3 거래량 465862
# 실시간(장중 체결) 뷰노 113242 33450 대비 500 체결량 1 거래량 465863
# 실시간(장중 체결) 뷰노 113243 33400 대비 450 체결량 1 거래량 465864
# 실시간(장중 체결) 뷰노 113245 33400 대비 450 체결량 2 거래량 465866
# 실시간(장중 체결) 뷰노 113247 33400 대비 450 체결량 5 거래량 465871
# 실시간(장중 체결) 뷰노 113247 33400 대비 450 체결량 61 거래량 465932
# 실시간(장중 체결) 뷰노 113248 33450 대비 500 체결량 1 거래량 465933
# 실시간(장중 체결) 뷰노 113250 33450 대비 500 체결량 7 거래량 465940
# 실시간(장중 체결) 셀바스AI 113252 17770 대비 10 체결량 2 거래량 198437
# 실시간(장중 체결) 뷰노 113253 33450 대비 500 체결량 13 거래량 465953
# 실시간(장중 체결) 뷰노 113255 33450 대비 500 체결량 1 거래량 465954
# 실시간(장중 체결) 셀바스AI 113255 17770 대비 10 체결량 50 거래량 198487
# 실시간(장중 체결) 뷰노 113256 33400 대비 450 체결량 100 거래량 466054
# 실시간(장중 체결) 뷰노 113257 33400 대비 450 체결량 5 거래량 466059
# 실시간(장중 체결) 뷰노 113258 33400 대비 450 체결량 5 거래량 466064
# 실시간(장중 체결) 뷰노 113300 33400 대비 450 체결량 34 거래량 466098
# 실시간(장중 체결) 셀바스AI 113301 17770 대비 10 체결량 500 거래량 198987
# 실시간(장중 체결) 뷰노 113304 33450 대비 500 체결량 7 거래량 466105
# 실시간(장중 체결) 셀바스AI 113306 17780 대비 20 체결량 30 거래량 199017
# 실시간(장중 체결) 셀바스AI 113310 17770 대비 10 체결량 21 거래량 199038
# 실시간(장중 체결) 뷰노 113311 33450 대비 500 체결량 3 거래량 466108
# 실시간(장중 체결) 뷰노 113312 33450 대비 500 체결량 3 거래량 466111
# 실시간(장중 체결) 뷰노 113314 33400 대비 450 체결량 79 거래량 466190
# 실시간(장중 체결) 뷰노 113314 33450 대비 500 체결량 1 거래량 466191
# 실시간(장중 체결) 뷰노 113317 33400 대비 450 체결량 41 거래량 466232
# 실시간(장중 체결) 뷰노 113318 33400 대비 450 체결량 100 거래량 466332
# 실시간(장중 체결) 알체라 113319 10280 대비 -30 체결량 4 거래량 30769
# 실시간(장중 체결) 뷰노 113320 33400 대비 450 체결량 50 거래량 466382
# 실시간(장중 체결) 셀바스AI 113321 17770 대비 10 체결량 8 거래량 199046
# 실시간(장중 체결) 뷰노 113323 33450 대비 500 체결량 25 거래량 466407
# 실시간(장중 체결) 뷰노 113323 33400 대비 450 체결량 50 거래량 466457
# 실시간(장중 체결) 뷰노 113324 33400 대비 450 체결량 10 거래량 466467
# 실시간(장중 체결) 뷰노 113327 33400 대비 450 체결량 100 거래량 466567
# 실시간(장중 체결) 셀바스AI 113327 17770 대비 10 체결량 16 거래량 199062
# 실시간(장중 체결) 뷰노 113329 33400 대비 450 체결량 4 거래량 466571
# 실시간(장중 체결) 뷰노 113331 33400 대비 450 체결량 80 거래량 466651
# 실시간(장중 체결) 셀바스AI 113333 17770 대비 10 체결량 1 거래량 199063
# 실시간(장중 체결) 셀바스AI 113334 17770 대비 10 체결량 1 거래량 199064
# 실시간(장중 체결) 셀바스AI 113335 17760 대비 0 체결량 70 거래량 199134
# 실시간(장중 체결) 에스에너지 113335 2755 대비 10 체결량 1 거래량 32570
# 실시간(장중 체결) 셀바스AI 113337 17760 대비 0 체결량 100 거래량 199234
# 실시간(장중 체결) 뷰노 113338 33350 대비 400 체결량 667 거래량 467318
# 실시간(장중 체결) 뷰노 113338 33350 대비 400 체결량 20 거래량 467363
# 실시간(장중 체결) 뷰노 113342 33350 대비 400 체결량 250 거래량 467613
# 실시간(장중 체결) 뷰노 113343 33350 대비 400 체결량 139 거래량 467752
# 실시간(장중 체결) 뷰노 113343 33350 대비 400 체결량 3 거래량 467755
# 실시간(장중 체결) 셀바스AI 113344 17770 대비 10 체결량 2 거래량 199236
# 실시간(장중 체결) 에스에너지 113344 2755 대비 10 체결량 5 거래량 32575
# 실시간(장중 체결) 뷰노 113346 33350 대비 400 체결량 30 거래량 467785
# 실시간(장중 체결) 뷰노 113349 33350 대비 400 체결량 45 거래량 467830
# 실시간(장중 체결) 뷰노 113354 33350 대비 400 체결량 16 거래량 467846
# 실시간(장중 체결) 뷰노 113354 33350 대비 400 체결량 41 거래량 467887
# 실시간(장중 체결) 뷰노 113354 33350 대비 400 체결량 8 거래량 467895
# 실시간(장중 체결) 뷰노 113356 33350 대비 400 체결량 10 거래량 467905
# 실시간(장중 체결) 뷰노 113357 33300 대비 350 체결량 51 거래량 467956
# 실시간(장중 체결) 셀바스AI 113359 17770 대비 10 체결량 20 거래량 199256
# 실시간(장중 체결) 뷰노 113400 33300 대비 350 체결량 13 거래량 467969
# 실시간(장중 체결) 뷰노 113401 33300 대비 350 체결량 138 거래량 468107
# 실시간(장중 체결) 뷰노 113401 33300 대비 350 체결량 85 거래량 468192
# 실시간(장중 체결) 뷰노 113404 33300 대비 350 체결량 18 거래량 468210
# 실시간(장중 체결) 뷰노 113404 33300 대비 350 체결량 53 거래량 468263
# 실시간(장중 체결) 셀바스AI 113404 17770 대비 10 체결량 12 거래량 199268
# 실시간(장중 체결) 알체라 113405 10280 대비 -30 체결량 7 거래량 30776
# 실시간(장중 체결) 뷰노 113406 33350 대비 400 체결량 7 거래량 468270
# 실시간(장중 체결) 뷰노 113407 33300 대비 350 체결량 268 거래량 468538
# 실시간(장중 체결) 뷰노 113408 33300 대비 350 체결량 1 거래량 468539
# 실시간(장중 체결) 알체라 113410 10280 대비 -30 체결량 365 거래량 31141
# 실시간(장중 체결) 뷰노 113417 33250 대비 300 체결량 45 거래량 468584
# 실시간(장중 체결) 뷰노 113417 33250 대비 300 체결량 100 거래량 468684
# 실시간(장중 체결) 뷰노 113417 33250 대비 300 체결량 17 거래량 468701
# 실시간(장중 체결) 뷰노 113419 33250 대비 300 체결량 1 거래량 468702
# 실시간(장중 체결) 셀바스AI 113421 17780 대비 20 체결량 1 거래량 199269
# 실시간(장중 체결) 알체라 113422 10280 대비 -30 체결량 180 거래량 31321
# 실시간(장중 체결) 뷰노 113423 33250 대비 300 체결량 23 거래량 468725
# 실시간(장중 체결) 뷰노 113423 33250 대비 300 체결량 100 거래량 468825
# 실시간(장중 체결) 뷰노 113424 33250 대비 300 체결량 104 거래량 468929
# 실시간(장중 체결) 뷰노 113424 33250 대비 300 체결량 38 거래량 468967
# 실시간(장중 체결) 뷰노 113425 33250 대비 300 체결량 15 거래량 468982
# 실시간(장중 체결) 뷰노 113425 33250 대비 300 체결량 5 거래량 468987
# 실시간(장중 체결) 뷰노 113425 33250 대비 300 체결량 3 거래량 468990
# 실시간(장중 체결) 뷰노 113426 33250 대비 300 체결량 46 거래량 469036
# 실시간(장중 체결) 뷰노 113426 33250 대비 300 체결량 64 거래량 469100
# 실시간(장중 체결) 뷰노 113427 33200 대비 250 체결량 100 거래량 469200
# 실시간(장중 체결) 뷰노 113427 33200 대비 250 체결량 11 거래량 469211
# 실시간(장중 체결) 뷰노 113430 33250 대비 300 체결량 3 거래량 469214
# 실시간(장중 체결) 뷰노 113431 33200 대비 250 체결량 1208 거래량 470422
# 실시간(장중 체결) 뷰노 113431 33150 대비 200 체결량 1268 거래량 471690
# 실시간(장중 체결) 뷰노 113431 33100 대비 150 체결량 40 거래량 471730
# 실시간(장중 체결) 뷰노 113431 33100 대비 150 체결량 57 거래량 471787
# 실시간(장중 체결) 뷰노 113431 33100 대비 150 체결량 100 거래량 471887
# 실시간(장중 체결) 뷰노 113431 33100 대비 150 체결량 41 거래량 471969
# 실시간(장중 체결) 뷰노 113432 33150 대비 200 체결량 2 거래량 471971
# 실시간(장중 체결) 뷰노 113432 33100 대비 150 체결량 2 거래량 471973
# 실시간(장중 체결) 뷰노 113434 33150 대비 200 체결량 1 거래량 471974
# 실시간(장중 체결) 셀바스AI 113434 17780 대비 20 체결량 1 거래량 199270
# 실시간(장중 체결) 뷰노 113435 33100 대비 150 체결량 22 거래량 471996
# 실시간(장중 체결) 뷰노 113435 33100 대비 150 체결량 22 거래량 472018
# 실시간(장중 체결) 뷰노 113436 33150 대비 200 체결량 50 거래량 472068
# 실시간(장중 체결) 뷰노 113437 33100 대비 150 체결량 58 거래량 472126
# 실시간(장중 체결) 뷰노 113438 33100 대비 150 체결량 287 거래량 472413
# 실시간(장중 체결) 뷰노 113441 33050 대비 100 체결량 2 거래량 472415
# 실시간(장중 체결) 뷰노 113441 33050 대비 100 체결량 2 거래량 472417
# 실시간(장중 체결) 뷰노 113441 33050 대비 100 체결량 259 거래량 472676
# 실시간(장중 체결) 뷰노 113442 33100 대비 150 체결량 3 거래량 472679
# 실시간(장중 체결) 뷰노 113442 33050 대비 100 체결량 260 거래량 472939
# 실시간(장중 체결) 셀바스AI 113445 17780 대비 20 체결량 211 거래량 199481
# 실시간(장중 체결) 셀바스AI 113446 17780 대비 20 체결량 1 거래량 199482
# 실시간(장중 체결) 뷰노 113448 33050 대비 100 체결량 14 거래량 472953
# 실시간(장중 체결) 뷰노 113449 33050 대비 100 체결량 100 거래량 473053
# 실시간(장중 체결) 뷰노 113449 33100 대비 150 체결량 3 거래량 473056
# 실시간(장중 체결) 뷰노 113449 33100 대비 150 체결량 2 거래량 473058
# 실시간(장중 체결) 셀바스AI 113450 17780 대비 20 체결량 1 거래량 199483
# 실시간(장중 체결) 셀바스AI 113452 17780 대비 20 체결량 30 거래량 199513
# 실시간(장중 체결) 뷰노 113452 33050 대비 100 체결량 1 거래량 473059
# 실시간(장중 체결) 셀바스AI 113455 17780 대비 20 체결량 13 거래량 199526
# 실시간(장중 체결) 셀바스AI 113456 17780 대비 20 체결량 100 거래량 199626
# 실시간(장중 체결) 뷰노 113456 33100 대비 150 체결량 1 거래량 473060
# 실시간(장중 체결) 뷰노 113456 33050 대비 100 체결량 2 거래량 473062
# 실시간(장중 체결) 셀바스AI 113457 17780 대비 20 체결량 1 거래량 199627
# 실시간(장중 체결) 플리토 113459 30800 대비 250 체결량 2 거래량 15682
# 실시간(장중 체결) 플리토 113459 30750 대비 200 체결량 48 거래량 15730
# 실시간(장중 체결) 셀바스AI 113501 17770 대비 10 체결량 55 거래량 199682
# 실시간(장중 체결) 셀바스AI 113502 17780 대비 20 체결량 171 거래량 199853
# 실시간(장중 체결) 셀바스AI 113503 17780 대비 20 체결량 100 거래량 199953
# 실시간(장중 체결) 뷰노 113506 33100 대비 150 체결량 1 거래량 473063
# 실시간(장중 체결) 뷰노 113507 33100 대비 150 체결량 2 거래량 473065
# 실시간(장중 체결) 뷰노 113508 33100 대비 150 체결량 8 거래량 473073
# 실시간(장중 체결) 뷰노 113516 33100 대비 150 체결량 2 거래량 473075
# 실시간(장중 체결) 뷰노 113518 33100 대비 150 체결량 6 거래량 473081
# 실시간(장중 체결) 뷰노 113519 33100 대비 150 체결량 1 거래량 473082
# 실시간(장중 체결) 알체라 113520 10280 대비 -30 체결량 48 거래량 31369
# 실시간(장중 체결) 뷰노 113522 33100 대비 150 체결량 1 거래량 473083
# 실시간(장중 체결) 셀바스AI 113525 17780 대비 20 체결량 1 거래량 199954
# 실시간(장중 체결) 셀바스AI 113525 17780 대비 20 체결량 6 거래량 199960
# 실시간(장중 체결) 뷰노 113525 33100 대비 150 체결량 50 거래량 473133
# 실시간(장중 체결) 알체라 113527 10290 대비 -20 체결량 20 거래량 31389
# 실시간(장중 체결) 뷰노 113528 33050 대비 100 체결량 2 거래량 473135
# 실시간(장중 체결) 뷰노 113528 33100 대비 150 체결량 1 거래량 473136
# 실시간(장중 체결) 뷰노 113528 33100 대비 150 체결량 5 거래량 473141
# 실시간(장중 체결) 뷰노 113530 33100 대비 150 체결량 6 거래량 473147
# 실시간(장중 체결) 뷰노 113530 33100 대비 150 체결량 72 거래량 473219
# 실시간(장중 체결) 셀바스AI 113531 17780 대비 20 체결량 30 거래량 199990
# 실시간(장중 체결) 뷰노 113531 33100 대비 150 체결량 5 거래량 473224
# 실시간(장중 체결) 뷰노 113531 33100 대비 150 체결량 2 거래량 473226
# 실시간(장중 체결) 뷰노 113531 33150 대비 200 체결량 1 거래량 473227
# 실시간(장중 체결) 셀바스AI 113531 17770 대비 10 체결량 163 거래량 200153
# 실시간(장중 체결) 뷰노 113532 33100 대비 150 체결량 7 거래량 473234
# 실시간(장중 체결) 뷰노 113532 33100 대비 150 체결량 2 거래량 473236
# 실시간(장중 체결) 뷰노 113532 33100 대비 150 체결량 1 거래량 473237
# 실시간(장중 체결) 뷰노 113533 33100 대비 150 체결량 59 거래량 473296
# 실시간(장중 체결) 알체라 113533 10290 대비 -20 체결량 1036 거래량 32425
# 실시간(장중 체결) 뷰노 113533 33150 대비 200 체결량 2 거래량 473298
# 실시간(장중 체결) 뷰노 113535 33100 대비 150 체결량 62 거래량 473360
# 실시간(장중 체결) 뷰노 113535 33050 대비 100 체결량 100 거래량 473460
# 실시간(장중 체결) 뷰노 113536 33100 대비 150 체결량 27 거래량 473487
# 실시간(장중 체결) 뷰노 113537 33100 대비 150 체결량 10 거래량 473497
# 실시간(장중 체결) 뷰노 113537 33050 대비 100 체결량 55 거래량 473552
# 실시간(장중 체결) 셀바스AI 113539 17780 대비 20 체결량 50 거래량 200203
# 실시간(장중 체결) 뷰노 113540 33100 대비 150 체결량 25 거래량 473577
# 실시간(장중 체결) 뷰노 113540 33100 대비 150 체결량 15 거래량 473592
# 실시간(장중 체결) 뷰노 113540 33050 대비 100 체결량 35 거래량 473627
# 실시간(장중 체결) 뷰노 113542 33150 대비 200 체결량 2 거래량 473629
# 실시간(장중 체결) 뷰노 113542 33050 대비 100 체결량 20 거래량 473649
# 실시간(장중 체결) 뷰노 113544 33050 대비 100 체결량 50 거래량 473699
# 실시간(장중 체결) 뷰노 113546 33150 대비 200 체결량 2 거래량 473701
# 실시간(장중 체결) 셀바스AI 113550 17780 대비 20 체결량 30 거래량 200233
# 실시간(장중 체결) 뷰노 113553 33100 대비 150 체결량 1 거래량 473702
# 실시간(장중 체결) 뷰노 113555 33100 대비 150 체결량 2 거래량 473704
# 실시간(장중 체결) 뷰노 113559 33150 대비 200 체결량 2 거래량 473706
# 실시간(장중 체결) 셀바스AI 113606 17780 대비 20 체결량 10 거래량 200243
# 실시간(장중 체결) 뷰노 113607 33100 대비 150 체결량 2 거래량 473708
# 실시간(장중 체결) 뷰노 113607 33150 대비 200 체결량 2 거래량 473710
# 실시간(장중 체결) 알체라 113610 10300 대비 -10 체결량 50 거래량 32475
# 실시간(장중 체결) 뷰노 113610 33150 대비 200 체결량 4 거래량 473714
# 실시간(장중 체결) 뷰노 113610 33150 대비 200 체결량 67 거래량 473781
# 실시간(장중 체결) 뷰노 113612 33150 대비 200 체결량 1 거래량 473782
# 실시간(장중 체결) 뷰노 113612 33150 대비 200 체결량 499 거래량 474281
# 실시간(장중 체결) 뷰노 113614 33150 대비 200 체결량 20 거래량 474301
# 실시간(장중 체결) 뷰노 113615 33150 대비 200 체결량 2 거래량 474303
# 실시간(장중 체결) 뷰노 113617 33200 대비 250 체결량 2 거래량 474305
# 실시간(장중 체결) 뷰노 113619 33150 대비 200 체결량 6 거래량 474311
# 실시간(장중 체결) 뷰노 113619 33100 대비 150 체결량 74 거래량 474385
# 실시간(장중 체결) 알체라 113629 10300 대비 -10 체결량 30 거래량 32505
# 실시간(장중 체결) 뷰노 113629 33200 대비 250 체결량 21 거래량 474406
# 실시간(장중 체결) 알체라 113631 10300 대비 -10 체결량 100 거래량 32605
# 실시간(장중 체결) 뷰노 113639 33150 대비 200 체결량 10 거래량 474416
# 실시간(장중 체결) 뷰노 113639 33100 대비 150 체결량 20 거래량 474436
# 실시간(장중 체결) 셀바스AI 113645 17770 대비 10 체결량 210 거래량 200453
# 실시간(장중 체결) 뷰노 113646 33150 대비 200 체결량 168 거래량 474604
# 실시간(장중 체결) 뷰노 113646 33150 대비 200 체결량 125 거래량 474729
# 실시간(장중 체결) 뷰노 113649 33200 대비 250 체결량 129 거래량 474858
# 실시간(장중 체결) 뷰노 113649 33200 대비 250 체결량 22 거래량 474880
# 실시간(장중 체결) 뷰노 113650 33150 대비 200 체결량 24 거래량 474904
# 실시간(장중 체결) 셀바스AI 113650 17770 대비 10 체결량 100 거래량 200553
# 실시간(장중 체결) 투비소프트 113653 1101 대비 6 체결량 12 거래량 427408
# 실시간(장중 체결) 뷰노 113657 33200 대비 250 체결량 1 거래량 474905
# 실시간(장중 체결) 셀바스AI 113700 17770 대비 10 체결량 40 거래량 200593
# 실시간(장중 체결) 뷰노 113700 33200 대비 250 체결량 10 거래량 474915
# 실시간(장중 체결) 뷰노 113706 33200 대비 250 체결량 2 거래량 474917
# 실시간(장중 체결) 뷰노 113706 33200 대비 250 체결량 11 거래량 474928
# 실시간(장중 체결) 뷰노 113706 33250 대비 300 체결량 2 거래량 474930
# 실시간(장중 체결) 뷰노 113706 33250 대비 300 체결량 46 거래량 474976
# 실시간(장중 체결) 알체라 113707 10300 대비 -10 체결량 1 거래량 32606
# 실시간(장중 체결) 셀바스AI 113708 17770 대비 10 체결량 1 거래량 200594
# 실시간(장중 체결) 뷰노 113712 33250 대비 300 체결량 10 거래량 474986
# 실시간(장중 체결) 셀바스AI 113715 17770 대비 10 체결량 118 거래량 200712
# 실시간(장중 체결) 셀바스AI 113719 17770 대비 10 체결량 28 거래량 200740
# 실시간(장중 체결) 셀바스AI 113722 17770 대비 10 체결량 5 거래량 200745
# 실시간(장중 체결) 셀바스AI 113723 17770 대비 10 체결량 2 거래량 200747
# 실시간(장중 체결) 뷰노 113723 33200 대비 250 체결량 1 거래량 474987
# 실시간(장중 체결) 뷰노 113723 33150 대비 200 체결량 29 거래량 475016
# 실시간(장중 체결) 셀바스AI 113725 17770 대비 10 체결량 40 거래량 200787
# 실시간(장중 체결) 뷰노 113725 33300 대비 350 체결량 1 거래량 475017
# 실시간(장중 체결) 뷰노 113726 33250 대비 300 체결량 10 거래량 475027
# 실시간(장중 체결) 뷰노 113726 33200 대비 250 체결량 7 거래량 475034
# 실시간(장중 체결) 뷰노 113737 33250 대비 300 체결량 1 거래량 475035
# 실시간(장중 체결) 에스에너지 113738 2755 대비 10 체결량 10 거래량 32585
# 실시간(장중 체결) 셀바스AI 113739 17780 대비 20 체결량 8 거래량 200795
# 실시간(장중 체결) 뷰노 113740 33250 대비 300 체결량 2 거래량 475037
# 실시간(장중 체결) 뷰노 113740 33300 대비 350 체결량 2 거래량 475039
# 실시간(장중 체결) 셀바스AI 113744 17770 대비 10 체결량 7 거래량 200802
# 실시간(장중 체결) 뷰노 113746 33300 대비 350 체결량 3 거래량 475042
# 실시간(장중 체결) 알체라 113747 10300 대비 -10 체결량 1 거래량 32607
# 실시간(장중 체결) 플리토 113749 30800 대비 250 체결량 1 거래량 15731
# 실시간(장중 체결) 셀바스AI 113755 17780 대비 20 체결량 61 거래량 200863
# 실시간(장중 체결) 뷰노 113757 33300 대비 350 체결량 1 거래량 475043
# 실시간(장중 체결) 뷰노 113757 33250 대비 300 체결량 10 거래량 475053
# 실시간(장중 체결) 셀바스AI 113801 17770 대비 10 체결량 1100 거래량 201963
# 실시간(장중 체결) 셀바스AI 113801 17780 대비 20 체결량 235 거래량 202198
# 실시간(장중 체결) 뷰노 113803 33200 대비 250 체결량 305 거래량 475358
# 실시간(장중 체결) 뷰노 113803 33150 대비 200 체결량 200 거래량 475558
# 실시간(장중 체결) 뷰노 113803 33100 대비 150 체결량 1006 거래량 476564
# 실시간(장중 체결) 뷰노 113803 33100 대비 150 체결량 341 거래량 476905
# 실시간(장중 체결) 뷰노 113804 33100 대비 150 체결량 51 거래량 476956
# 실시간(장중 체결) 뷰노 113805 33250 대비 300 체결량 1 거래량 476957
# 실시간(장중 체결) 셀바스AI 113805 17780 대비 20 체결량 229 거래량 202427
# 실시간(장중 체결) 뷰노 113806 33250 대비 300 체결량 1 거래량 476958
# 실시간(장중 체결) 뷰노 113811 33250 대비 300 체결량 2 거래량 476960
# 실시간(장중 체결) 셀바스AI 113811 17780 대비 20 체결량 96 거래량 202523
# 실시간(장중 체결) 플리토 113812 30800 대비 250 체결량 1 거래량 15732
# 실시간(장중 체결) 셀바스AI 113812 17770 대비 10 체결량 9 거래량 202532
# 실시간(장중 체결) 뷰노 113814 33250 대비 300 체결량 4 거래량 476964
# 실시간(장중 체결) 셀바스AI 113817 17770 대비 10 체결량 50 거래량 202582
# 실시간(장중 체결) 뷰노 113819 33150 대비 200 체결량 2 거래량 476966
# 실시간(장중 체결) 알체라 113819 10300 대비 -10 체결량 1 거래량 32608
# 실시간(장중 체결) 알체라 113820 10300 대비 -10 체결량 8 거래량 32616
# 실시간(장중 체결) 뷰노 113822 33150 대비 200 체결량 2 거래량 476968
# 실시간(장중 체결) 뷰노 113826 33150 대비 200 체결량 3 거래량 476971
# 실시간(장중 체결) 뷰노 113827 33100 대비 150 체결량 16 거래량 476987
# 실시간(장중 체결) 뷰노 113827 33050 대비 100 체결량 21 거래량 477008
# 실시간(장중 체결) 셀바스AI 113833 17770 대비 10 체결량 74 거래량 202656
# 실시간(장중 체결) 셀바스AI 113833 17760 대비 0 체결량 726 거래량 203382
# 실시간(장중 체결) 뷰노 113834 33100 대비 150 체결량 10 거래량 477018
# 실시간(장중 체결) 뷰노 113834 33050 대비 100 체결량 190 거래량 477208
# 실시간(장중 체결) 뷰노 113843 33100 대비 150 체결량 172 거래량 477380
# 실시간(장중 체결) 뷰노 113846 33150 대비 200 체결량 3 거래량 477383
# 실시간(장중 체결) 뷰노 113849 33100 대비 150 체결량 10 거래량 477393
# 실시간(장중 체결) 뷰노 113849 33100 대비 150 체결량 10 거래량 477403
# 실시간(장중 체결) 플리토 113850 30750 대비 200 체결량 128 거래량 15860
# 실시간(장중 체결) 뷰노 113852 33250 대비 300 체결량 5 거래량 477408
# 실시간(장중 체결) 셀바스AI 113904 17760 대비 0 체결량 50 거래량 203432
# 실시간(장중 체결) 알체라 113907 10300 대비 -10 체결량 71 거래량 32687
# 실시간(장중 체결) 뷰노 113907 33200 대비 250 체결량 1 거래량 477409
# 실시간(장중 체결) 셀바스AI 113908 17770 대비 10 체결량 10 거래량 203442
# 실시간(장중 체결) 뷰노 113910 33200 대비 250 체결량 3 거래량 477412
# 실시간(장중 체결) 뷰노 113910 33150 대비 200 체결량 1 거래량 477413
# 실시간(장중 체결) 뷰노 113915 33150 대비 200 체결량 15 거래량 477428
# 실시간(장중 체결) 뷰노 113916 33200 대비 250 체결량 11 거래량 477439
# 실시간(장중 체결) 뷰노 113916 33200 대비 250 체결량 2 거래량 477441
# 실시간(장중 체결) 셀바스AI 113918 17780 대비 20 체결량 65 거래량 203507
# 실시간(장중 체결) 뷰노 113918 33200 대비 250 체결량 1 거래량 477442
# 실시간(장중 체결) 뷰노 113920 33200 대비 250 체결량 2 거래량 477444
# 실시간(장중 체결) 셀바스AI 113922 17770 대비 10 체결량 100 거래량 203607
# 실시간(장중 체결) 뷰노 113924 33200 대비 250 체결량 34 거래량 477478
# 실시간(장중 체결) 뷰노 113924 33200 대비 250 체결량 10 거래량 477488
# 실시간(장중 체결) 뷰노 113925 33250 대비 300 체결량 1 거래량 477489
# 실시간(장중 체결) 플리토 113926 30750 대비 200 체결량 1 거래량 15861
# 실시간(장중 체결) 플리토 113928 30750 대비 200 체결량 1 거래량 15862
# 실시간(장중 체결) 뷰노 113928 33200 대비 250 체결량 3 거래량 477492
# 실시간(장중 체결) 뷰노 113929 33200 대비 250 체결량 10 거래량 477502
# 실시간(장중 체결) 셀바스AI 113932 17770 대비 10 체결량 16 거래량 203623
# 실시간(장중 체결) 셀바스AI 113934 17760 대비 0 체결량 100 거래량 203723
# 실시간(장중 체결) 셀바스AI 113935 17760 대비 0 체결량 50 거래량 203773
# 실시간(장중 체결) 뷰노 113939 33250 대비 300 체결량 1 거래량 477503
# 실시간(장중 체결) 투비소프트 113941 1091 대비 -4 체결량 3 거래량 427411
# 실시간(장중 체결) 뷰노 113943 33250 대비 300 체결량 2 거래량 477505
# 실시간(장중 체결) 뷰노 113943 33250 대비 300 체결량 1 거래량 477506
# 실시간(장중 체결) 셀바스AI 113946 17760 대비 0 체결량 50 거래량 203823
# 실시간(장중 체결) 알체라 113946 10300 대비 -10 체결량 1 거래량 32688
# 실시간(장중 체결) 뷰노 113951 33250 대비 300 체결량 2 거래량 477508
# 실시간(장중 체결) 뷰노 113955 33250 대비 300 체결량 30 거래량 477538
# 실시간(장중 체결) 뷰노 114003 33250 대비 300 체결량 1 거래량 477539
# 실시간(장중 체결) 셀바스AI 114004 17760 대비 0 체결량 1 거래량 203824
# 실시간(장중 체결) 투비소프트 114005 1095 대비 0 체결량 100 거래량 427511
# 실시간(장중 체결) 뷰노 114006 33250 대비 300 체결량 20 거래량 477559
# 실시간(장중 체결) 뷰노 114014 33250 대비 300 체결량 1 거래량 477560
# 실시간(장중 체결) 뷰노 114016 33250 대비 300 체결량 10 거래량 477570
# 실시간(장중 체결) 뷰노 114018 33250 대비 300 체결량 4 거래량 477574
# 실시간(장중 체결) 알체라 114018 10300 대비 -10 체결량 1 거래량 32689
# 실시간(장중 체결) 알체라 114020 10300 대비 -10 체결량 61 거래량 32750
# 실시간(장중 체결) 뷰노 114024 33250 대비 300 체결량 10 거래량 477584
# 실시간(장중 체결) 뷰노 114025 33250 대비 300 체결량 100 거래량 477684
# 실시간(장중 체결) 뷰노 114025 33250 대비 300 체결량 3 거래량 477687
# 실시간(장중 체결) 셀바스AI 114029 17760 대비 0 체결량 1 거래량 203825
# 실시간(장중 체결) 뷰노 114031 33250 대비 300 체결량 3 거래량 477690
# 실시간(장중 체결) 뷰노 114031 33250 대비 300 체결량 2 거래량 477692
# 실시간(장중 체결) 뷰노 114040 33250 대비 300 체결량 25 거래량 477717
# 실시간(장중 체결) 뷰노 114041 33250 대비 300 체결량 16 거래량 477733
# 실시간(장중 체결) 뷰노 114044 33300 대비 350 체결량 5 거래량 477738
# 실시간(장중 체결) 알체라 114045 10300 대비 -10 체결량 3 거래량 32753
# 실시간(장중 체결) 뷰노 114048 33300 대비 350 체결량 2 거래량 477740
# 실시간(장중 체결) 알체라 114050 10300 대비 -10 체결량 1 거래량 32754
# 실시간(장중 체결) 셀바스AI 114050 17760 대비 0 체결량 2 거래량 203827
# 실시간(장중 체결) 뷰노 114057 33300 대비 350 체결량 2 거래량 477742
# 실시간(장중 체결) 뷰노 114057 33300 대비 350 체결량 1 거래량 477743
# 실시간(장중 체결) 뷰노 114057 33300 대비 350 체결량 150 거래량 477893
# 실시간(장중 체결) 뷰노 114102 33300 대비 350 체결량 100 거래량 477993
# 실시간(장중 체결) 뷰노 114102 33300 대비 350 체결량 1 거래량 477994
# 실시간(장중 체결) 뷰노 114104 33300 대비 350 체결량 80 거래량 478074
# 실시간(장중 체결) 뷰노 114104 33300 대비 350 체결량 323 거래량 478397
# 실시간(장중 체결) 알체라 114105 10300 대비 -10 체결량 108 거래량 32862
# 실시간(장중 체결) 뷰노 114107 33300 대비 350 체결량 5 거래량 478402
# 실시간(장중 체결) 뷰노 114107 33300 대비 350 체결량 45 거래량 478447
# 실시간(장중 체결) 셀바스AI 114110 17770 대비 10 체결량 50 거래량 203877
# 실시간(장중 체결) 뷰노 114113 33350 대비 400 체결량 1 거래량 478448
# 실시간(장중 체결) 뷰노 114114 33300 대비 350 체결량 50 거래량 478498
# 실시간(장중 체결) 뷰노 114119 33350 대비 400 체결량 3 거래량 478501
# 실시간(장중 체결) 뷰노 114120 33350 대비 400 체결량 10 거래량 478511
# 실시간(장중 체결) 뷰노 114120 33300 대비 350 체결량 1 거래량 478512
# 실시간(장중 체결) 알체라 114124 10310 대비 0 체결량 1 거래량 32863
# 실시간(장중 체결) 뷰노 114124 33350 대비 400 체결량 13 거래량 478525
# 실시간(장중 체결) 플리토 114126 30750 대비 200 체결량 5 거래량 15867
# 실시간(장중 체결) 뷰노 114129 33350 대비 400 체결량 1 거래량 478526
# 실시간(장중 체결) 뷰노 114129 33350 대비 400 체결량 4 거래량 478530
# 실시간(장중 체결) 뷰노 114130 33300 대비 350 체결량 10 거래량 478540
# 실시간(장중 체결) 셀바스AI 114130 17770 대비 10 체결량 115 거래량 203992
# 실시간(장중 체결) 뷰노 114133 33350 대비 400 체결량 3 거래량 478543
# 실시간(장중 체결) 뷰노 114133 33300 대비 350 체결량 60 거래량 478603
# 실시간(장중 체결) 셀바스AI 114136 17770 대비 10 체결량 1 거래량 203993
# 실시간(장중 체결) 뷰노 114140 33350 대비 400 체결량 1 거래량 478604
# 실시간(장중 체결) 셀바스AI 114140 17770 대비 10 체결량 10 거래량 204003
# 실시간(장중 체결) 알체라 114140 10310 대비 0 체결량 5 거래량 32868
# 실시간(장중 체결) 뷰노 114146 33350 대비 400 체결량 2 거래량 478606
# 실시간(장중 체결) 셀바스AI 114146 17770 대비 10 체결량 10 거래량 204013
# 실시간(장중 체결) 뷰노 114147 33350 대비 400 체결량 1 거래량 478607
# 실시간(장중 체결) 뷰노 114150 33300 대비 350 체결량 1 거래량 478608
# 실시간(장중 체결) 뷰노 114152 33350 대비 400 체결량 59 거래량 478667
# 실시간(장중 체결) 투비소프트 114153 1095 대비 0 체결량 135 거래량 427646
# 실시간(장중 체결) 투비소프트 114153 1095 대비 0 체결량 5 거래량 427651
# 실시간(장중 체결) 투비소프트 114153 1095 대비 0 체결량 1877 거래량 429528
# 실시간(장중 체결) 셀바스AI 114155 17770 대비 10 체결량 100 거래량 204113
# 실시간(장중 체결) 플리토 114156 30700 대비 150 체결량 28 거래량 15895
# 실시간(장중 체결) 뷰노 114156 33350 대비 400 체결량 141 거래량 478808
# 실시간(장중 체결) 셀바스AI 114157 17770 대비 10 체결량 27 거래량 204140
# 실시간(장중 체결) 뷰노 114200 33350 대비 400 체결량 4 거래량 478812
# 실시간(장중 체결) 뷰노 114201 33400 대비 450 체결량 1 거래량 478813
# 실시간(장중 체결) 알체라 114202 10300 대비 -10 체결량 240 거래량 33108
# 실시간(장중 체결) 뷰노 114204 33400 대비 450 체결량 30 거래량 478843
# 실시간(장중 체결) 셀바스AI 114210 17770 대비 10 체결량 28 거래량 204168
# 실시간(장중 체결) 셀바스AI 114211 17770 대비 10 체결량 100 거래량 204268
# 실시간(장중 체결) 셀바스AI 114216 17770 대비 10 체결량 10 거래량 204278
# 실시간(장중 체결) 뷰노 114218 33400 대비 450 체결량 1 거래량 478844
# 실시간(장중 체결) 셀바스AI 114218 17770 대비 10 체결량 10 거래량 204288
# 실시간(장중 체결) 뷰노 114222 33400 대비 450 체결량 4 거래량 478848
# 실시간(장중 체결) 뷰노 114222 33400 대비 450 체결량 91 거래량 478939
# 실시간(장중 체결) 셀바스AI 114226 17770 대비 10 체결량 100 거래량 204388
# 실시간(장중 체결) 셀바스AI 114228 17770 대비 10 체결량 10 거래량 204398
# 실시간(장중 체결) 뷰노 114228 33400 대비 450 체결량 10 거래량 478949
# 실시간(장중 체결) 셀바스AI 114230 17770 대비 10 체결량 10 거래량 204408
# 실시간(장중 체결) 뷰노 114232 33400 대비 450 체결량 1 거래량 478950
# 실시간(장중 체결) 뷰노 114233 33350 대비 400 체결량 30 거래량 478980
# 실시간(장중 체결) 셀바스AI 114236 17770 대비 10 체결량 100 거래량 204508
# 실시간(장중 체결) 셀바스AI 114236 17770 대비 10 체결량 617 거래량 205125
# 실시간(장중 체결) 셀바스AI 114236 17770 대비 10 체결량 641 거래량 205766
# 실시간(장중 체결) 셀바스AI 114247 17770 대비 10 체결량 10 거래량 205776
# 실시간(장중 체결) 셀바스AI 114247 17770 대비 10 체결량 875 거래량 206651
# 실시간(장중 체결) 플리토 114248 30700 대비 150 체결량 227 거래량 16122
# 실시간(장중 체결) 플리토 114248 30650 대비 100 체결량 142 거래량 16264
# 실시간(장중 체결) 플리토 114248 30600 대비 50 체결량 365 거래량 16629
# 실시간(장중 체결) 플리토 114248 30550 대비 0 체결량 466 거래량 17095
# 실시간(장중 체결) 뷰노 114248 33350 대비 400 체결량 17 거래량 478997
# 실시간(장중 체결) 뷰노 114250 33400 대비 450 체결량 2 거래량 478999
# 실시간(장중 체결) 뷰노 114258 33400 대비 450 체결량 2 거래량 479001
# 실시간(장중 체결) 셀바스AI 114258 17770 대비 10 체결량 30 거래량 206681
# 실시간(장중 체결) 뷰노 114258 33400 대비 450 체결량 2 거래량 479003
# 실시간(장중 체결) 뷰노 114259 33400 대비 450 체결량 9 거래량 479012
# 실시간(장중 체결) 셀바스AI 114300 17760 대비 0 체결량 10 거래량 206691
# 실시간(장중 체결) 셀바스AI 114300 17770 대비 10 체결량 12 거래량 206703
# 실시간(장중 체결) 셀바스AI 114301 17770 대비 10 체결량 34 거래량 206737
# 실시간(장중 체결) 뷰노 114303 33350 대비 400 체결량 6 거래량 479018
# 실시간(장중 체결) 셀바스AI 114304 17770 대비 10 체결량 49 거래량 206786
# 실시간(장중 체결) 셀바스AI 114304 17770 대비 10 체결량 399 거래량 207185
# 실시간(장중 체결) 셀바스AI 114304 17770 대비 10 체결량 87 거래량 207272
# 실시간(장중 체결) 뷰노 114308 33400 대비 450 체결량 12 거래량 479030
# 실시간(장중 체결) 셀바스AI 114310 17780 대비 20 체결량 8 거래량 207280
# 실시간(장중 체결) 뷰노 114314 33400 대비 450 체결량 1 거래량 479031
# 실시간(장중 체결) 뷰노 114317 33400 대비 450 체결량 110 거래량 479141
# 실시간(장중 체결) 뷰노 114318 33400 대비 450 체결량 9 거래량 479150
# 실시간(장중 체결) 뷰노 114322 33400 대비 450 체결량 2 거래량 479152
# 실시간(장중 체결) 뷰노 114322 33400 대비 450 체결량 2 거래량 479154
# 실시간(장중 체결) 뷰노 114324 33400 대비 450 체결량 10 거래량 479164
# 실시간(장중 체결) 뷰노 114324 33350 대비 400 체결량 10 거래량 479174
# 실시간(장중 체결) 뷰노 114326 33400 대비 450 체결량 1 거래량 479175
# 실시간(장중 체결) 뷰노 114332 33350 대비 400 체결량 10 거래량 479185
# 실시간(장중 체결) 투비소프트 114332 1089 대비 -6 체결량 1 거래량 429529
# 실시간(장중 체결) 뷰노 114333 33400 대비 450 체결량 65 거래량 479250
# 실시간(장중 체결) 셀바스AI 114336 17780 대비 20 체결량 1 거래량 207281
# 실시간(장중 체결) 뷰노 114339 33400 대비 450 체결량 1 거래량 479251
# 실시간(장중 체결) 뷰노 114340 33400 대비 450 체결량 10 거래량 479261
# 실시간(장중 체결) 셀바스AI 114345 17770 대비 10 체결량 71 거래량 207352
# 실시간(장중 체결) 셀바스AI 114346 17770 대비 10 체결량 100 거래량 207452
# 실시간(장중 체결) 셀바스AI 114346 17770 대비 10 체결량 129 거래량 207581
# 실시간(장중 체결) 뷰노 114348 33400 대비 450 체결량 1 거래량 479262
# 실시간(장중 체결) 뷰노 114351 33350 대비 400 체결량 97 거래량 479359
# 실시간(장중 체결) 뷰노 114353 33400 대비 450 체결량 2 거래량 479361
# 실시간(장중 체결) 뷰노 114356 33350 대비 400 체결량 20 거래량 479381
# 실시간(장중 체결) 뷰노 114356 33400 대비 450 체결량 1 거래량 479382
# 실시간(장중 체결) 뷰노 114400 33400 대비 450 체결량 125 거래량 479507
# 실시간(장중 체결) 뷰노 114400 33350 대비 400 체결량 3 거래량 479510
# 실시간(장중 체결) 뷰노 114402 33400 대비 450 체결량 1 거래량 479511
# 실시간(장중 체결) 셀바스AI 114404 17760 대비 0 체결량 17 거래량 207598
# 실시간(장중 체결) 뷰노 114405 33400 대비 450 체결량 1 거래량 479512
# 실시간(장중 체결) 뷰노 114405 33400 대비 450 체결량 14 거래량 479526
# 실시간(장중 체결) 알체라 114408 10300 대비 -10 체결량 52 거래량 33160
# 실시간(장중 체결) 뷰노 114409 33400 대비 450 체결량 43 거래량 479569
# 실시간(장중 체결) 투비소프트 114412 1088 대비 -7 체결량 1000 거래량 430529
# 실시간(장중 체결) 뷰노 114412 33350 대비 400 체결량 12 거래량 479581
# 실시간(장중 체결) 뷰노 114412 33400 대비 450 체결량 2 거래량 479583
# 실시간(장중 체결) 뷰노 114416 33400 대비 450 체결량 38 거래량 479621
# 실시간(장중 체결) 뷰노 114416 33400 대비 450 체결량 338 거래량 479959
# 실시간(장중 체결) 셀바스AI 114417 17760 대비 0 체결량 35 거래량 207633
# 실시간(장중 체결) 뷰노 114416 33400 대비 450 체결량 176 거래량 480135
# 실시간(장중 체결) 뷰노 114419 33450 대비 500 체결량 2 거래량 480137
# 실시간(장중 체결) 뷰노 114420 33450 대비 500 체결량 2 거래량 480139
# 실시간(장중 체결) 뷰노 114421 33400 대비 450 체결량 1 거래량 480140
# 실시간(장중 체결) 뷰노 114421 33450 대비 500 체결량 296 거래량 480436
# 실시간(장중 체결) 뷰노 114421 33450 대비 500 체결량 44 거래량 480480
# 실시간(장중 체결) 뷰노 114426 33450 대비 500 체결량 8 거래량 480488
# 실시간(장중 체결) 뷰노 114430 33450 대비 500 체결량 21 거래량 480509
# 실시간(장중 체결) 에스에너지 114432 2755 대비 10 체결량 3 거래량 32588
# 실시간(장중 체결) 뷰노 114433 33450 대비 500 체결량 5 거래량 480514
# 실시간(장중 체결) 뷰노 114434 33450 대비 500 체결량 1 거래량 480515
# 실시간(장중 체결) 뷰노 114436 33450 대비 500 체결량 10 거래량 480525
# 실시간(장중 체결) 뷰노 114437 33450 대비 500 체결량 7 거래량 480532
# 실시간(장중 체결) 뷰노 114438 33450 대비 500 체결량 126 거래량 480658
# 실시간(장중 체결) 뷰노 114438 33400 대비 450 체결량 1 거래량 480659
# 실시간(장중 체결) 셀바스AI 114442 17760 대비 0 체결량 10 거래량 207643
# 실시간(장중 체결) 셀바스AI 114442 17760 대비 0 체결량 6 거래량 207649
# 실시간(장중 체결) 투비소프트 114443 1087 대비 -8 체결량 1 거래량 430530
# 실시간(장중 체결) 투비소프트 114443 1086 대비 -9 체결량 1522 거래량 432052
# 실시간(장중 체결) 투비소프트 114443 1085 대비 -10 체결량 4478 거래량 436530
# 실시간(장중 체결) 투비소프트 114443 1083 대비 -12 체결량 1001 거래량 437531
# 실시간(장중 체결) 투비소프트 114443 1082 대비 -13 체결량 1582 거래량 439113
# 실시간(장중 체결) 투비소프트 114443 1081 대비 -14 체결량 1416 거래량 440529
# 실시간(장중 체결) 알체라 114444 10310 대비 0 체결량 1 거래량 33161
# 실시간(장중 체결) 뷰노 114446 33450 대비 500 체결량 1 거래량 480660
# 실시간(장중 체결) 뷰노 114448 33450 대비 500 체결량 38 거래량 480698
# 실시간(장중 체결) 셀바스AI 114452 17760 대비 0 체결량 15 거래량 207664
# 실시간(장중 체결) 뷰노 114453 33450 대비 500 체결량 2 거래량 480700
# 실시간(장중 체결) 셀바스AI 114453 17760 대비 0 체결량 113 거래량 207777
# 실시간(장중 체결) 뷰노 114456 33450 대비 500 체결량 50 거래량 480750
# 실시간(장중 체결) 알체라 114500 10310 대비 0 체결량 1 거래량 33162
# 실시간(장중 체결) 뷰노 114502 33400 대비 450 체결량 2 거래량 480752
# 실시간(장중 체결) 뷰노 114503 33450 대비 500 체결량 71 거래량 480823
# 실시간(장중 체결) 뷰노 114506 33450 대비 500 체결량 44 거래량 480867
# 실시간(장중 체결) 뷰노 114507 33450 대비 500 체결량 29 거래량 480896
# 실시간(장중 체결) 뷰노 114516 33450 대비 500 체결량 70 거래량 480966
# 실시간(장중 체결) 뷰노 114517 33400 대비 450 체결량 2 거래량 480968
# 실시간(장중 체결) 뷰노 114521 33400 대비 450 체결량 100 거래량 481068
# 실시간(장중 체결) 뷰노 114522 33400 대비 450 체결량 24 거래량 481092
# 실시간(장중 체결) 뷰노 114524 33400 대비 450 체결량 41 거래량 481133
# 실시간(장중 체결) 뷰노 114525 33400 대비 450 체결량 10 거래량 481143
# 실시간(장중 체결) 뷰노 114536 33450 대비 500 체결량 1 거래량 481144
# 실시간(장중 체결) 뷰노 114544 33450 대비 500 체결량 2 거래량 481146
# 실시간(장중 체결) 플리토 114545 30600 대비 50 체결량 8 거래량 17103
# 실시간(장중 체결) 셀바스AI 114546 17760 대비 0 체결량 40 거래량 207817
# 실시간(장중 체결) 셀바스AI 114550 17760 대비 0 체결량 27 거래량 207844
# 실시간(장중 체결) 뷰노 114554 33450 대비 500 체결량 1 거래량 481147
# 실시간(장중 체결) 셀바스AI 114554 17760 대비 0 체결량 7 거래량 207851
# 실시간(장중 체결) 플리토 114555 30700 대비 150 체결량 1 거래량 17104
# 실시간(장중 체결) 뷰노 114556 33450 대비 500 체결량 59 거래량 481206
# 실시간(장중 체결) 뷰노 114556 33450 대비 500 체결량 41 거래량 481247
# 실시간(장중 체결) 뷰노 114556 33400 대비 450 체결량 19 거래량 481266
# 실시간(장중 체결) 투비소프트 114558 1082 대비 -13 체결량 1137 거래량 441666
# 실시간(장중 체결) 투비소프트 114558 1081 대비 -14 체결량 1172 거래량 442838
# 실시간(장중 체결) 뷰노 114559 33500 대비 550 체결량 10 거래량 481276
# 실시간(장중 체결) 셀바스AI 114559 17780 대비 20 체결량 3 거래량 207854
# 실시간(장중 체결) 투비소프트 114605 1081 대비 -14 체결량 998 거래량 443836
# 실시간(장중 체결) 투비소프트 114605 1081 대비 -14 체결량 1266 거래량 445102
# 실시간(장중 체결) 뷰노 114611 33500 대비 550 체결량 1 거래량 481277
# 실시간(장중 체결) 뷰노 114613 33500 대비 550 체결량 3 거래량 481280
# 실시간(장중 체결) 뷰노 114613 33500 대비 550 체결량 2 거래량 481282
# 실시간(장중 체결) 셀바스AI 114615 17760 대비 0 체결량 1 거래량 207855
# 실시간(장중 체결) 뷰노 114618 33500 대비 550 체결량 5 거래량 481287
# 실시간(장중 체결) 뷰노 114618 33500 대비 550 체결량 1 거래량 481288
# 실시간(장중 체결) 뷰노 114620 33500 대비 550 체결량 630 거래량 481918
# 실시간(장중 체결) 뷰노 114621 33500 대비 550 체결량 818 거래량 482736
# 실시간(장중 체결) 알체라 114621 10300 대비 -10 체결량 450 거래량 33612
# 실시간(장중 체결) 뷰노 114624 33550 대비 600 체결량 1 거래량 482737
# 실시간(장중 체결) 뷰노 114624 33550 대비 600 체결량 2 거래량 482739
# 실시간(장중 체결) 뷰노 114624 33500 대비 550 체결량 2 거래량 482741
# 실시간(장중 체결) 셀바스AI 114629 17780 대비 20 체결량 47 거래량 207902
# 실시간(장중 체결) 뷰노 114630 33550 대비 600 체결량 2 거래량 482743
# 실시간(장중 체결) 셀바스AI 114629 17780 대비 20 체결량 51 거래량 207953
# 실시간(장중 체결) 뷰노 114630 33550 대비 600 체결량 25 거래량 482768
# 실시간(장중 체결) 뷰노 114631 33550 대비 600 체결량 1 거래량 482769
# 실시간(장중 체결) 뷰노 114634 33500 대비 550 체결량 1 거래량 482770
# 실시간(장중 체결) 뷰노 114637 33500 대비 550 체결량 2 거래량 482772
# 실시간(장중 체결) 뷰노 114637 33500 대비 550 체결량 5 거래량 482777
# 실시간(장중 체결) 뷰노 114637 33550 대비 600 체결량 1 거래량 482778
# 실시간(장중 체결) 뷰노 114638 33550 대비 600 체결량 2 거래량 482780
# 실시간(장중 체결) 투비소프트 114638 1089 대비 -6 체결량 1 거래량 445103
# 실시간(장중 체결) 뷰노 114639 33500 대비 550 체결량 4 거래량 482784
# 실시간(장중 체결) 뷰노 114644 33550 대비 600 체결량 1 거래량 482785
# 실시간(장중 체결) 알체라 114645 10300 대비 -10 체결량 1 거래량 33613
# 실시간(장중 체결) 뷰노 114645 33550 대비 600 체결량 1 거래량 482786
# ...
# 실시간(장중 체결) 셀바스AI 151430 17720 대비 -40 체결량 1 거래량 341241
# 실시간(장중 체결) 뷰노 151430 33000 대비 50 체결량 2 거래량 841694
# 실시간(장중 체결) 뷰노 151431 33000 대비 50 체결량 747 거래량 842441
# 실시간(장중 체결) 뷰노 151431 33000 대비 50 체결량 52 거래량 842493
# 실시간(장중 체결) 셀바스AI 151432 17720 대비 -40 체결량 100 거래량 341341
# 실시간(장중 체결) 에스에너지 151434 2735 대비 -10 체결량 1 거래량 53305
# 실시간(장중 체결) 뷰노 151436 33050 대비 100 체결량 1 거래량 842494
# 실시간(장중 체결) 셀바스AI 151441 17720 대비 -40 체결량 200 거래량 341541
# 실시간(장중 체결) 투비소프트 151442 1081 대비 -14 체결량 89 거래량 759565
# 실시간(장중 체결) 투비소프트 151442 1080 대비 -15 체결량 911 거래량 760476
# 실시간(장중 체결) 셀바스AI 151445 17720 대비 -40 체결량 10 거래량 341551
# 실시간(장중 체결) 에스에너지 151446 2735 대비 -10 체결량 10 거래량 53315
# 실시간(장중 체결) 뷰노 151447 33000 대비 50 체결량 6 거래량 842500
# 실시간(장중 체결) 셀바스AI 151447 17720 대비 -40 체결량 1 거래량 341552
# 실시간(장중 체결) 뷰노 151448 33050 대비 100 체결량 5 거래량 842505
# 실시간(장중 체결) 셀바스AI 151451 17720 대비 -40 체결량 1 거래량 341553
# 실시간(장중 체결) 알체라 151452 10210 대비 -100 체결량 1956 거래량 72364
# 실시간(장중 체결) 알체라 151452 10200 대비 -110 체결량 348 거래량 72712
# 실시간(장중 체결) 플리토 151453 30800 대비 250 체결량 11 거래량 21384
# 실시간(장중 체결) 뷰노 151453 33050 대비 100 체결량 10 거래량 842515
# 실시간(장중 체결) 알체라 151453 10200 대비 -110 체결량 40 거래량 72752
# 실시간(장중 체결) 플리토 151454 30800 대비 250 체결량 11 거래량 21395
# 실시간(장중 체결) 셀바스AI 151455 17720 대비 -40 체결량 100 거래량 341653
# 실시간(장중 체결) 뷰노 151456 33050 대비 100 체결량 1 거래량 842516
# 실시간(장중 체결) 뷰노 151457 33000 대비 50 체결량 5 거래량 842521
# 실시간(장중 체결) 뷰노 151458 33000 대비 50 체결량 212 거래량 842733
# 실시간(장중 체결) 셀바스AI 151500 17720 대비 -40 체결량 70 거래량 341723
# 실시간(장중 체결) 셀바스AI 151501 17710 대비 -50 체결량 5 거래량 341728
# 실시간(장중 체결) 셀바스AI 151501 17720 대비 -40 체결량 1 거래량 341729
# 실시간(장중 체결) 셀바스AI 151502 17710 대비 -50 체결량 5 거래량 341734
# 실시간(장중 체결) 뷰노 151503 33000 대비 50 체결량 1 거래량 842734
# 실시간(장중 체결) 뷰노 151506 33000 대비 50 체결량 3 거래량 842737
# 실시간(장중 체결) 뷰노 151507 33000 대비 50 체결량 1 거래량 842738
# 실시간(장중 체결) 뷰노 151508 33000 대비 50 체결량 1 거래량 842739
# 실시간(장중 체결) 뷰노 151509 32950 대비 0 체결량 37 거래량 842776
# 실시간(장중 체결) 투비소프트 151510 1089 대비 -6 체결량 1 거래량 760477
# 실시간(장중 체결) 에스에너지 151510 2735 대비 -10 체결량 10 거래량 53325
# 실시간(장중 체결) 셀바스AI 151512 17720 대비 -40 체결량 1 거래량 341735
# 실시간(장중 체결) 뷰노 151512 33000 대비 50 체결량 3 거래량 842779
# 실시간(장중 체결) 셀바스AI 151513 17720 대비 -40 체결량 56 거래량 341791
# 실시간(장중 체결) 투비소프트 151516 1080 대비 -15 체결량 1 거래량 760478
# 실시간(장중 체결) 뷰노 151517 33000 대비 50 체결량 1 거래량 842780
# 실시간(장중 체결) 셀바스AI 151517 17710 대비 -50 체결량 2 거래량 341793
# 실시간(장중 체결) 알체라 151519 10210 대비 -100 체결량 100 거래량 72852
# 실시간(장중 체결) 뷰노 151522 33000 대비 50 체결량 5 거래량 842785
# 실시간(장중 체결) 셀바스AI 151523 17710 대비 -50 체결량 56 거래량 341849
# 실시간(장중 체결) 뷰노 151533 33000 대비 50 체결량 1 거래량 842786
# 실시간(장중 체결) 셀바스AI 151537 17720 대비 -40 체결량 10 거래량 341859
# 실시간(장중 체결) 셀바스AI 151539 17720 대비 -40 체결량 30 거래량 341889
# 실시간(장중 체결) 셀바스AI 151540 17720 대비 -40 체결량 554 거래량 342443
# 실시간(장중 체결) 뷰노 151541 33000 대비 50 체결량 1 거래량 842787
# 실시간(장중 체결) 뷰노 151541 32950 대비 0 체결량 223 거래량 843010
# 실시간(장중 체결) 뷰노 151541 32900 대비 -50 체결량 377 거래량 843387
# 실시간(장중 체결) 셀바스AI 151543 17720 대비 -40 체결량 50 거래량 342493
# 실시간(장중 체결) 뷰노 151544 33000 대비 50 체결량 1 거래량 843388
# 실시간(장중 체결) 알체라 151544 10210 대비 -100 체결량 4 거래량 72856
# 실시간(장중 체결) 셀바스AI 151544 17720 대비 -40 체결량 69 거래량 342562
# 실시간(장중 체결) 알체라 151549 10210 대비 -100 체결량 5 거래량 72861
# 실시간(장중 체결) 뷰노 151550 32950 대비 0 체결량 87 거래량 843475
# 실시간(장중 체결) 셀바스AI 151551 17720 대비 -40 체결량 500 거래량 343062
# 실시간(장중 체결) 뷰노 151552 32950 대비 0 체결량 10 거래량 843485
# 실시간(장중 체결) 셀바스AI 151552 17720 대비 -40 체결량 30 거래량 343092
# 실시간(장중 체결) 뷰노 151554 32950 대비 0 체결량 100 거래량 843585
# 실시간(장중 체결) 셀바스AI 151556 17720 대비 -40 체결량 59 거래량 343151
# 실시간(장중 체결) 셀바스AI 151556 17720 대비 -40 체결량 31 거래량 343182
# 실시간(장중 체결) 뷰노 151558 32950 대비 0 체결량 2 거래량 843587
# 실시간(장중 체결) 뷰노 151558 32950 대비 0 체결량 5 거래량 843592
# 실시간(장중 체결) 뷰노 151600 32950 대비 0 체결량 123 거래량 843715
# 실시간(장중 체결) 뷰노 151601 33000 대비 50 체결량 2 거래량 843717
# 실시간(장중 체결) 뷰노 151601 32950 대비 0 체결량 10 거래량 843727
# 실시간(장중 체결) 뷰노 151606 32950 대비 0 체결량 5 거래량 843732
# 실시간(장중 체결) 뷰노 151606 32950 대비 0 체결량 16 거래량 843748
# 실시간(장중 체결) 셀바스AI 151606 17720 대비 -40 체결량 111 거래량 343293
# 실시간(장중 체결) 셀바스AI 151606 17710 대비 -50 체결량 1271 거래량 344564
# 실시간(장중 체결) 뷰노 151606 32950 대비 0 체결량 391 거래량 844139
# 실시간(장중 체결) 뷰노 151606 32900 대비 -50 체결량 7807 거래량 851946
# 실시간(장중 체결) 알체라 151606 10210 대비 -100 체결량 50 거래량 72911
# 실시간(장중 체결) 뷰노 151608 32850 대비 -100 체결량 24 거래량 851970
# 실시간(장중 체결) 뷰노 151608 32850 대비 -100 체결량 524 거래량 852494
# 실시간(장중 체결) 뷰노 151608 32800 대비 -150 체결량 11 거래량 852505
# 실시간(장중 체결) 뷰노 151609 32800 대비 -150 체결량 17 거래량 852522
# 실시간(장중 체결) 뷰노 151609 32900 대비 -50 체결량 10 거래량 852532
# 실시간(장중 체결) 알체라 151609 10210 대비 -100 체결량 1 거래량 72912
# 실시간(장중 체결) 뷰노 151613 32800 대비 -150 체결량 17 거래량 852549
# 실시간(장중 체결) 투비소프트 151616 1089 대비 -6 체결량 1 거래량 760479
# 실시간(장중 체결) 뷰노 151620 32900 대비 -50 체결량 14 거래량 852563
# 실시간(장중 체결) 뷰노 151620 32950 대비 0 체결량 5 거래량 852568
# 실시간(장중 체결) 뷰노 151620 32950 대비 0 체결량 20 거래량 852588
# 실시간(장중 체결) 투비소프트 151620 1088 대비 -7 체결량 1 거래량 760480
# 실시간(장중 체결) 투비소프트 151620 1080 대비 -15 체결량 1 거래량 760481
# 실시간(장중 체결) 셀바스AI 151621 17720 대비 -40 체결량 10 거래량 344574
# 실시간(장중 체결) 셀바스AI 151622 17720 대비 -40 체결량 1 거래량 344575
# 실시간(장중 체결) 투비소프트 151622 1089 대비 -6 체결량 1185 거래량 761666
# 실시간(장중 체결) 투비소프트 151622 1090 대비 -5 체결량 26 거래량 761692
# 실시간(장중 체결) 투비소프트 151622 1091 대비 -4 체결량 1551 거래량 763243
# 실시간(장중 체결) 투비소프트 151622 1092 대비 -3 체결량 174 거래량 763417
# 실시간(장중 체결) 알체라 151625 10210 대비 -100 체결량 1 거래량 72913
# 실시간(장중 체결) 알체라 151628 10210 대비 -100 체결량 7 거래량 72920
# 실시간(장중 체결) 투비소프트 151628 1081 대비 -14 체결량 1 거래량 763418
# 실시간(장중 체결) 셀바스AI 151628 17720 대비 -40 체결량 23 거래량 344598
# 실시간(장중 체결) 셀바스AI 151628 17730 대비 -30 체결량 77 거래량 344675
# 실시간(장중 체결) 뷰노 151630 32850 대비 -100 체결량 38 거래량 852626
# 실시간(장중 체결) 뷰노 151630 32800 대비 -150 체결량 462 거래량 853088
# 실시간(장중 체결) 뷰노 151631 32950 대비 0 체결량 3 거래량 853091
# 실시간(장중 체결) 에스에너지 151632 2725 대비 -20 체결량 1000 거래량 54325
# 실시간(장중 체결) 알체라 151635 10210 대비 -100 체결량 33 거래량 72953
# 실시간(장중 체결) 뷰노 151635 32850 대비 -100 체결량 2 거래량 853093
# 실시간(장중 체결) 뷰노 151635 32800 대비 -150 체결량 38 거래량 853131
# 실시간(장중 체결) 뷰노 151635 32950 대비 0 체결량 32 거래량 853163
# 실시간(장중 체결) 셀바스AI 151636 17720 대비 -40 체결량 11 거래량 344686
# 실시간(장중 체결) 셀바스AI 151636 17710 대비 -50 체결량 89 거래량 344775
# 실시간(장중 체결) 투비소프트 151636 1091 대비 -4 체결량 1 거래량 763419
# 실시간(장중 체결) 투비소프트 151636 1092 대비 -3 체결량 826 거래량 764245
# 실시간(장중 체결) 투비소프트 151636 1093 대비 -2 체결량 1660 거래량 765905
# 실시간(장중 체결) 셀바스AI 151636 17710 대비 -50 체결량 1 거래량 344776
# 실시간(장중 체결) 뷰노 151638 32800 대비 -150 체결량 7 거래량 853170
# 실시간(장중 체결) 에스에너지 151638 2735 대비 -10 체결량 1 거래량 54326
# 실시간(장중 체결) 셀바스AI 151639 17710 대비 -50 체결량 166 거래량 344942
# 실시간(장중 체결) 셀바스AI 151640 17710 대비 -50 체결량 34 거래량 344976
# 실시간(장중 체결) 뷰노 151641 32800 대비 -150 체결량 10 거래량 853180
# 실시간(장중 체결) 투비소프트 151642 1081 대비 -14 체결량 1 거래량 765906
# 실시간(장중 체결) 셀바스AI 151642 17730 대비 -30 체결량 100 거래량 345076
# 실시간(장중 체결) 셀바스AI 151642 17730 대비 -30 체결량 100 거래량 345176
# 실시간(장중 체결) 플리토 151642 30800 대비 250 체결량 5 거래량 21400
# 실시간(장중 체결) 알체라 151646 10210 대비 -100 체결량 2 거래량 72955
# 실시간(장중 체결) 뷰노 151648 32800 대비 -150 체결량 50 거래량 853230
# 실시간(장중 체결) 뷰노 151650 32800 대비 -150 체결량 1 거래량 853231
# 실시간(장중 체결) 셀바스AI 151651 17710 대비 -50 체결량 76 거래량 345252
# 실시간(장중 체결) 셀바스AI 151651 17700 대비 -60 체결량 84 거래량 345336
# 실시간(장중 체결) 알체라 151652 10210 대비 -100 체결량 10 거래량 72965
# 실시간(장중 체결) 뷰노 151653 32800 대비 -150 체결량 3 거래량 853234
# 실시간(장중 체결) 셀바스AI 151653 17700 대비 -60 체결량 5 거래량 345341
# 실시간(장중 체결) 셀바스AI 151655 17700 대비 -60 체결량 294 거래량 345635
# 실시간(장중 체결) 뷰노 151657 32800 대비 -150 체결량 50 거래량 853284
# 실시간(장중 체결) 알체라 151657 10210 대비 -100 체결량 196 거래량 73161
# 실시간(장중 체결) 셀바스AI 151657 17710 대비 -50 체결량 2 거래량 345637
# 실시간(장중 체결) 셀바스AI 151659 17710 대비 -50 체결량 1 거래량 345638
# 실시간(장중 체결) 뷰노 151700 32900 대비 -50 체결량 3 거래량 853287
# 실시간(장중 체결) 뷰노 151700 32900 대비 -50 체결량 3 거래량 853290
# 실시간(장중 체결) 뷰노 151700 32900 대비 -50 체결량 1 거래량 853291
# 실시간(장중 체결) 뷰노 151701 32900 대비 -50 체결량 2 거래량 853293
# 실시간(장중 체결) 뷰노 151701 32900 대비 -50 체결량 3 거래량 853296
# 실시간(장중 체결) 뷰노 151701 32900 대비 -50 체결량 4 거래량 853300
# 실시간(장중 체결) 셀바스AI 151704 17710 대비 -50 체결량 50 거래량 345688
# 실시간(장중 체결) 셀바스AI 151704 17710 대비 -50 체결량 3 거래량 345691
# 실시간(장중 체결) 뷰노 151704 32850 대비 -100 체결량 2 거래량 853302
# 실시간(장중 체결) 뷰노 151704 32800 대비 -150 체결량 45 거래량 853347
# 실시간(장중 체결) 셀바스AI 151707 17710 대비 -50 체결량 244 거래량 345935
# 실시간(장중 체결) 뷰노 151707 32900 대비 -50 체결량 2 거래량 853349
# 실시간(장중 체결) 알체라 151708 10210 대비 -100 체결량 113 거래량 73274
# 실시간(장중 체결) 뷰노 151710 32900 대비 -50 체결량 2 거래량 853351
# 실시간(장중 체결) 셀바스AI 151713 17710 대비 -50 체결량 10 거래량 345945
# 실시간(장중 체결) 셀바스AI 151713 17730 대비 -30 체결량 1 거래량 345946
# 실시간(장중 체결) 뷰노 151713 32900 대비 -50 체결량 1 거래량 853352
# 실시간(장중 체결) 투비소프트 151714 1084 대비 -11 체결량 100 거래량 766006
# 실시간(장중 체결) 셀바스AI 151716 17710 대비 -50 체결량 100 거래량 346046
# 실시간(장중 체결) 뷰노 151716 32900 대비 -50 체결량 39 거래량 853391
# 실시간(장중 체결) 뷰노 151718 32900 대비 -50 체결량 33 거래량 853424
# 실시간(장중 체결) 셀바스AI 151719 17730 대비 -30 체결량 1 거래량 346047
# 실시간(장중 체결) 셀바스AI 151721 17710 대비 -50 체결량 300 거래량 346347
# 실시간(장중 체결) 뷰노 151722 32900 대비 -50 체결량 33 거래량 853457
# 실시간(장중 체결) 뷰노 151722 32800 대비 -150 체결량 110 거래량 853567
# 실시간(장중 체결) 뷰노 151724 32800 대비 -150 체결량 180 거래량 853747
# 실시간(장중 체결) 셀바스AI 151724 17730 대비 -30 체결량 1 거래량 346348
# 실시간(장중 체결) 뷰노 151725 32900 대비 -50 체결량 10 거래량 853757
# 실시간(장중 체결) 셀바스AI 151726 17710 대비 -50 체결량 15 거래량 346363
# 실시간(장중 체결) 뷰노 151729 32800 대비 -150 체결량 7 거래량 853764
# 실시간(장중 체결) 셀바스AI 151731 17720 대비 -40 체결량 100 거래량 346463
# 실시간(장중 체결) 뷰노 151732 32900 대비 -50 체결량 2 거래량 853766
# 실시간(장중 체결) 뷰노 151733 32800 대비 -150 체결량 10 거래량 853776
# 실시간(장중 체결) 셀바스AI 151741 17720 대비 -40 체결량 100 거래량 346563
# 실시간(장중 체결) 뷰노 151745 32800 대비 -150 체결량 1 거래량 853777
# 실시간(장중 체결) 뷰노 151750 32900 대비 -50 체결량 5 거래량 853782
# 실시간(장중 체결) 셀바스AI 151754 17720 대비 -40 체결량 23 거래량 346586
# 실시간(장중 체결) 셀바스AI 151756 17710 대비 -50 체결량 750 거래량 347336
# 실시간(장중 체결) 뷰노 151757 32850 대비 -100 체결량 1 거래량 853783
# 실시간(장중 체결) 뷰노 151757 32800 대비 -150 체결량 2 거래량 853785
# 실시간(장중 체결) 뷰노 151758 32900 대비 -50 체결량 2 거래량 853787
# 실시간(장중 체결) 뷰노 151758 32900 대비 -50 체결량 2 거래량 853789
# 실시간(장중 체결) 뷰노 151800 32850 대비 -100 체결량 2 거래량 853791
# 실시간(장중 체결) 뷰노 151800 32800 대비 -150 체결량 7 거래량 853798
# 실시간(장중 체결) 뷰노 151801 32800 대비 -150 체결량 54 거래량 853852
# 실시간(장중 체결) 뷰노 151802 32800 대비 -150 체결량 1 거래량 853853
# 실시간(장중 체결) 뷰노 151803 32900 대비 -50 체결량 10 거래량 853863
# 실시간(장중 체결) 셀바스AI 151803 17720 대비 -40 체결량 50 거래량 347386
# 실시간(장중 체결) 셀바스AI 151804 17720 대비 -40 체결량 19 거래량 347405
# 실시간(장중 체결) 셀바스AI 151807 17730 대비 -30 체결량 1 거래량 347406
# 실시간(장중 체결) 셀바스AI 151809 17720 대비 -40 체결량 30 거래량 347436
# 실시간(장중 체결) 뷰노 151815 32900 대비 -50 체결량 10 거래량 853873
# 실시간(장중 체결) 투비소프트 151816 1092 대비 -3 체결량 1 거래량 766007
# 실시간(장중 체결) 투비소프트 151816 1093 대비 -2 체결량 199 거래량 766206
# 실시간(장중 체결) 셀바스AI 151817 17720 대비 -40 체결량 10 거래량 347446
# 실시간(장중 체결) 뷰노 151819 32900 대비 -50 체결량 100 거래량 853973
# 실시간(장중 체결) 셀바스AI 151820 17720 대비 -40 체결량 5 거래량 347451
# 실시간(장중 체결) 뷰노 151821 32900 대비 -50 체결량 3 거래량 853976
# 실시간(장중 체결) 셀바스AI 151823 17730 대비 -30 체결량 1 거래량 347452
# 실시간(장중 체결) 뷰노 151824 32850 대비 -100 체결량 1 거래량 853977
# 실시간(장중 체결) 뷰노 151826 32900 대비 -50 체결량 1 거래량 853978
# 실시간(장중 체결) 투비소프트 151828 1093 대비 -2 체결량 8 거래량 766214
# 실시간(장중 체결) 에스에너지 151829 2730 대비 -15 체결량 4 거래량 54330
# 실시간(장중 체결) 뷰노 151832 32900 대비 -50 체결량 60 거래량 854038
# 실시간(장중 체결) 뷰노 151832 32900 대비 -50 체결량 211 거래량 854249
# 실시간(장중 체결) 투비소프트 151835 1086 대비 -9 체결량 1 거래량 766215
# 실시간(장중 체결) 뷰노 151835 32950 대비 0 체결량 10 거래량 854259
# 실시간(장중 체결) 셀바스AI 151837 17730 대비 -30 체결량 2 거래량 347454
# 실시간(장중 체결) 셀바스AI 151837 17730 대비 -30 체결량 100 거래량 347554
# 실시간(장중 체결) 셀바스AI 151837 17730 대비 -30 체결량 200 거래량 347754
# 실시간(장중 체결) 투비소프트 151838 1086 대비 -9 체결량 938 거래량 767153
# 실시간(장중 체결) 투비소프트 151838 1086 대비 -9 체결량 62 거래량 767215
# 실시간(장중 체결) 뷰노 151839 32900 대비 -50 체결량 299 거래량 854558
# 실시간(장중 체결) 뷰노 151840 32900 대비 -50 체결량 1 거래량 854559
# 실시간(장중 체결) 셀바스AI 151840 17720 대비 -40 체결량 200 거래량 347954
# 실시간(장중 체결) 셀바스AI 151842 17720 대비 -40 체결량 5 거래량 347959
# 실시간(장중 체결) 셀바스AI 151842 17730 대비 -30 체결량 156 거래량 348115
# 실시간(장중 체결) 투비소프트 151842 1085 대비 -10 체결량 100 거래량 767315
# 실시간(장중 체결) 투비소프트 151843 1084 대비 -11 체결량 114 거래량 767429
# 실시간(장중 체결) 셀바스AI 151843 17720 대비 -40 체결량 10 거래량 348125
# 실시간(장중 체결) 뷰노 151846 32900 대비 -50 체결량 5 거래량 854564
# 실시간(장중 체결) 셀바스AI 151846 17720 대비 -40 체결량 2 거래량 348127
# 실시간(장중 체결) 셀바스AI 151849 17720 대비 -40 체결량 1 거래량 348128
# 실시간(장중 체결) 뷰노 151849 32850 대비 -100 체결량 20 거래량 854584
# 실시간(장중 체결) 뷰노 151853 32900 대비 -50 체결량 5 거래량 854589
# 실시간(장중 체결) 뷰노 151857 32900 대비 -50 체결량 1 거래량 854590
# 실시간(장중 체결) 뷰노 151858 32850 대비 -100 체결량 113 거래량 854703
# 실시간(장중 체결) 뷰노 151901 32850 대비 -100 체결량 1 거래량 854704
# 실시간(장중 체결) 셀바스AI 151901 17720 대비 -40 체결량 2 거래량 348130
# 실시간(장중 체결) 뷰노 151902 32850 대비 -100 체결량 22 거래량 854726
# 실시간(장중 체결) 셀바스AI 151902 17720 대비 -40 체결량 30 거래량 348160
# 실시간(장중 체결) 뷰노 151903 32850 대비 -100 체결량 10 거래량 854736
# 실시간(장중 체결) 뷰노 151903 32900 대비 -50 체결량 10 거래량 854746
# 실시간(장중 체결) 셀바스AI 151905 17730 대비 -30 체결량 1 거래량 348161
# 실시간(장중 체결) 뷰노 151906 32850 대비 -100 체결량 44 거래량 854790
# 실시간(장중 체결) 셀바스AI 151906 17730 대비 -30 체결량 24 거래량 348185
# 실시간(장중 체결) 뷰노 151912 32800 대비 -150 체결량 200 거래량 854990
# 실시간(장중 체결) 플리토 151912 30800 대비 250 체결량 10 거래량 21410
# 실시간(장중 체결) 뷰노 151913 32850 대비 -100 체결량 10 거래량 855000
# 실시간(장중 체결) 셀바스AI 151913 17720 대비 -40 체결량 20 거래량 348205
# 실시간(장중 체결) 뷰노 151916 32850 대비 -100 체결량 12 거래량 855012
# 실시간(장중 체결) 셀바스AI 151917 17720 대비 -40 체결량 6 거래량 348211
# 실시간(장중 체결) 셀바스AI 151919 17730 대비 -30 체결량 250 거래량 348461
# 실시간(장중 체결) 뷰노 151920 32900 대비 -50 체결량 49 거래량 855061
# 실시간(장중 체결) 알체라 151922 10210 대비 -100 체결량 10 거래량 73284
# 실시간(장중 체결) 뷰노 151926 32900 대비 -50 체결량 10 거래량 855071
# 실시간(장중 체결) 뷰노 151927 32900 대비 -50 체결량 8 거래량 855079
# 실시간(장중 체결) 뷰노 151927 32900 대비 -50 체결량 20 거래량 855099
# 실시간(장중 체결) 셀바스AI 151930 17730 대비 -30 체결량 1 거래량 348462
# 실시간(장중 체결) 셀바스AI 151931 17730 대비 -30 체결량 100 거래량 348562
# 실시간(장중 체결) 뷰노 151932 32850 대비 -100 체결량 1 거래량 855100
# 실시간(장중 체결) 셀바스AI 151936 17720 대비 -40 체결량 48 거래량 348610
# 실시간(장중 체결) 뷰노 151936 32900 대비 -50 체결량 10 거래량 855110
# 실시간(장중 체결) 투비소프트 151937 1093 대비 -2 체결량 1077 거래량 768506
# 실시간(장중 체결) 뷰노 151937 32900 대비 -50 체결량 9 거래량 855119
# 실시간(장중 체결) 투비소프트 151940 1084 대비 -11 체결량 1 거래량 768507
# 실시간(장중 체결) 투비소프트 151941 1084 대비 -11 체결량 140 거래량 768647
# 실시간(장중 체결) 셀바스AI 151947 17730 대비 -30 체결량 5 거래량 348615
# 실시간(장중 체결) 플리토 151947 30700 대비 150 체결량 64 거래량 21474
# 실시간(장중 체결) 뷰노 151948 32900 대비 -50 체결량 1 거래량 855120
# 실시간(장중 체결) 셀바스AI 151949 17720 대비 -40 체결량 30 거래량 348645
# 실시간(장중 체결) 뷰노 151951 32900 대비 -50 체결량 10 거래량 855130
# 실시간(장중 체결) 플리토 151951 30650 대비 100 체결량 100 거래량 21574
# 실시간(장중 체결) 에스에너지 151951 2725 대비 -20 체결량 200 거래량 54530
# 실시간(장중 체결) 셀바스AI 151952 17720 대비 -40 체결량 10 거래량 348655
# 실시간(장중 체결) 뷰노 151952 32900 대비 -50 체결량 50 거래량 855180
# 실시간(장중 체결) 뷰노 151956 32850 대비 -100 체결량 43 거래량 855223
# 실시간(장중 체결) 플리토 151956 30700 대비 150 체결량 30 거래량 21604
# 실시간(장중 체결) 셀바스AI 151958 17730 대비 -30 체결량 1 거래량 348656
# 실시간(장중 체결) 뷰노 151959 32900 대비 -50 체결량 15 거래량 855238
# 실시간(장중 체결) 플리토 151959 30700 대비 150 체결량 1 거래량 21605
# 실시간(장중 체결) 뷰노 151959 32900 대비 -50 체결량 2 거래량 855240
# 실시간(장중 체결) 뷰노 153002 32900 대비 -50 체결량 9954 거래량 865194
# 실시간(장중 체결) 셀바스AI 153028 17710 대비 -50 체결량 10745 거래량 359401
# 실시간(장중 체결) 에스에너지 153028 2730 대비 -15 체결량 289 거래량 54819
# 실시간(장중 체결) 투비소프트 153030 1084 대비 -11 체결량 6004 거래량 774651
# 실시간(장중 체결) 플리토 153030 30900 대비 350 체결량 547 거래량 22152
# 실시간(장중 체결) 알체라 153030 10240 대비 -70 체결량 595 거래량 73879
# 실시간(장중 체결) 투비소프트 154000 1084 대비 -11 체결량 80 거래량 774731
# 실시간(장중 체결) 에스에너지 154000 2730 대비 -15 체결량 142 거래량 54961
# 실시간(장중 체결) 셀바스AI 154000 17710 대비 -50 체결량 179 거래량 359580
# 실시간(장중 체결) 뷰노 154000 32900 대비 -50 체결량 393 거래량 865587
# 실시간(장중 체결) 알체라 154000 10240 대비 -70 체결량 8 거래량 73887
# 실시간(장중 체결) 알체라 154004 10240 대비 -70 체결량 1 거래량 73888
# 실시간(장중 체결) 뷰노 154039 32900 대비 -50 체결량 1 거래량 865588
# 실시간(장중 체결) 알체라 154050 10240 대비 -70 체결량 2 거래량 73890
# 실시간(장중 체결) 뷰노 154106 32900 대비 -50 체결량 49 거래량 865637
# 실시간(장중 체결) 셀바스AI 154108 17710 대비 -50 체결량 2 거래량 359582
# 실시간(장중 체결) 뷰노 154128 32900 대비 -50 체결량 3 거래량 865640
# 실시간(장중 체결) 셀바스AI 154131 17710 대비 -50 체결량 150 거래량 359732
# 실시간(장중 체결) 셀바스AI 154228 17710 대비 -50 체결량 1 거래량 359733
# 실시간(장중 체결) 알체라 154232 10240 대비 -70 체결량 5 거래량 73895
# 실시간(장중 체결) 셀바스AI 154316 17710 대비 -50 체결량 31 거래량 359764
# 실시간(장중 체결) 뷰노 154334 32900 대비 -50 체결량 30 거래량 865670
# 실시간(장중 체결) 알체라 154346 10240 대비 -70 체결량 5 거래량 73900
# 실시간(장중 체결) 플리토 154347 30900 대비 350 체결량 1 거래량 22153
# 실시간(장중 체결) 셀바스AI 154451 17710 대비 -50 체결량 30 거래량 359794
# 실시간(장중 체결) 알체라 154507 10240 대비 -70 체결량 1 거래량 73901
# 실시간(장중 체결) 플리토 154508 30900 대비 350 체결량 22 거래량 22175
# 실시간(장중 체결) 뷰노 154519 32900 대비 -50 체결량 5 거래량 865675
# 6 종목 실시간 해지되었음
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
