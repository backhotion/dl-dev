# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client

# %%
class CpEvent:
    def set_params(self, client):
        self.client = client
 
    def OnReceived(self):
        code = self.client.GetHeaderValue(0)  # 종목코도
        name = self.client.GetHeaderValue(1)  # 종목명
        timess = self.client.GetHeaderValue(18)  # 초
        exFlag = self.client.GetHeaderValue(19)  # 예상체결 플래그
        cprice = self.client.GetHeaderValue(13)  # 현재가
        diff = self.client.GetHeaderValue(2)  # 대비
        cVol = self.client.GetHeaderValue(17)  # 순간체결수량
        vol = self.client.GetHeaderValue(9)  # 거래량
 
        if (exFlag == ord('1')):  # 동시호가 시간 (예상체결)
            print("실시간(예상체결)", name, timess, "*", cprice, "대비", diff, "체결량", cVol, "거래량", vol)
        elif (exFlag == ord('2')):  # 장중(체결)
            print("실시간(장중 체결)", name, timess, cprice, "대비", diff, "체결량", cVol, "거래량", vol)

# %%
class CpStockCur:
    def Subscribe(self, code):
        self.objStockCur = win32com.client.Dispatch("DsCbo1.StockCur")
        handler = win32com.client.WithEvents(self.objStockCur, CpEvent)
        self.objStockCur.SetInputValue(0, code)
        handler.set_params(self.objStockCur)
        self.objStockCur.Subscribe()
 
    def Unsubscribe(self):
        self.objStockCur.Unsubscribe()

# %%
class MyWindow(QMainWindow):
 
    def __init__(self):
        super().__init__()
        self.setWindowTitle("PLUS API TEST")
        self.setGeometry(300, 300, 300, 150)
        self.isSB = False
        self.objStockCur1 = CpStockCur()
        self.objStockCur2 = CpStockCur()
        self.objStockCur3 = CpStockCur()
 
        btnStart = QPushButton("요청 시작", self)
        btnStart.move(20, 20)
        btnStart.clicked.connect(self.btnStart_clicked)
 
        btnStop = QPushButton("요청 종료", self)
        btnStop.move(20, 70)
        btnStop.clicked.connect(self.btnStop_clicked)
 
        btnExit = QPushButton("종료", self)
        btnExit.move(20, 120)
        btnExit.clicked.connect(self.btnExit_clicked)
 
    def StopSubscribe(self):
        if self.isSB:
            self.objStockCur1.Unsubscribe()
            self.objStockCur2.Unsubscribe()
            self.objStockCur3.Unsubscribe()
 
        self.isSB = False
 
    def btnStart_clicked(self):
        self.objStockCur1.Subscribe("A003540") # 대신증권
        self.objStockCur2.Subscribe("A000660") # 하이닉스
        self.objStockCur3.Subscribe("A005930") # 삼성전자
 
        print("빼기빼기================-")
        print("실시간 현재가 요청 시작")
        self.isSB = True
 
    def btnStop_clicked(self):
        self.StopSubscribe()
 
 
    def btnExit_clicked(self):
        self.StopSubscribe()
        exit()
 
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()
# Out:
# 빼기빼기================-
# 실시간 현재가 요청 시작
# 실시간(장중 체결) SK하이닉스 120205 115400 대비 600 체결량 17 거래량 1626854
# 실시간(장중 체결) SK하이닉스 120205 115300 대비 500 체결량 1 거래량 1626855
# 실시간(장중 체결) 삼성전자 120205 71000 대비 -200 체결량 5 거래량 5949942
# 실시간(장중 체결) SK하이닉스 120205 115300 대비 500 체결량 1 거래량 1626856
# 실시간(장중 체결) SK하이닉스 120206 115400 대비 600 체결량 4123 거래량 1630979
# 실시간(장중 체결) 삼성전자 120207 71000 대비 -200 체결량 4 거래량 5949946
# 실시간(장중 체결) SK하이닉스 120207 115500 대비 700 체결량 948 거래량 1631927
# 실시간(장중 체결) 삼성전자 120207 71000 대비 -200 체결량 4 거래량 5949950
# 실시간(장중 체결) SK하이닉스 120207 115500 대비 700 체결량 52 거래량 1631979
# 실시간(장중 체결) SK하이닉스 120208 115400 대비 600 체결량 8 거래량 1631987
# 실시간(장중 체결) SK하이닉스 120208 115500 대비 700 체결량 3 거래량 1631990
# 실시간(장중 체결) 삼성전자 120208 71000 대비 -200 체결량 1 거래량 5949951
# 실시간(장중 체결) SK하이닉스 120208 115500 대비 700 체결량 7 거래량 1631997
# 실시간(장중 체결) 삼성전자 120209 71000 대비 -200 체결량 10 거래량 5949961
# 실시간(장중 체결) 삼성전자 120209 71000 대비 -200 체결량 2 거래량 5949963
# 실시간(장중 체결) 삼성전자 120210 71000 대비 -200 체결량 112 거래량 5950075
# 실시간(장중 체결) 삼성전자 120211 71100 대비 -100 체결량 1 거래량 5950076
# 실시간(장중 체결) 삼성전자 120212 71000 대비 -200 체결량 2 거래량 5950078
# 실시간(장중 체결) SK하이닉스 120213 115500 대비 700 체결량 5 거래량 1632002
# 실시간(장중 체결) 삼성전자 120213 71100 대비 -100 체결량 1 거래량 5950079
# 실시간(장중 체결) 삼성전자 120213 71100 대비 -100 체결량 26 거래량 5950105
# 실시간(장중 체결) SK하이닉스 120213 115500 대비 700 체결량 4 거래량 1632014
# 실시간(장중 체결) SK하이닉스 120214 115500 대비 700 체결량 1 거래량 1632015
# 실시간(장중 체결) SK하이닉스 120214 115500 대비 700 체결량 25 거래량 1632040
# 실시간(장중 체결) 삼성전자 120214 71000 대비 -200 체결량 6 거래량 5950111
# 실시간(장중 체결) SK하이닉스 120214 115500 대비 700 체결량 75 거래량 1632115
# 실시간(장중 체결) SK하이닉스 120214 115500 대비 700 체결량 3 거래량 1632118
# 실시간(장중 체결) 삼성전자 120215 71100 대비 -100 체결량 2 거래량 5950113
# 실시간(장중 체결) SK하이닉스 120214 115500 대비 700 체결량 1 거래량 1632124
# 실시간(장중 체결) SK하이닉스 120215 115500 대비 700 체결량 12 거래량 1632136
# 실시간(장중 체결) SK하이닉스 120215 115500 대비 700 체결량 39 거래량 1632813
# 실시간(장중 체결) SK하이닉스 120215 115500 대비 700 체결량 481 거래량 1633294
# 실시간(장중 체결) 삼성전자 120215 71000 대비 -200 체결량 100 거래량 5950213
# 실시간(장중 체결) SK하이닉스 120215 115500 대비 700 체결량 6 거래량 1633300
# 실시간(장중 체결) SK하이닉스 120216 115500 대비 700 체결량 3 거래량 1633303
# 실시간(장중 체결) 삼성전자 120216 71100 대비 -100 체결량 1 거래량 5950214
# 실시간(장중 체결) 삼성전자 120216 71000 대비 -200 체결량 4 거래량 5950218
# 실시간(장중 체결) 삼성전자 120216 71000 대비 -200 체결량 2 거래량 5950220
# 실시간(장중 체결) 삼성전자 120217 71100 대비 -100 체결량 1 거래량 5950221
# 실시간(장중 체결) 삼성전자 120217 71100 대비 -100 체결량 1 거래량 5950222
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 3 거래량 1633306
# 실시간(장중 체결) 삼성전자 120217 71100 대비 -100 체결량 20 거래량 5950242
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 10 거래량 1633316
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 35 거래량 1633351
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 1 거래량 1633352
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 4 거래량 1633363
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 1 거래량 1633372
# 실시간(장중 체결) 삼성전자 120217 71000 대비 -200 체결량 5 거래량 5950247
# 실시간(장중 체결) SK하이닉스 120217 115500 대비 700 체결량 11 거래량 1633383
# 실시간(장중 체결) 삼성전자 120218 71000 대비 -200 체결량 5 거래량 5950252
# 실시간(장중 체결) 삼성전자 120218 71100 대비 -100 체결량 1 거래량 5950253
# 실시간(장중 체결) 삼성전자 120218 71000 대비 -200 체결량 59 거래량 5950312
# 실시간(장중 체결) 삼성전자 120218 71100 대비 -100 체결량 30 거래량 5950342
# 실시간(장중 체결) SK하이닉스 120219 115500 대비 700 체결량 9 거래량 1633392
# 실시간(장중 체결) SK하이닉스 120219 115500 대비 700 체결량 9 거래량 1633401
# 실시간(장중 체결) SK하이닉스 120219 115500 대비 700 체결량 9 거래량 1633410
# 실시간(장중 체결) 삼성전자 120219 71000 대비 -200 체결량 147 거래량 5950489
# 실시간(장중 체결) SK하이닉스 120219 115500 대비 700 체결량 2 거래량 1633412
# 실시간(장중 체결) SK하이닉스 120219 115400 대비 600 체결량 440 거래량 1633852
# 실시간(장중 체결) 삼성전자 120219 71000 대비 -200 체결량 71 거래량 5950560
# 실시간(장중 체결) SK하이닉스 120220 115500 대비 700 체결량 1 거래량 1633853
# 실시간(장중 체결) SK하이닉스 120220 115500 대비 700 체결량 1 거래량 1633854
# 실시간(장중 체결) 삼성전자 120220 71000 대비 -200 체결량 2 거래량 5950562
# 실시간(장중 체결) 대신증권 120220 13750 대비 0 체결량 1 거래량 16219
# 실시간(장중 체결) SK하이닉스 120221 115500 대비 700 체결량 2 거래량 1633856
# 실시간(장중 체결) 삼성전자 120221 71100 대비 -100 체결량 29 거래량 5950591
# 실시간(장중 체결) SK하이닉스 120221 115500 대비 700 체결량 1 거래량 1633857
# 실시간(장중 체결) SK하이닉스 120222 115500 대비 700 체결량 2 거래량 1633859
# 실시간(장중 체결) 삼성전자 120221 71100 대비 -100 체결량 7 거래량 5950598
# 실시간(장중 체결) 삼성전자 120222 71100 대비 -100 체결량 2 거래량 5950600
# 실시간(장중 체결) SK하이닉스 120222 115500 대비 700 체결량 24 거래량 1633883
# 실시간(장중 체결) SK하이닉스 120223 115500 대비 700 체결량 2 거래량 1633885
# 실시간(장중 체결) SK하이닉스 120224 115400 대비 600 체결량 8 거래량 1633893
# 실시간(장중 체결) 삼성전자 120224 71000 대비 -200 체결량 83 거래량 5950683
# 실시간(장중 체결) 삼성전자 120224 71000 대비 -200 체결량 1 거래량 5950684
# 실시간(장중 체결) 삼성전자 120227 71100 대비 -100 체결량 20 거래량 5950704
# 실시간(장중 체결) SK하이닉스 120227 115500 대비 700 체결량 3 거래량 1633896
# 실시간(장중 체결) 삼성전자 120228 71000 대비 -200 체결량 1 거래량 5950705
# 실시간(장중 체결) 삼성전자 120228 71000 대비 -200 체결량 1 거래량 5950706
# 실시간(장중 체결) SK하이닉스 120228 115500 대비 700 체결량 1 거래량 1633897
# 실시간(장중 체결) SK하이닉스 120228 115500 대비 700 체결량 1 거래량 1633898
# 실시간(장중 체결) SK하이닉스 120228 115500 대비 700 체결량 2 거래량 1633900
# 실시간(장중 체결) 삼성전자 120230 71000 대비 -200 체결량 4 거래량 5950710
# 실시간(장중 체결) SK하이닉스 120230 115500 대비 700 체결량 36 거래량 1633936
# 실시간(장중 체결) 삼성전자 120230 71000 대비 -200 체결량 123 거래량 5950833
# 실시간(장중 체결) SK하이닉스 120231 115400 대비 600 체결량 1 거래량 1633937
# 실시간(장중 체결) SK하이닉스 120231 115500 대비 700 체결량 5 거래량 1633942
# 실시간(장중 체결) SK하이닉스 120231 115400 대비 600 체결량 14 거래량 1633956
# 실시간(장중 체결) 삼성전자 120231 71000 대비 -200 체결량 50 거래량 5950883
# 실시간(장중 체결) 삼성전자 120231 71000 대비 -200 체결량 104 거래량 5950987
# 실시간(장중 체결) 삼성전자 120232 71000 대비 -200 체결량 14 거래량 5951001
# 실시간(장중 체결) SK하이닉스 120232 115500 대비 700 체결량 33 거래량 1633989
# 실시간(장중 체결) SK하이닉스 120232 115400 대비 600 체결량 1 거래량 1633990
# 실시간(장중 체결) 삼성전자 120233 71000 대비 -200 체결량 8 거래량 5951009
# 실시간(장중 체결) SK하이닉스 120233 115500 대비 700 체결량 2010 거래량 1636000
# 실시간(장중 체결) SK하이닉스 120233 115500 대비 700 체결량 5 거래량 1636005
# 실시간(장중 체결) SK하이닉스 120234 115500 대비 700 체결량 25 거래량 1636030
# 실시간(장중 체결) 삼성전자 120235 71000 대비 -200 체결량 1 거래량 5951010
# 실시간(장중 체결) SK하이닉스 120235 115600 대비 800 체결량 40 거래량 1636070
# 실시간(장중 체결) SK하이닉스 120235 115500 대비 700 체결량 45 거래량 1636115
# 실시간(장중 체결) SK하이닉스 120235 115600 대비 800 체결량 25 거래량 1636140
# 실시간(장중 체결) 삼성전자 120235 71000 대비 -200 체결량 1 거래량 5951011
# 실시간(장중 체결) 삼성전자 120236 71000 대비 -200 체결량 11 거래량 5951022
# 실시간(장중 체결) SK하이닉스 120236 115600 대비 800 체결량 200 거래량 1636340
# 실시간(장중 체결) SK하이닉스 120236 115600 대비 800 체결량 1 거래량 1636341
# 실시간(장중 체결) SK하이닉스 120236 115600 대비 800 체결량 23 거래량 1636364
# 실시간(장중 체결) 삼성전자 120237 71100 대비 -100 체결량 54 거래량 5951076
# 실시간(장중 체결) 삼성전자 120237 71000 대비 -200 체결량 13 거래량 5951089
# 실시간(장중 체결) SK하이닉스 120237 115600 대비 800 체결량 1 거래량 1636365
# 실시간(장중 체결) SK하이닉스 120238 115600 대비 800 체결량 1000 거래량 1637365
# 실시간(장중 체결) SK하이닉스 120239 115500 대비 700 체결량 6 거래량 1637371
# 실시간(장중 체결) 삼성전자 120240 71100 대비 -100 체결량 3884 거래량 5954973
# 실시간(장중 체결) SK하이닉스 120241 115600 대비 800 체결량 10 거래량 1637381
# 실시간(장중 체결) 삼성전자 120241 71100 대비 -100 체결량 228 거래량 5955201
# 실시간(장중 체결) SK하이닉스 120242 115500 대비 700 체결량 4 거래량 1637385
# 실시간(장중 체결) SK하이닉스 120242 115500 대비 700 체결량 3 거래량 1637388
# 실시간(장중 체결) SK하이닉스 120243 115600 대비 800 체결량 1 거래량 1637389
# 실시간(장중 체결) SK하이닉스 120244 115600 대비 800 체결량 2654 거래량 1640043
# 실시간(장중 체결) SK하이닉스 120244 115600 대비 800 체결량 2 거래량 1640045
# 실시간(장중 체결) SK하이닉스 120244 115600 대비 800 체결량 188 거래량 1640233
# 실시간(장중 체결) 삼성전자 120244 71100 대비 -100 체결량 2 거래량 5955203
# 실시간(장중 체결) SK하이닉스 120244 115700 대비 900 체결량 2 거래량 1640235
# 실시간(장중 체결) SK하이닉스 120244 115700 대비 900 체결량 2 거래량 1640237
# 실시간(장중 체결) 삼성전자 120244 71000 대비 -200 체결량 15 거래량 5955218
# 실시간(장중 체결) SK하이닉스 120244 115600 대비 800 체결량 2 거래량 1640239
# 실시간(장중 체결) SK하이닉스 120244 115700 대비 900 체결량 891 거래량 1641130
# 실시간(장중 체결) 삼성전자 120245 71000 대비 -200 체결량 5 거래량 5955223
# 실시간(장중 체결) 삼성전자 120245 71000 대비 -200 체결량 631 거래량 5955854
# 실시간(장중 체결) 삼성전자 120245 71000 대비 -200 체결량 114 거래량 5955968
# 실시간(장중 체결) SK하이닉스 120245 115700 대비 900 체결량 52 거래량 1641182
# 실시간(장중 체결) SK하이닉스 120246 115700 대비 900 체결량 8 거래량 1641190
# 실시간(장중 체결) SK하이닉스 120246 115700 대비 900 체결량 14 거래량 1641204
# 실시간(장중 체결) 삼성전자 120248 71000 대비 -200 체결량 1 거래량 5955969
# 실시간(장중 체결) 삼성전자 120250 71100 대비 -100 체결량 131 거래량 5956100
# 실시간(장중 체결) 삼성전자 120250 71000 대비 -200 체결량 2 거래량 5956102
# 실시간(장중 체결) SK하이닉스 120251 115700 대비 900 체결량 2 거래량 1641206
# 실시간(장중 체결) SK하이닉스 120251 115700 대비 900 체결량 2 거래량 1641208
# 실시간(장중 체결) SK하이닉스 120251 115700 대비 900 체결량 5 거래량 1641213
# 실시간(장중 체결) 삼성전자 120251 71000 대비 -200 체결량 1 거래량 5956103
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
