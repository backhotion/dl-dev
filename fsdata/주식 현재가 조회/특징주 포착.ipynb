# %%
import sys
from PyQt5.QtWidgets import *
import win32com.client
import ctypes
import pandas as pd
import os

# %%
g_objCodeMgr = win32com.client.Dispatch('CpUtil.CpCodeMgr')
g_objCpStatus = win32com.client.Dispatch('CpUtil.CpCybos')
g_objCpTrade = win32com.client.Dispatch('CpTrade.CpTdUtil')
 
gExcelFile = '특징주포착.csv'

# %%
def InitPlusCheck():
    # 프로세스가 관리자 권한으로 실행 여부
    if ctypes.windll.shell32.IsUserAnAdmin():
        print('정상: 관리자권한으로 실행된 프로세스입니다.')
    else:
        print('오류: 일반권한으로 실행됨. 관리자 권한으로 실행해 주세요')
        return False
 
    # 연결 여부 체크
    if (g_objCpStatus.IsConnect == 0):
        print("PLUS가 정상적으로 연결되지 않음. ")
        return False
 
    '''
    # 주문 관련 초기화
    if (g_objCpTrade.TradeInit(0) != 0):
        print("주문 초기화 실패")
        return False
    '''
    return True

# %%
# CpEvent: 실시간 이벤트 수신 클래스
class CpEvent:
    def set_params(self, client, name, caller):
        self.client = client  # CP 실시간 통신 object
        self.name = name  # 서비스가 다른 이벤트를 구분하기 위한 이름
        self.caller = caller  # callback 을 위해 보관
        self.diccode = {
            10: '외국계증권사창구첫매수',
            11: '외국계증권사창구첫매도',
            12: '외국인순매수',
            13: '외국인순매도',
            21: '전일거래량갱신',
            22: '최근5일거래량최고갱신',
            23: '최근5일매물대돌파',
            24: '최근60일매물대돌파',
            28: '최근5일첫상한가',
            29: '최근5일신고가갱신',
            30: '최근5일신저가갱신',
            31: '상한가직전',
            32: '하한가직전',
            41: '주가 5MA 상향돌파',
            42: '주가 5MA 하향돌파',
            43: '거래량 5MA 상향돌파',
            44: '주가데드크로스(5MA < 20MA)',
            45: '주가골든크로스(5MA > 20MA)',
            46: 'MACD 매수-Signal(9) 상향돌파',
            47: 'MACD 매도-Signal(9) 하향돌파',
            48: 'CCI 매수-기준선(-100) 상향돌파',
            49: 'CCI 매도-기준선(100) 하향돌파',
            50: 'Stochastic(10,5,5)매수- 기준선상향돌파',
            51: 'Stochastic(10,5,5)매도- 기준선하향돌파',
            52: 'Stochastic(10,5,5)매수- %K%D 교차',
            53: 'Stochastic(10,5,5)매도- %K%D 교차',
            54: 'Sonar 매수-Signal(9) 상향돌파',
            55: 'Sonar 매도-Signal(9) 하향돌파',
            56: 'Momentum 매수-기준선(100) 상향돌파',
            57: 'Momentum 매도-기준선(100) 하향돌파',
            58: 'RSI(14) 매수-Signal(9) 상향돌파',
            59: 'RSI(14) 매도-Signal(9) 하향돌파',
            60: 'Volume Oscillator 매수-Signal(9) 상향돌파',
            61: 'Volume Oscillator 매도-Signal(9) 하향돌파',
            62: 'Price roc 매수-Signal(9) 상향돌파',
            63: 'Price roc 매도-Signal(9) 하향돌파',
            64: '일목균형표매수-전환선 > 기준선상향교차',
            65: '일목균형표매도-전환선 < 기준선하향교차',
            66: '일목균형표매수-주가가선행스팬상향돌파',
            67: '일목균형표매도-주가가선행스팬하향돌파',
            68: '삼선전환도-양전환',
            69: '삼선전환도-음전환',
            70: '캔들패턴-상승반전형',
            71: '캔들패턴-하락반전형',
            81: '단기급락후 5MA 상향돌파',
            82: '주가이동평균밀집-5%이내',
            83: '눌림목재상승-20MA 지지'
        }

    def OnReceived(self):
        print(self.name)
        # 실시간 처리 - marketwatch : 특이 신호(차트, 외국인 순매수 등)
        if self.name == 'marketwatch':
            code = self.client.GetHeaderValue(0)
            name = g_objCodeMgr.CodeToName(code)
            cnt = self.client.GetHeaderValue(2)
 
            for i in range(cnt):
                item = {}
                newcancel = ''
                time = self.client.GetDataValue(0, i)
                h,m = divmod(time, 100)
                item['시간'] = '%02d:%02d' % (h,m)
                update = self.client.GetDataValue(1, i)
                item['코드'] = code
                item['종목명'] = name
                cate = self.client.GetDataValue(2, i)
                if (update == ord('c')):
                    newcancel =  '[취소]'
                if cate in self.diccode:
                    item['특이사항'] = newcancel + self.diccode[cate]
                else:
                    item['특이사항'] = newcancel + ''
 
                self.caller.listWatchData.insert(0,item)
                print(item)
 
        # 실시간 처리 - marketnews : 뉴스 및 공시 정보
        elif self.name == 'marketnews':
            item = {}
            update = self.client.GetHeaderValue(0)
            cont = ''
            if update == ord('D') :
                cont = '[삭제]'
            code = item['코드'] = self.client.GetHeaderValue(1)
            time = self.client.GetHeaderValue(2)
            h, m = divmod(time, 100)
            item['시간'] = '%02d:%02d' % (h, m)
            item['종목명'] = name = g_objCodeMgr.CodeToName(code)
            cate = self.client.GetHeaderValue(4)
            item['특이사항'] = cont + self.client.GetHeaderValue(5)
            print(item)
            self.caller.listWatchData.insert(0, item)

# %%
class CpPublish:
    def __init__(self, name, serviceID):
        self.name = name
        self.obj = win32com.client.Dispatch(serviceID)
        self.bIsSB = False
 
    def Subscribe(self, var, caller):
        if self.bIsSB:
            self.Unsubscribe()
 
        if (len(var) > 0):
            self.obj.SetInputValue(0, var)
 
        handler = win32com.client.WithEvents(self.obj, CpEvent)
        handler.set_params(self.obj, self.name, caller)
        self.obj.Subscribe()
        self.bIsSB = True
 
    def Unsubscribe(self):
        if self.bIsSB:
            self.obj.Unsubscribe()
        self.bIsSB = False
 
# CpPBMarkeWatch:
class CpPBMarkeWatch(CpPublish):
    def __init__(self):
        super().__init__('marketwatch', 'CpSysDib.CpMarketWatchS')
 
# CpPBMarkeWatch:
class CpPB8092news(CpPublish):
    def __init__(self):
        super().__init__('marketnews', 'Dscbo1.CpSvr8092S')

# %%
# CpRpMarketWatch : 특징주 포착 통신
class CpRpMarketWatch:
    def __init__(self):
        self.objStockMst = win32com.client.Dispatch('CpSysDib.CpMarketWatch')
        self.objpbMarket = CpPBMarkeWatch()
        self.objpbNews = CpPB8092news()
        return
 
    def Request(self, code, caller):
        self.objpbMarket.Unsubscribe()
        self.objpbNews.Unsubscribe()
 
        self.objStockMst.SetInputValue(0, code)
        # 1: 종목 뉴스 2: 공시정보 10: 외국계 창구첫매수, 11:첫매도 12 외국인 순매수 13 순매도
        rqField = '1,2,10,11,12,13'
        self.objStockMst.SetInputValue(1, rqField)
        self.objStockMst.SetInputValue(2, 0) # 시작 시간: 0 처음부터
 
        ret = self.objStockMst.BlockRequest()
        if self.objStockMst.GetDibStatus() != 0:
            print('통신상태', self.objStockMst.GetDibStatus(), self.objStockMst.GetDibMsg1())
            return False
 
        cnt = self.objStockMst.GetHeaderValue(2)  # 수신 개수
        for i in range(cnt):
            item = {}
 
            time  = self.objStockMst.GetDataValue(0, i)
            h, m = divmod(time, 100)
            item['시간'] = '%02d:%02d' % (h, m)
            item['코드'] = self.objStockMst.GetDataValue(1, i)
            item['종목명'] = g_objCodeMgr.CodeToName(item['코드'])
            cate = self.objStockMst.GetDataValue(3, i)
            item['특이사항'] = self.objStockMst.GetDataValue(4, i)
            print(item)
            caller.listWatchData.append(item)
 
        self.objpbMarket.Subscribe(code, caller)
        self.objpbNews.Subscribe(code, caller)
 
        return True

# %%
class MyWindow(QMainWindow):
    def __init__(self):
        super().__init__()
 
        # plus 상태 체크
        if InitPlusCheck() == False:
            exit()
 
        self.listWatchData = []
        self.objMarketWatch = CpRpMarketWatch()
 
        self.setWindowTitle("특징주 포착(#8092 Market-Watch")
        self.setGeometry(300, 300, 300, 180)
 
        nH = 20
 
        btnPrint = QPushButton('Print', self)
        btnPrint.move(20, nH)
        btnPrint.clicked.connect(self.btnPrint_clicked)
        nH += 50
 
        btnExcel = QPushButton('Excel 내보내기', self)
        btnExcel.move(20, nH)
        btnExcel.clicked.connect(self.btnExcel_clicked)
        nH += 50
 
 
        btnExit = QPushButton('종료', self)
        btnExit.move(20, nH)
        btnExit.clicked.connect(self.btnExit_clicked)
        nH += 50
 
        self.objMarketWatch.Request('*', self)
 
 
    def btnPrint_clicked(self):
        for item in self.listWatchData:
            print(item)
        return
 
    def btnExcel_clicked(self):
 
        if (len(self.listWatchData) == 0):
            print('데이터 없음')
            return
 
        df = pd.DataFrame(columns=['시간', '코드', '종목명', '특이사항'])
 
        for item in self.listWatchData:
            df.loc[len(df)] = item
 
        writer = pd.ExcelWriter(gExcelFile, engine='xlsxwriter')
        # Convert the dataframe to an XlsxWriter Excel object.
        df.to_excel(writer, sheet_name='Sheet1')
        # Close the Pandas Excel writer and output the Excel file.
        writer.save()
        os.startfile(gExcelFile)
        return
 
 
    def btnExit_clicked(self):
        exit()
        return

# %%
if __name__ == "__main__":
    app = QApplication(sys.argv)
    myWindow = MyWindow()
    myWindow.show()
    app.exec_()
# Out:
# 정상: 관리자권한으로 실행된 프로세스입니다.
# {'시간': '10:23', '코드': 'A021240', '종목명': '코웨이', '특이사항': "코웨이, '2023 대한민국 혁신대상 신기술혁신상' 수상"}
# {'시간': '10:23', '코드': 'A272210', '종목명': '한화시스템', '특이사항': '한화시스템, 레오나르도와 AESA레이다 개발·수출 ‘맞손’'}
# {'시간': '10:23', '코드': 'A208370', '종목명': '셀바스헬스케어', '특이사항': '셀바스헬스케어, 구주주 유상증자 청약률 99.41%'}
# {'시간': '10:23', '코드': 'A000480', '종목명': '조선내화', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A002150', '종목명': '도화엔지니어링', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A007280', '종목명': '한국특강', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A079160', '종목명': 'CJ CGV', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A241560', '종목명': '두산밥캣', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A089010', '종목명': '켐트로닉스', '특이사항': '켐트로닉스(089010) 소폭 상승세 +3.02%'}
# {'시간': '10:23', '코드': 'A900250', '종목명': '크리스탈신소재', '특이사항': '크리스탈신소재(900250) 소폭 상승세 +3.26%'}
# {'시간': '10:23', '코드': 'A078340', '종목명': '컴투스', '특이사항': '컴투스, 149억원 규모 배당 계획···"주주가치 제고 정책"'}
# {'시간': '10:23', '코드': 'A003490', '종목명': '대한항공', '특이사항': '\'취임 1년\' 강석훈 산은 회장 "대한항공·아시아나 합병 3분기 중 결론"'}
# {'시간': '10:23', '코드': 'A011200', '종목명': 'HMM', '특이사항': '\'취임 1년\' 강석훈 산은 회장 "대한항공·아시아나 합병 3분기 중 결론"'}
# {'시간': '10:23', '코드': 'A204840', '종목명': '지엘팜텍', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# {'시간': '10:23', '코드': 'A151910', '종목명': 'SBW생명과학', '특이사항': '외국계증권사 창구 첫 매수 포착'}
# {'시간': '10:22', '코드': 'A069960', '종목명': '현대백화점', '특이사항': '현대백화점, 친환경 쇼핑백으로 나무 2만 그루 보호'}
# {'시간': '10:22', '코드': 'A000660', '종목명': 'SK하이닉스', '특이사항': 'SK하이닉스, 실리콘밸리서 미래 인재 찾는다'}
# {'시간': '10:22', '코드': 'A060260', '종목명': '뉴보텍', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# {'시간': '10:22', '코드': 'A068760', '종목명': '셀트리온제약', '특이사항': '외국계증권사 창구 첫 매수 포착'}
# {'시간': '10:21', '코드': 'A069620', '종목명': '대웅제약', '특이사항': '대웅제약, 위식도역류질환 신약 처방액 300억원 돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A086040', '종목명': '바이오톡스텍', '특이사항': '삼선전환도-양전환'}
# {'시간': '10:24', '코드': 'A086040', '종목명': '바이오톡스텍', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A251340', '종목명': 'KODEX 코스닥150선물인버스', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A100090', '종목명': 'SK오션플랜트', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:24', '코드': 'A100090', '종목명': 'SK오션플랜트', '특이사항': '주가이동평균밀집-5%이내'}
# marketwatch
# {'시간': '10:13', '코드': 'A347890', '종목명': '엠투아이', '특이사항': '[취소]일목균형표매수-주가가선행스팬상향돌파'}
# marketwatch
# {'시간': '10:19', '코드': 'A028670', '종목명': '팬오션', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A086390', '종목명': '유니테스트', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A058400', '종목명': 'KNN', '특이사항': '삼선전환도-양전환'}
# marketwatch
# {'시간': '10:24', '코드': 'A100590', '종목명': '머큐리', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:24', '코드': 'A100590', '종목명': '머큐리', '특이사항': 'Stochastic(10,5,5)매도- %K%D 교차'}
# {'시간': '10:24', '코드': 'A100590', '종목명': '머큐리', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:20', '코드': 'A100590', '종목명': '머큐리', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:23', '코드': 'Q530031', '종목명': '삼성 레버리지 WTI원유 선물 ETN', '특이사항': '[취소]최근60일매물대돌파'}
# marketwatch
# {'시간': '10:06', '코드': 'A086820', '종목명': '바이오솔루션', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': '주가 5MA 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A187420', '종목명': '제노포커스', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '10:24', '코드': 'A455850', '종목명': 'SOL 반도체소부장Fn', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A005387', '종목명': '현대차2우B', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '10:20', '코드': 'A005387', '종목명': '현대차2우B', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A252990', '종목명': '샘씨엔에스', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A086960', '종목명': 'MDS테크', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '09:02', '코드': 'A253450', '종목명': '스튜디오드래곤', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:24', '코드': 'A253450', '종목명': '스튜디오드래곤', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:19', '코드': 'A058730', '종목명': '다스코', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A101170', '종목명': '우림피티에스', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:16', '코드': 'A101170', '종목명': '우림피티에스', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A253590', '종목명': '네오셈', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A058850', '종목명': 'KTcs', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A030530', '종목명': '원익홀딩스', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:24', '코드': 'A030530', '종목명': '원익홀딩스', '특이사항': 'Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A352820', '종목명': '하이브', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A189860', '종목명': '서전기전', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:20', '코드': 'A189860', '종목명': '서전기전', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:16', '코드': 'A189980', '종목명': '흥국에프엔비', '특이사항': '[취소]MACD 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A101400', '종목명': '엔시트론', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A256150', '종목명': '한독크린텍', '특이사항': '최근60일매물대돌파'}
# {'시간': '10:24', '코드': 'A256150', '종목명': '한독크린텍', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A191410', '종목명': '육일씨엔에쓰', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '10:24', '코드': 'A059270', '종목명': '해성티피씨', '특이사항': 'Stochastic(10,5,5)매도- 기준선하향돌파'}
# {'시간': '10:24', '코드': 'A059270', '종목명': '해성티피씨', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A088800', '종목명': '에이스테크', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A192230', '종목명': '아리바이오', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:24', '코드': 'A192230', '종목명': '아리바이오', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A192230', '종목명': '아리바이오', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A256940', '종목명': '케이피에스', '특이사항': '삼선전환도-음전환'}
# marketwatch
# {'시간': '10:12', '코드': 'A101730', '종목명': '위메이드맥스', '특이사항': '[취소]삼선전환도-양전환'}
# marketwatch
# {'시간': '10:21', '코드': 'A354350', '종목명': 'HANARO 글로벌럭셔리S&P(합성)', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:16', '코드': 'A005740', '종목명': '크라운해태홀딩스', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:24', '코드': 'A005740', '종목명': '크라운해태홀딩스', '특이사항': 'Stochastic(10,5,5)매수- %K%D 교차'}
# {'시간': '10:24', '코드': 'A005740', '종목명': '크라운해태홀딩스', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A192250', '종목명': '케이사인', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A356680', '종목명': '엑스게이트', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A032620', '종목명': '유비케어', '특이사항': '최근60일매물대돌파'}
# marketwatch
# {'시간': '09:32', '코드': 'A900100', '종목명': '애머릿지', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A032640', '종목명': 'LG유플러스', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '09:05', '코드': 'A102370', '종목명': '케이옥션', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'Q570082', '종목명': 'TRUE 인버스 2X 코스닥 150 선물 ETN', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A089230', '종목명': 'THE E&M', '특이사항': '최근5일신고가갱신'}
# {'시간': '10:24', '코드': 'A089230', '종목명': 'THE E&M', '특이사항': 'Stochastic(10,5,5)매수- %K%D 교차'}
# {'시간': '10:01', '코드': 'A089230', '종목명': 'THE E&M', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A089470', '종목명': 'HDC현대EP', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '09:53', '코드': 'A260870', '종목명': 'SK시그넷', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A102710', '종목명': '이엔에프테크놀로지', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A005870', '종목명': '휴니드', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A900250', '종목명': '크리스탈신소재', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '09:59', '코드': 'A005880', '종목명': '대한해운', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:24', '코드': 'A007980', '종목명': '태평양물산', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A357870', '종목명': 'TIGER CD금리투자KIS(합성)', '특이사항': '거래량 5MA 상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A900270', '종목명': '헝셩그룹', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A089850', '종목명': '유비벨록스', '특이사항': '최근5일거래량최고갱신'}
# {'시간': '10:06', '코드': 'A089850', '종목명': '유비벨록스', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:06', '코드': 'A089850', '종목명': '유비벨록스', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A089850', '종목명': '유비벨록스', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:24', '코드': 'A008110', '종목명': '대동전자', '특이사항': 'Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:24', '코드': 'A261200', '종목명': '덴티스', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:24', '코드': 'A261200', '종목명': '덴티스', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketnews
# {'코드': 'A290690', '시간': '10:24', '종목명': '소룩스', '특이사항': '[특징주]소룩스, 아리바이오 치매 신약 美FDA 이어 국내 3임상 신청 소식에↑'}
# marketwatch
# {'시간': '10:09', '코드': 'A360140', '종목명': 'KODEX 200롱코스닥150숏선물', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '09:29', '코드': 'A900300', '종목명': '오가닉티코스메틱', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:22', '코드': 'A900300', '종목명': '오가닉티코스메틱', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:14', '코드': 'A900310', '종목명': '컬러레이', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A032980', '종목명': '바이온', '특이사항': '[취소]일목균형표매수-주가가선행스팬상향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A090080', '종목명': '평화산업', '특이사항': '일목균형표매도-주가가선행스팬하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A008350', '종목명': '남선알미늄', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A196030', '종목명': 'ACE 일본TOPIX레버리지(H)', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A361390', '종목명': '제노코', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A361390', '종목명': '제노코', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A033100', '종목명': '제룡전기', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A006050', '종목명': '국영지앤엠', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:17', '코드': 'A196230', '종목명': 'KBSTAR 단기통안채', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:24', '코드': 'A008420', '종목명': '문배철강', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:20', '코드': 'A008470', '종목명': '부스타', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:15', '코드': 'A090410', '종목명': '덕신하우징', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '09:55', '코드': 'A950200', '종목명': '소마젠', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A363250', '종목명': '진시스템', '특이사항': '거래량 5MA 상향돌파'}
# {'시간': '10:17', '코드': 'A363250', '종목명': '진시스템', '특이사항': '[취소]주가데드크로스(5MA < 20MA)'}
# marketwatch
# {'시간': '10:25', '코드': 'A104620', '종목명': '노랑풍선', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A363260', '종목명': '모비데이즈', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:11', '코드': 'A090470', '종목명': '제이스텍', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:14', '코드': 'A263750', '종목명': '펄어비스', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A263770', '종목명': '유에스티', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A364980', '종목명': 'TIGER KRX2차전지K-뉴딜', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A199820', '종목명': '제일전기공업', '특이사항': '[취소]Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A009150', '종목명': '삼성전기', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A263860', '종목명': '지니언스', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A395760', '종목명': 'ARIRANG ESG성장주액티브', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:25', '코드': 'A395760', '종목명': 'ARIRANG ESG성장주액티브', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A009155', '종목명': '삼성전기우', '특이사항': '일목균형표매도-주가가선행스팬하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A396300', '종목명': '세아메카닉스', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:22', '코드': 'A396300', '종목명': '세아메카닉스', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A091230', '종목명': 'TIGER 반도체', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A009180', '종목명': '한솔로지스틱스', '특이사항': '[취소]Volume Oscillator 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A091340', '종목명': 'S&K폴리텍', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:05', '코드': 'A106080', '종목명': '하이소닉', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '09:51', '코드': 'A365590', '종목명': '하이딥', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A006570', '종목명': '대림통상', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A396520', '종목명': 'TIGER 차이나반도체FACTSET', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A365900', '종목명': '브이씨', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A365900', '종목명': '브이씨', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:25', '코드': 'A365900', '종목명': '브이씨', '특이사항': '삼선전환도-양전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A006650', '종목명': '대한유화', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '09:11', '코드': 'A397410', '종목명': 'KBSTAR 국채선물5년추종인버스', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A397410', '종목명': 'KBSTAR 국채선물5년추종인버스', '특이사항': 'Stochastic(10,5,5)매도- 기준선하향돌파'}
# {'시간': '10:25', '코드': 'A397410', '종목명': 'KBSTAR 국채선물5년추종인버스', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A091590', '종목명': '남화토건', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A009270', '종목명': '신원', '특이사항': 'Stochastic(10,5,5)매수- %K%D 교차'}
# {'시간': '10:25', '코드': 'A009270', '종목명': '신원', '특이사항': '캔들패턴-상승반전형'}
# {'시간': '10:20', '코드': 'A009270', '종목명': '신원', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:09', '코드': 'A200880', '종목명': '서연이화', '특이사항': '[취소]삼선전환도-양전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A265560', '종목명': '영화테크', '특이사항': 'Stochastic(10,5,5)매수- %K%D 교차'}
# marketnews
# {'코드': 'A322310', '시간': '10:18', '종목명': '오로스테크놀로지', '특이사항': '[장중수급포착] 오로스테크놀로지, 외국인 5일 연속 순매수행진... 주가 +1.55%'}
# marketnews
# {'코드': 'A036200', '시간': '10:18', '종목명': '유니셈', '특이사항': '[장중수급포착] 유니셈, 외국인 5일 연속 순매수행진... 주가 +1.29%'}
# marketwatch
# {'시간': '10:20', '코드': 'A091810', '종목명': '티웨이항공', '특이사항': '[취소]Stochastic(10,5,5)매도- %K%D 교차'}
# marketwatch
# {'시간': '10:20', '코드': 'A034300', '종목명': '신세계건설', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A00680K', '종목명': '미래에셋증권2우B', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '09:08', '코드': 'A034310', '종목명': 'NICE', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A203650', '종목명': '드림시큐리티', '특이사항': '최근60일매물대돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A108670', '종목명': 'LX하우시스', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:11', '코드': 'A03473K', '종목명': 'SK우', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A092130', '종목명': '이크레더블', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'Q530107', '종목명': '삼성 인버스 2X 코스닥150 선물 ETN', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A204020', '종목명': '그리티', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:16', '코드': 'A092190', '종목명': '서울바이오시스', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '09:40', '코드': 'Q570070', '종목명': 'TRUE 인버스 2X 플래티넘 선물 ETN', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A267290', '종목명': '경동도시가스', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:25', '코드': 'A267290', '종목명': '경동도시가스', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A368600', '종목명': '아이씨에이치', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A401170', '종목명': 'KBSTAR iSelect메타버스', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A204270', '종목명': '제이앤티씨', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A109610', '종목명': '에스와이', '특이사항': '최근5일매물대돌파'}
# marketnews
# {'코드': 'A069960', '시간': '10:25', '종목명': '현대백화점', '특이사항': '[게시판] 현대백화점, 서울관광재단과 축제활성화 업무협약'}
# marketwatch
# {'시간': '10:21', '코드': 'A368970', '종목명': '오에스피', '특이사항': '[취소]삼선전환도-음전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A007070', '종목명': 'GS리테일', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '09:14', '코드': 'A109820', '종목명': '진매트릭스', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A369370', '종목명': '블리츠웨이', '특이사항': '최근5일신고가갱신'}
# {'시간': '10:25', '코드': 'A369370', '종목명': '블리츠웨이', '특이사항': '주가 5MA 상향돌파'}
# {'시간': '10:25', '코드': 'A369370', '종목명': '블리츠웨이', '특이사항': 'Stochastic(10,5,5)매수- 기준선상향돌파'}
# {'시간': '10:25', '코드': 'A369370', '종목명': '블리츠웨이', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# {'시간': '10:25', '코드': 'A369370', '종목명': '블리츠웨이', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'Q500014', '종목명': '신한 인버스 옥수수 선물 ETN(H)', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A110790', '종목명': '크리스에프앤씨', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A371450', '종목명': 'TIGER 글로벌클라우드컴퓨팅INDXX', '특이사항': '캔들패턴-하락반전형'}
# marketnews
# {'코드': 'A019170', '시간': '10:24', '종목명': '신풍제약', '특이사항': '<유>신풍제약, 장중 신저가 기록.. 16,350→16,130(▼220)'}
# marketwatch
# {'시간': '10:25', '코드': 'A009680', '종목명': '모토닉', '특이사항': 'Stochastic(10,5,5)매도- 기준선하향돌파'}
# marketwatch
# {'시간': '10:18', '코드': 'A371470', '종목명': 'TIGER 차이나바이오테크SOLACTIVE', '특이사항': '[취소]Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A405100', '종목명': '큐알티', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:58', '코드': 'A405640', '종목명': '신한제9호스팩', '특이사항': '[취소]Stochastic(10,5,5)매도- %K%D 교차'}
# marketwatch
# {'시간': '10:25', '코드': 'A270870', '종목명': '뉴트리', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:25', '코드': 'A270870', '종목명': '뉴트리', '특이사항': '[취소]일목균형표매수-전환선 > 기준선상향교차'}
# marketwatch
# {'시간': '10:25', '코드': 'Q530107', '종목명': '삼성 인버스 2X 코스닥150 선물 ETN', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A206400', '종목명': '베노홀딩스', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A372800', '종목명': '아이티아이즈', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A206560', '종목명': '덱스터', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A009900', '종목명': '명신산업', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:25', '코드': 'A009900', '종목명': '명신산업', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A206640', '종목명': '바디텍메드', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:21', '코드': 'A206640', '종목명': '바디텍메드', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '09:03', '코드': 'A271560', '종목명': '오리온', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A007690', '종목명': '국도화학', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:21', '코드': 'A007690', '종목명': '국도화학', '특이사항': '[취소]CCI 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'Q530031', '종목명': '삼성 레버리지 WTI원유 선물 ETN', '특이사항': '최근60일매물대돌파'}
# marketwatch
# {'시간': '09:16', '코드': 'A093640', '종목명': '케이알엠', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A207760', '종목명': '미스터블루', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:25', '코드': 'A207760', '종목명': '미스터블루', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:18', '코드': 'A271940', '종목명': '일진하이솔루스', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A373490', '종목명': 'KODEX K-이노베이션액티브', '특이사항': '주가 5MA 하향돌파'}
# marketnews
# {'코드': 'A127980', '시간': '10:25', '종목명': '화인써키트', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# marketwatch
# {'시간': '10:20', '코드': 'Q530099', '종목명': '삼성 블룸버그 레버리지 WTI원유 선물 ETN', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A207940', '종목명': '삼성바이오로직스', '특이사항': '주가이동평균밀집-5%이내'}
# marketwatch
# {'시간': '10:25', '코드': 'A007720', '종목명': '대명소노시즌', '특이사항': '주가 5MA 하향돌파'}
# marketnews
# {'코드': 'A131100', '시간': '10:25', '종목명': '초록뱀이앤엠', '특이사항': '외국계증권사 창구 첫 매수 포착'}
# marketwatch
# {'시간': '10:25', '코드': 'A094170', '종목명': '동운아나텍', '특이사항': '상한가직전'}
# marketwatch
# {'시간': '10:10', '코드': 'A208140', '종목명': '정다운', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:10', '코드': 'A208140', '종목명': '정다운', '특이사항': '[취소]삼선전환도-음전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A409820', '종목명': 'KODEX 미국나스닥100레버리지(합성 H)', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A114460', '종목명': 'ACE 국고채3년', '특이사항': '[취소]삼선전환도-양전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A411050', '종목명': 'ACE 글로벌메타버스테크액티브', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'Q500066', '종목명': '신한 블룸버그 인버스 2X WTI원유 선물 ETN', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A114630', '종목명': '폴라리스우노', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A411060', '종목명': 'ACE KRX금현물', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A036000', '종목명': '예림당', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A272550', '종목명': '삼양패키징', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:02', '코드': 'A094820', '종목명': '일진파워', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:22', '코드': 'A272580', '종목명': 'TIGER 단기채권액티브', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:22', '코드': 'A272580', '종목명': 'TIGER 단기채권액티브', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A036030', '종목명': '케이티알파', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A036030', '종목명': '케이티알파', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:20', '코드': 'A036030', '종목명': '케이티알파', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A273060', '종목명': '와이즈버즈', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:18', '코드': 'A376410', '종목명': 'TIGER 탄소효율그린뉴딜', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A036090', '종목명': '위지트', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A000070', '종목명': '삼양홀딩스', '특이사항': '일목균형표매도-주가가선행스팬하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A114840', '종목명': '아이패밀리에스씨', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A036120', '종목명': 'SCI평가정보', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A412770', '종목명': 'TIGER 글로벌메타버스액티브', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A094860', '종목명': '네오리진', '특이사항': '[취소]CCI 매수-기준선(-100) 상향돌파'}
# {'시간': '10:25', '코드': 'A094860', '종목명': '네오리진', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:21', '코드': 'A094860', '종목명': '네오리진', '특이사항': '[취소]삼선전환도-음전환'}
# marketwatch
# {'시간': '09:29', '코드': 'A000080', '종목명': '하이트진로', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# {'시간': '10:25', '코드': 'A000080', '종목명': '하이트진로', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A010280', '종목명': '쌍용정보통신', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A036170', '종목명': '클라우드에어', '특이사항': '최근60일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A094940', '종목명': '푸른기술', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'Q530100', '종목명': '삼성 블룸버그 인버스 2X WTI원유 선물 ETN', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '09:57', '코드': 'A036200', '종목명': '유니셈', '특이사항': '[취소]삼선전환도-양전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A417010', '종목명': '나노팀', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A000150', '종목명': '두산', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A417180', '종목명': '핑거스토리', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A275750', '종목명': 'KBSTAR 코스닥150선물인버스', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A000180', '종목명': '성창기업지주', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:25', '코드': 'A000180', '종목명': '성창기업지주', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A010620', '종목명': '현대미포조선', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A377450', '종목명': '리파인', '특이사항': '[취소]주가이동평균밀집-5%이내'}
# marketwatch
# {'시간': '10:21', '코드': 'A036480', '종목명': '대성미생물', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '10:21', '코드': 'A036480', '종목명': '대성미생물', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A417630', '종목명': 'TIGER KEDI혁신기업ESG30', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A036530', '종목명': 'SNT홀딩스', '특이사항': '[취소]Stochastic(10,5,5)매도- %K%D 교차'}
# {'시간': '10:21', '코드': 'A036530', '종목명': 'SNT홀딩스', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '09:49', '코드': 'A010690', '종목명': '화신', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A010690', '종목명': '화신', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:22', '코드': 'A276730', '종목명': '제주맥주', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A276730', '종목명': '제주맥주', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A036560', '종목명': '영풍정밀', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A010770', '종목명': '평화홀딩스', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'Q700016', '종목명': '하나 S&P 인버스 2X WTI원유 선물 ETN', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A378800', '종목명': '샤페론', '특이사항': '[취소]Volume Oscillator 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A095910', '종목명': '에스에너지', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A000250', '종목명': '삼천당제약', '특이사항': '거래량 5MA 상향돌파'}
# {'시간': '10:25', '코드': 'A000250', '종목명': '삼천당제약', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:25', '코드': 'A000250', '종목명': '삼천당제약', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A117580', '종목명': '대성에너지', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A000270', '종목명': '기아', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:37', '코드': 'A277540', '종목명': 'ACE 아시아TOP50S&P', '특이사항': '[취소]최근60일매물대돌파'}
# marketwatch
# {'시간': '10:09', '코드': 'A117700', '종목명': 'KODEX 건설', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '09:25', '코드': 'A379790', '종목명': 'KBSTAR 유로스탁스50(H)', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A379790', '종목명': 'KBSTAR 유로스탁스50(H)', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# {'시간': '10:25', '코드': 'A379790', '종목명': 'KBSTAR 유로스탁스50(H)', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A000320', '종목명': '노루홀딩스', '특이사항': '[취소]삼선전환도-양전환'}
# marketwatch
# {'시간': '10:25', '코드': 'A277810', '종목명': '레인보우로보틱스', '특이사항': '최근5일거래량최고갱신'}
# {'시간': '10:25', '코드': 'A277810', '종목명': '레인보우로보틱스', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:06', '코드': 'A036670', '종목명': 'KCI', '특이사항': '[취소]Stochastic(10,5,5)매도- 기준선하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A419050', '종목명': '삼기이브이', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A419080', '종목명': '엔젯', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '09:03', '코드': 'A214430', '종목명': '아이쓰리시스템', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A119500', '종목명': '포메탈', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:13', '코드': 'A119500', '종목명': '포메탈', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:13', '코드': 'A119500', '종목명': '포메탈', '특이사항': '[취소]주가이동평균밀집-5%이내'}
# marketwatch
# {'시간': '10:21', '코드': 'A036800', '종목명': '나이스정보통신', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'A419170', '종목명': 'HANARO 미국메타버스iSelect', '특이사항': '최근5일신고가갱신'}
# marketwatch
# {'시간': '10:25', '코드': 'A000440', '종목명': '중앙에너비스', '특이사항': '주가데드크로스(5MA < 20MA)'}
# marketwatch
# {'시간': '10:25', '코드': 'A119650', '종목명': 'KC코트렐', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:18', '코드': 'A214980', '종목명': 'KODEX 단기채권PLUS', '특이사항': '[취소]Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:25', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '최근5일신저가갱신'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]주가골든크로스(5MA > 20MA)'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]MACD 매수-Signal(9) 상향돌파'}
# {'시간': '10:25', '코드': 'A279060', '종목명': '이노벡스', '특이사항': 'Stochastic(10,5,5)매도- %K%D 교차'}
# {'시간': '10:25', '코드': 'A279060', '종목명': '이노벡스', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]일목균형표매수-주가가선행스팬상향돌파'}
# {'시간': '09:48', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '[취소]주가이동평균밀집-5%이내'}
# {'시간': '10:25', '코드': 'A279060', '종목명': '이노벡스', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:23', '코드': 'Q500019', '종목명': '신한 레버리지 WTI원유 선물 ETN(H)', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A119830', '종목명': '아이텍', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A419530', '종목명': 'SAMG엔터', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:16', '코드': 'A060480', '종목명': '국일신동', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A215000', '종목명': '골프존', '특이사항': '주가데드크로스(5MA < 20MA)'}
# marketwatch
# {'시간': '10:25', '코드': 'A381970', '종목명': '케이카', '특이사항': 'CCI 매도-기준선(100) 하향돌파'}
# {'시간': '10:25', '코드': 'A381970', '종목명': '케이카', '특이사항': 'Stochastic(10,5,5)매도- %K%D 교차'}
# marketwatch
# {'시간': '10:25', '코드': 'A419540', '종목명': '비스토스', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A060540', '종목명': '에스에이티', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:13', '코드': 'A000520', '종목명': '삼일제약', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:25', '코드': 'A060560', '종목명': '홈센타홀딩스', '특이사항': '주가골든크로스(5MA > 20MA)'}
# marketwatch
# {'시간': '10:25', '코드': 'A215360', '종목명': '우리산업', '특이사항': '최근5일신고가갱신'}
# marketwatch
# {'시간': '10:16', '코드': 'A037230', '종목명': '한국팩키지', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A011280', '종목명': '태림포장', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# {'시간': '10:26', '코드': 'A011280', '종목명': '태림포장', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A000660', '종목명': 'SK하이닉스', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A383310', '종목명': '에코프로에이치엔', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A121600', '종목명': '나노신소재', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '09:19', '코드': 'A037370', '종목명': 'EG', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:26', '코드': 'A037370', '종목명': 'EG', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:18', '코드': 'A423920', '종목명': 'TIGER 미국필라델피아반도체레버리지(합성)', '특이사항': '[취소]Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A061040', '종목명': '알에프텍', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketnews
# {'코드': 'A275630', '시간': '10:26', '종목명': '에스에스알', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# marketwatch
# {'시간': '10:26', '코드': 'A011370', '종목명': '서한', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# {'시간': '10:26', '코드': 'A011370', '종목명': '서한', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A037400', '종목명': '우리엔터프라이즈', '특이사항': '주가 5MA 상향돌파'}
# {'시간': '09:38', '코드': 'A037400', '종목명': '우리엔터프라이즈', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A000700', '종목명': '유수홀딩스', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A061250', '종목명': '화일약품', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A283580', '종목명': 'KODEX 차이나CSI300', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A122350', '종목명': '삼기', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A284430', '종목명': 'KODEX 200미국채혼합', '특이사항': '삼선전환도-양전환'}
# marketwatch
# {'시간': '10:01', '코드': 'A122450', '종목명': 'KX', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:01', '코드': 'A122450', '종목명': 'KX', '특이사항': '[취소]삼선전환도-양전환'}
# marketwatch
# {'시간': '10:26', '코드': 'A037460', '종목명': '삼지전자', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:26', '코드': 'A037460', '종목명': '삼지전자', '특이사항': 'Stochastic(10,5,5)매도- %K%D 교차'}
# {'시간': '10:26', '코드': 'A037460', '종목명': '삼지전자', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:54', '코드': 'A011690', '종목명': '와이투솔루션', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:17', '코드': 'A011690', '종목명': '와이투솔루션', '특이사항': '[취소]최근60일매물대돌파'}
# marketwatch
# {'시간': '10:07', '코드': 'A385600', '종목명': 'ACE 2차전지&친환경차액티브', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketnews
# {'코드': 'A196170', '시간': '10:26', '종목명': '알테오젠', '특이사항': '코스닥, 외국인 매물 출회 확대…880선 위협'}
# marketwatch
# {'시간': '10:26', '코드': 'A037760', '종목명': '쎄니트', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:23', '코드': 'A430220', '종목명': '신영스팩8호', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:23', '코드': 'A430220', '종목명': '신영스팩8호', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# {'시간': '10:23', '코드': 'A430220', '종목명': '신영스팩8호', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A037950', '종목명': '엘컴텍', '특이사항': '[취소]Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A285490', '종목명': '노바텍', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A122870', '종목명': '와이지엔터테인먼트', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A387270', '종목명': 'TIGER 글로벌BBIG액티브', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A038060', '종목명': '루멘스', '특이사항': '삼선전환도-음전환'}
# {'시간': '10:21', '코드': 'A038060', '종목명': '루멘스', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketnews
# {'코드': 'A170030', '시간': '10:26', '종목명': '현대공업', '특이사항': '현대공업, 분리막·실리콘 음극재·전고체 업체 이어 전기차 밸류체인 투자 확'}
# marketwatch
# {'시간': '10:26', '코드': 'A218150', '종목명': '미래생명자원', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A387280', '종목명': 'TIGER 퓨처모빌리티액티브', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'Q580046', '종목명': 'KB 블룸버그 인버스2X 천연가스선물 ETN(H)', '특이사항': '주가 5MA 상향돌파'}
# {'시간': '10:26', '코드': 'Q580046', '종목명': 'KB 블룸버그 인버스2X 천연가스선물 ETN(H)', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A000890', '종목명': '보해양조', '특이사항': '주가데드크로스(5MA < 20MA)'}
# marketwatch
# {'시간': '10:03', '코드': 'A064090', '종목명': '웨스트라이즈', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:18', '코드': 'A388050', '종목명': '지투파워', '특이사항': '[취소]CCI 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A123040', '종목명': '엠에스오토텍', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketnews
# {'코드': 'A123410', '시간': '10:18', '종목명': '코리아에프티', '특이사항': '[장중수급포착] 코리아에프티, 외국인 7일 연속 순매수행진... 주가 +1.71%'}
# marketwatch
# {'시간': '10:26', '코드': 'A287300', '종목명': 'KBSTAR 200건설', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A433970', '종목명': 'KODEX TDF2030액티브', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:23', '코드': 'A433970', '종목명': 'KODEX TDF2030액티브', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# {'시간': '10:23', '코드': 'A433970', '종목명': 'KODEX TDF2030액티브', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:18', '코드': 'A219480', '종목명': 'KODEX 미국S&P500선물(H)', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:08', '코드': 'A287410', '종목명': '제이시스메디칼', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A038460', '종목명': '바이오스마트', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'Q700016', '종목명': '하나 S&P 인버스 2X WTI원유 선물 ETN', '특이사항': '거래량 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A219550', '종목명': '디와이디', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A064480', '종목명': '브리지텍', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:26', '코드': 'A219900', '종목명': 'ACE 중국본토CSI300레버리지(합성)', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A389030', '종목명': '지니너스', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A123420', '종목명': '위메이드플레이', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A220130', '종목명': 'SOL 차이나강소기업CSI500(합성 H)', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '09:17', '코드': 'A435040', '종목명': 'ACE 글로벌브랜드TOP10블룸버그', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A038680', '종목명': '에스넷', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:21', '코드': 'A038680', '종목명': '에스넷', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:26', '코드': 'A038680', '종목명': '에스넷', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:12', '코드': 'A012330', '종목명': '현대모비스', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:22', '코드': 'A220260', '종목명': '켐트로스', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '10:19', '코드': 'A289220', '종목명': '자이언트스텝', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'Q580022', '종목명': 'KB 레버리지 금 선물 ETN(H)', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# {'시간': '10:26', '코드': 'Q580022', '종목명': 'KB 레버리지 금 선물 ETN(H)', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A123840', '종목명': '한일진공', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'Q580032', '종목명': 'KB 레버리지 구리 선물 ETN(H)', '특이사항': '최근5일거래량최고갱신'}
# {'시간': '10:26', '코드': 'Q580032', '종목명': 'KB 레버리지 구리 선물 ETN(H)', '특이사항': '거래량 5MA 상향돌파'}
# {'시간': '10:26', '코드': 'Q580032', '종목명': 'KB 레버리지 구리 선물 ETN(H)', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:18', '코드': 'A123860', '종목명': '아나패스', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '09:48', '코드': 'A391710', '종목명': '코닉오토메이션', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A290130', '종목명': 'KBSTAR ESG사회책임투자', '특이사항': '캔들패턴-상승반전형'}
# marketnews
# {'코드': 'A008970', '시간': '10:26', '종목명': '동양철관', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# marketwatch
# {'시간': '10:26', '코드': 'A065350', '종목명': '신성델타테크', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A222980', '종목명': '한국맥널티', '특이사항': '삼선전환도-음전환'}
# {'시간': '10:22', '코드': 'A222980', '종목명': '한국맥널티', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A394670', '종목명': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'Q580046', '종목명': 'KB 블룸버그 인버스2X 천연가스선물 ETN(H)', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '10:26', '코드': 'Q580046', '종목명': 'KB 블룸버그 인버스2X 천연가스선물 ETN(H)', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A001270', '종목명': '부국증권', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '09:17', '코드': 'A065420', '종목명': '에스아이리소스', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '09:17', '코드': 'A065420', '종목명': '에스아이리소스', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:03', '코드': 'A012790', '종목명': '신일제약', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:00', '코드': 'A001340', '종목명': '백광산업', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '09:45', '코드': 'A065500', '종목명': '오리엔트정공', '특이사항': '[취소]CCI 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:12', '코드': 'A065510', '종목명': '휴비츠', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:26', '코드': 'A065510', '종목명': '휴비츠', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A306620', '종목명': '네온테크', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A065530', '종목명': '와이어블', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A013120', '종목명': '동원개발', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:26', '코드': 'A013120', '종목명': '동원개발', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:26', '코드': 'A013120', '종목명': '동원개발', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A065650', '종목명': '메디프론', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A225220', '종목명': '제놀루션', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A291620', '종목명': 'KOSEF 코스닥150선물인버스', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:18', '코드': 'A128540', '종목명': '에코캡', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:21', '코드': 'A065660', '종목명': '안트로젠', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A128660', '종목명': '피제이메탈', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A307510', '종목명': 'TIGER 의료기기', '특이사항': '주가 5MA 하향돌파'}
# marketnews
# {'코드': 'A108860', '시간': '10:26', '종목명': '셀바스AI', '특이사항': '셀바스헬스케어,주주배정 유증 청약률99.41%...210억원 확보 성공'}
# marketwatch
# {'시간': '10:26', '코드': 'A065680', '종목명': '우주일렉트로', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A291650', '종목명': '압타머사이언스', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A442900', '종목명': '미래에셋드림스팩1호', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:26', '코드': 'A442900', '종목명': '미래에셋드림스팩1호', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A065690', '종목명': '파커스', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A128940', '종목명': '한미약품', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# {'시간': '10:26', '코드': 'A128940', '종목명': '한미약품', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A129260', '종목명': '인터지스', '특이사항': 'Stochastic(10,5,5)매도- %K%D 교차'}
# {'시간': '10:18', '코드': 'A129260', '종목명': '인터지스', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:21', '코드': 'A039860', '종목명': '나노엔텍', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '10:26', '코드': 'A039860', '종목명': '나노엔텍', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# {'시간': '10:21', '코드': 'A039860', '종목명': '나노엔텍', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:26', '코드': 'A039860', '종목명': '나노엔텍', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '09:07', '코드': 'A444490', '종목명': 'WOORI 미국S&P500', '특이사항': '[취소]캔들패턴-하락반전형'}
# {'시간': '10:26', '코드': 'A444490', '종목명': 'WOORI 미국S&P500', '특이사항': '주가이동평균밀집-5%이내'}
# marketwatch
# {'시간': '10:26', '코드': 'A065770', '종목명': 'CS', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A013700', '종목명': '까뮤이앤씨', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A065950', '종목명': '웰크론', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A001540', '종목명': '안국약품', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A226330', '종목명': '신테카바이오', '특이사항': '최근5일거래량최고갱신'}
# {'시간': '09:04', '코드': 'A226330', '종목명': '신테카바이오', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:26', '코드': 'A226330', '종목명': '신테카바이오', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:26', '코드': 'A293490', '종목명': '카카오게임즈', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:22', '코드': 'A013870', '종목명': '지엠비코리아', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A040350', '종목명': '큐로컴', '특이사항': '주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A130660', '종목명': '한전산업', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:26', '코드': 'A130660', '종목명': '한전산업', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketnews
# {'코드': 'A016250', '시간': '10:26', '종목명': 'SGC이테크건설', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# marketwatch
# {'시간': '10:12', '코드': 'A066575', '종목명': 'LG전자우', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '09:59', '코드': 'A066575', '종목명': 'LG전자우', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A130680', '종목명': 'TIGER 원유선물Enhanced(H)', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A001620', '종목명': '케이비아이동국실업', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:12', '코드': 'A066620', '종목명': '국보디자인', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '10:12', '코드': 'A066620', '종목명': '국보디자인', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# {'시간': '10:12', '코드': 'A066620', '종목명': '국보디자인', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:12', '코드': 'A066620', '종목명': '국보디자인', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:15', '코드': 'A309930', '종목명': '오하임아이엔티', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A131100', '종목명': '초록뱀이앤엠', '특이사항': '전일거래량갱신'}
# marketnews
# {'코드': 'A369370', '시간': '10:26', '종목명': '블리츠웨이', '특이사항': '<코>블리츠웨이, 현재가 8.23% 급등'}
# marketwatch
# {'시간': '10:03', '코드': 'A066790', '종목명': '씨씨에스', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:03', '코드': 'A066790', '종목명': '씨씨에스', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A227830', '종목명': 'ARIRANG 코스피', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A001750', '종목명': '한양증권', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A066900', '종목명': '디에이피', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:17', '코드': 'A066900', '종목명': '디에이피', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketnews
# {'코드': 'A170030', '시간': '10:26', '종목명': '현대공업', '특이사항': '현대공업(170030) 상승폭 확대 +6.81%, 4거래일 연속 상승'}
# marketwatch
# {'시간': '10:26', '코드': 'A014440', '종목명': '영보화학', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# {'시간': '10:26', '코드': 'A014440', '종목명': '영보화학', '특이사항': '삼선전환도-양전환'}
# marketwatch
# {'시간': '10:26', '코드': 'A227840', '종목명': '현대코퍼레이션홀딩스', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:26', '코드': 'A227840', '종목명': '현대코퍼레이션홀딩스', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A295020', '종목명': 'KBSTAR 국채선물10년인버스', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# {'시간': '10:26', '코드': 'A295020', '종목명': 'KBSTAR 국채선물10년인버스', '특이사항': 'Stochastic(10,5,5)매도- 기준선하향돌파'}
# {'시간': '10:26', '코드': 'A295020', '종목명': 'KBSTAR 국채선물10년인버스', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A131370', '종목명': '알서포트', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A001770', '종목명': 'SHD', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:22', '코드': 'A014470', '종목명': '부방', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:19', '코드': 'A448290', '종목명': 'TIGER 미국S&P500TR(H)', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A310870', '종목명': '디와이씨', '특이사항': 'Sonar 매수-Signal(9) 상향돌파'}
# {'시간': '10:23', '코드': 'A310870', '종목명': '디와이씨', '특이사항': '[취소]일목균형표매도-주가가선행스팬하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A041520', '종목명': '이라이콤', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A001795', '종목명': '대한제당우', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '10:07', '코드': 'A041830', '종목명': '인바디', '특이사항': '[취소]CCI 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'Q520040', '종목명': '미래에셋 인버스 코스닥150 선물 ETN', '특이사항': '최근5일매물대돌파'}
# {'시간': '09:20', '코드': 'Q520040', '종목명': '미래에셋 인버스 코스닥150 선물 ETN', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:26', '코드': 'Q520040', '종목명': '미래에셋 인버스 코스닥150 선물 ETN', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A067080', '종목명': '대화제약', '특이사항': '[취소]주가 5MA 상향돌파'}
# marketwatch
# {'시간': '10:23', '코드': 'A298000', '종목명': '효성화학', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A133820', '종목명': '화인베스틸', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A041920', '종목명': '메디아나', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:23', '코드': 'A311690', '종목명': 'CJ 바이오사이언스', '특이사항': '[취소]MACD 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A067160', '종목명': '아프리카TV', '특이사항': 'Stochastic(10,5,5)매도- 기준선하향돌파'}
# marketwatch
# {'시간': '10:14', '코드': 'A001840', '종목명': '이화공영', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:17', '코드': 'A067170', '종목명': '오텍', '특이사항': '[취소]최근60일매물대돌파'}
# {'시간': '10:17', '코드': 'A067170', '종목명': '오텍', '특이사항': '[취소]MACD 매수-Signal(9) 상향돌파'}
# {'시간': '10:22', '코드': 'A067170', '종목명': '오텍', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:22', '코드': 'A134580', '종목명': '탑코미디어', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A001880', '종목명': 'DL건설', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:05', '코드': 'A001880', '종목명': 'DL건설', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A298060', '종목명': '에스씨엠생명과학', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:25', '코드': 'Q530031', '종목명': '삼성 레버리지 WTI원유 선물 ETN', '특이사항': '[취소]최근60일매물대돌파'}
# marketwatch
# {'시간': '09:50', '코드': 'A067370', '종목명': '선바이오', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '09:24', '코드': 'A042370', '종목명': '비츠로테크', '특이사항': '[취소]MACD 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '09:04', '코드': 'A002100', '종목명': '경농', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '09:57', '코드': 'A002100', '종목명': '경농', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:26', '코드': 'A136540', '종목명': '윈스', '특이사항': '전일거래량갱신'}
# marketwatch
# {'시간': '10:17', '코드': 'A042420', '종목명': '네오위즈홀딩스', '특이사항': '[취소]최근60일매물대돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A015020', '종목명': '이스타코', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:46', '코드': 'A136660', '종목명': '큐엠씨', '특이사항': '[취소]최근60일매물대돌파'}
# {'시간': '09:46', '코드': 'A136660', '종목명': '큐엠씨', '특이사항': '[취소]Sonar 매수-Signal(9) 상향돌파'}
# {'시간': '09:46', '코드': 'A136660', '종목명': '큐엠씨', '특이사항': '[취소]단기급락후 5MA 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A136790', '종목명': '동화일렉트로라이트', '특이사항': '주가 5MA 상향돌파'}
# {'시간': '10:26', '코드': 'A136790', '종목명': '동화일렉트로라이트', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:26', '코드': 'A136790', '종목명': '동화일렉트로라이트', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '09:08', '코드': 'A067730', '종목명': '로지시스', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A316640', '종목명': '마이지놈박스', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '10:23', '코드': 'A232140', '종목명': '와이아이케이', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:26', '코드': 'A450910', '종목명': 'SOL 코스닥150', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '09:55', '코드': 'A015710', '종목명': '코콤', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:23', '코드': 'A299660', '종목명': '셀리드', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:26', '코드': 'A299660', '종목명': '셀리드', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:27', '코드': 'A015890', '종목명': '태경산업', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# marketwatch
# ...
# {'시간': '10:24', '코드': 'A086960', '종목명': 'MDS테크', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:21', '코드': 'A252990', '종목명': '샘씨엔에스', '특이사항': '[취소]캔들패턴-하락반전형'}
# {'시간': '10:20', '코드': 'A005387', '종목명': '현대차2우B', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:20', '코드': 'A005387', '종목명': '현대차2우B', '특이사항': '[취소]주가 5MA 상향돌파'}
# {'시간': '10:24', '코드': 'A455850', '종목명': 'SOL 반도체소부장Fn', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A187420', '종목명': '제노포커스', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': '캔들패턴-상승반전형'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': 'MACD 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': '주가 5MA 상향돌파'}
# {'시간': '10:24', '코드': 'A030010', '종목명': '하이투자증권', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:06', '코드': 'A086820', '종목명': '바이오솔루션', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:23', '코드': 'Q530031', '종목명': '삼성 레버리지 WTI원유 선물 ETN', '특이사항': '[취소]최근60일매물대돌파'}
# {'시간': '10:20', '코드': 'A100590', '종목명': '머큐리', '특이사항': '[취소]Price roc 매수-Signal(9) 상향돌파'}
# {'시간': '10:24', '코드': 'A100590', '종목명': '머큐리', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# {'시간': '10:24', '코드': 'A100590', '종목명': '머큐리', '특이사항': 'Stochastic(10,5,5)매도- %K%D 교차'}
# {'시간': '10:24', '코드': 'A100590', '종목명': '머큐리', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:24', '코드': 'A058400', '종목명': 'KNN', '특이사항': '삼선전환도-양전환'}
# {'시간': '10:24', '코드': 'A086390', '종목명': '유니테스트', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:19', '코드': 'A028670', '종목명': '팬오션', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# {'시간': '10:13', '코드': 'A347890', '종목명': '엠투아이', '특이사항': '[취소]일목균형표매수-주가가선행스팬상향돌파'}
# {'시간': '10:24', '코드': 'A100090', '종목명': 'SK오션플랜트', '특이사항': '주가이동평균밀집-5%이내'}
# {'시간': '10:24', '코드': 'A100090', '종목명': 'SK오션플랜트', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:24', '코드': 'A251340', '종목명': 'KODEX 코스닥150선물인버스', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:24', '코드': 'A086040', '종목명': '바이오톡스텍', '특이사항': '캔들패턴-상승반전형'}
# {'시간': '10:24', '코드': 'A086040', '종목명': '바이오톡스텍', '특이사항': '삼선전환도-양전환'}
# {'시간': '10:23', '코드': 'A021240', '종목명': '코웨이', '특이사항': "코웨이, '2023 대한민국 혁신대상 신기술혁신상' 수상"}
# {'시간': '10:23', '코드': 'A272210', '종목명': '한화시스템', '특이사항': '한화시스템, 레오나르도와 AESA레이다 개발·수출 ‘맞손’'}
# {'시간': '10:23', '코드': 'A208370', '종목명': '셀바스헬스케어', '특이사항': '셀바스헬스케어, 구주주 유상증자 청약률 99.41%'}
# {'시간': '10:23', '코드': 'A000480', '종목명': '조선내화', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A002150', '종목명': '도화엔지니어링', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A007280', '종목명': '한국특강', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A079160', '종목명': 'CJ CGV', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A241560', '종목명': '두산밥캣', '특이사항': '[유레카 발굴종목] 도화엔지니어링, AI알고리즘의 매매의견 확인하기'}
# {'시간': '10:23', '코드': 'A089010', '종목명': '켐트로닉스', '특이사항': '켐트로닉스(089010) 소폭 상승세 +3.02%'}
# {'시간': '10:23', '코드': 'A900250', '종목명': '크리스탈신소재', '특이사항': '크리스탈신소재(900250) 소폭 상승세 +3.26%'}
# {'시간': '10:23', '코드': 'A078340', '종목명': '컴투스', '특이사항': '컴투스, 149억원 규모 배당 계획···"주주가치 제고 정책"'}
# {'시간': '10:23', '코드': 'A003490', '종목명': '대한항공', '특이사항': '\'취임 1년\' 강석훈 산은 회장 "대한항공·아시아나 합병 3분기 중 결론"'}
# {'시간': '10:23', '코드': 'A011200', '종목명': 'HMM', '특이사항': '\'취임 1년\' 강석훈 산은 회장 "대한항공·아시아나 합병 3분기 중 결론"'}
# {'시간': '10:23', '코드': 'A204840', '종목명': '지엘팜텍', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# {'시간': '10:23', '코드': 'A151910', '종목명': 'SBW생명과학', '특이사항': '외국계증권사 창구 첫 매수 포착'}
# {'시간': '10:22', '코드': 'A069960', '종목명': '현대백화점', '특이사항': '현대백화점, 친환경 쇼핑백으로 나무 2만 그루 보호'}
# {'시간': '10:22', '코드': 'A000660', '종목명': 'SK하이닉스', '특이사항': 'SK하이닉스, 실리콘밸리서 미래 인재 찾는다'}
# {'시간': '10:22', '코드': 'A060260', '종목명': '뉴보텍', '특이사항': '외국계증권사 창구 첫 매도 포착'}
# {'시간': '10:22', '코드': 'A068760', '종목명': '셀트리온제약', '특이사항': '외국계증권사 창구 첫 매수 포착'}
# {'시간': '10:21', '코드': 'A069620', '종목명': '대웅제약', '특이사항': '대웅제약, 위식도역류질환 신약 처방액 300억원 돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A365040', '종목명': 'TIGER AI코리아그로스액티브', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 52, in MyWindow.btnExcel_clicked(self)
#      49 for item in self.listWatchData:
#      50     df.loc[len(df)] = item
# ---> 52 writer = pd.ExcelWriter(gExcelFile, engine='xlsxwriter')
#      53 # Convert the dataframe to an XlsxWriter Excel object.
#      54 df.to_excel(writer, sheet_name='Sheet1')
#
# File c:\Users\USER\anaconda3\envs\stock_info\lib\site-packages\pandas\io\excel\_xlsxwriter.py:199, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     196 if mode == "a":
#     197     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 199 super().__init__(
#     200     path,
#     201     engine=engine,
#     202     date_format=date_format,
#     203     datetime_format=datetime_format,
#     204     mode=mode,
#     205     storage_options=storage_options,
#     206     if_sheet_exists=if_sheet_exists,
#     207     engine_kwargs=engine_kwargs,
#     208 )
#     210 self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File c:\Users\USER\anaconda3\envs\stock_info\lib\site-packages\pandas\io\excel\_base.py:1194, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1192 if isinstance(path, str):
#    1193     ext = os.path.splitext(path)[-1]
# -> 1194     self.check_extension(ext)
#    1196 # use mode to open the file
#    1197 if "b" not in mode:
#
# File c:\Users\USER\anaconda3\envs\stock_info\lib\site-packages\pandas\io\excel\_base.py:1309, in ExcelWriter.check_extension(cls, ext)
#    1307     ext = ext[1:]
#    1308 if not any(ext in extension for extension in cls._supported_extensions):
# -> 1309     raise ValueError(f"Invalid extension for engine '{cls.engine}': '{ext}'")
#    1310 return True
#
# ValueError: Invalid extension for engine '<property object at 0x0FF4FBE0>': 'csv'
# marketwatch
# {'시간': '10:41', '코드': 'A900100', '종목명': '애머릿지', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:43', '코드': 'A002390', '종목명': '한독', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:43', '코드': 'Q530075', '종목명': '삼성 레버리지 HSCEI ETN(H)', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:43', '코드': 'Q530075', '종목명': '삼성 레버리지 HSCEI ETN(H)', '특이사항': '삼선전환도-음전환'}
# marketwatch
# {'시간': '10:43', '코드': 'A900110', '종목명': '이스트아시아홀딩스', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:43', '코드': 'A900110', '종목명': '이스트아시아홀딩스', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:43', '코드': 'A900110', '종목명': '이스트아시아홀딩스', '특이사항': 'MACD 매도-Signal(9) 하향돌파'}
# {'시간': '10:43', '코드': 'A900110', '종목명': '이스트아시아홀딩스', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# {'시간': '10:43', '코드': 'A900110', '종목명': '이스트아시아홀딩스', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:39', '코드': 'A144960', '종목명': '뉴파워프라즈마', '특이사항': '[취소]최근60일매물대돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A297090', '종목명': '씨에스베어링', '특이사항': '삼선전환도-양전환'}
# marketwatch
# {'시간': '10:32', '코드': 'A366030', '종목명': '공구우먼', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:43', '코드': 'A002420', '종목명': '세기상사', '특이사항': 'Price roc 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:34', '코드': 'A033100', '종목명': '제룡전기', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A200880', '종목명': '서연이화', '특이사항': '거래량 5MA 상향돌파'}
# marketwatch
# {'시간': '10:34', '코드': 'A094480', '종목명': '갤럭시아머니트리', '특이사항': '[취소]삼선전환도-음전환'}
# marketwatch
# {'시간': '10:43', '코드': 'Q500019', '종목명': '신한 레버리지 WTI원유 선물 ETN(H)', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:40', '코드': 'A201490', '종목명': '미투온', '특이사항': '[취소]CCI 매수-기준선(-100) 상향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A033160', '종목명': '엠케이전자', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:27', '코드': 'A145720', '종목명': '덴티움', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A094820', '종목명': '일진파워', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A002630', '종목명': '오리엔트바이오', '특이사항': 'CCI 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:20', '코드': 'A033230', '종목명': '인성정보', '특이사항': '[취소]캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:32', '코드': 'A203650', '종목명': '드림시큐리티', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:36', '코드': 'A203650', '종목명': '드림시큐리티', '특이사항': '[취소]주가골든크로스(5MA > 20MA)'}
# {'시간': '10:32', '코드': 'A203650', '종목명': '드림시큐리티', '특이사항': '[취소]MACD 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A368200', '종목명': 'KBSTAR Fn K-뉴딜디지털플러스', '특이사항': '최근5일신저가갱신'}
# marketwatch
# {'시간': '10:39', '코드': 'A147760', '종목명': '피엠티', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A010770', '종목명': '평화홀딩스', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:39', '코드': 'A033250', '종목명': '체시스', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:43', '코드': 'A147830', '종목명': '제룡산업', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:06', '코드': 'A204270', '종목명': '제이앤티씨', '특이사항': '[취소]Stochastic(10,5,5)매도- %K%D 교차'}
# marketwatch
# {'시간': '10:43', '코드': 'A002720', '종목명': '국제약품', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:08', '코드': 'A950130', '종목명': '엑세스바이오', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:43', '코드': 'A298540', '종목명': '더네이쳐홀딩스', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '09:03', '코드': 'A033320', '종목명': '제이씨현시스템', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:43', '코드': 'A370090', '종목명': '퓨런티어', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:43', '코드': 'A033500', '종목명': '동성화인텍', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '09:35', '코드': 'A011000', '종목명': '진원생명과학', '특이사항': '[취소]Stochastic(10,5,5)매도- %K%D 교차'}
# marketwatch
# {'시간': '10:43', '코드': 'A033530', '종목명': '세종공업', '특이사항': '캔들패턴-상승반전형'}
# marketnews
# {'코드': 'A063080', '시간': '10:43', '종목명': '컴투스홀딩스', '특이사항': '컴투스홀딩스, 워킹데드 글로벌 업데이트'}
# marketwatch
# {'시간': '10:38', '코드': 'A950190', '종목명': '미투젠', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:39', '코드': 'A095570', '종목명': 'AJ네트웍스', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A149950', '종목명': '아바텍', '특이사항': '최근5일신저가갱신'}
# marketnews
# {'코드': 'A047560', '시간': '10:43', '종목명': '이스트소프트', '특이사항': '이스트소프트, 한투 AI 애널리스트 한지아 음성 기술 고도화'}
# marketwatch
# {'시간': '10:16', '코드': 'A095610', '종목명': '테스', '특이사항': '[취소]Stochastic(10,5,5)매도- %K%D 교차'}
# marketwatch
# {'시간': '10:44', '코드': 'A371470', '종목명': 'TIGER 차이나바이오테크SOLACTIVE', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A204840', '종목명': '지엘팜텍', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketnews
# {'코드': 'A079160', '시간': '10:26', '종목명': 'CJ CGV', '특이사항': "[리포트 브리핑]CJ CGV, 'NEXT CGV' Not Rated - 신한투자증권"}
# marketwatch
# {'시간': '10:44', '코드': 'A150900', '종목명': '파수', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:44', '코드': 'A299660', '종목명': '셀리드', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A011150', '종목명': 'CJ씨푸드', '특이사항': 'Momentum 매수-기준선(100) 상향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A002870', '종목명': '신풍', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# {'시간': '09:13', '코드': 'A002870', '종목명': '신풍', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A033830', '종목명': '티비씨', '특이사항': '최근5일매물대돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A095910', '종목명': '에스에너지', '특이사항': '최근5일신저가갱신'}
# {'시간': '10:44', '코드': 'A095910', '종목명': '에스에너지', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:30', '코드': 'A300120', '종목명': '라온피플', '특이사항': '[취소]Stochastic(10,5,5)매수- %K%D 교차'}
# marketwatch
# {'시간': '10:44', '코드': 'A372910', '종목명': '한컴라이프케어', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A300640', '종목명': 'KBSTAR 게임테마', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A395290', '종목명': 'HANARO Fn K-POP&미디어', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:29', '코드': 'A206640', '종목명': '바디텍메드', '특이사항': '[취소]Momentum 매수-기준선(100) 상향돌파'}
# marketnews
# {'코드': 'A018250', '시간': '10:44', '종목명': '애경산업', '특이사항': '애경산업(018250) 소폭 상승세 +3.19%'}
# marketwatch
# {'시간': '10:40', '코드': 'A300950', '종목명': 'KODEX 게임산업', '특이사항': '[취소]주가 5MA 하향돌파'}
# marketwatch
# {'시간': '10:39', '코드': 'A011280', '종목명': '태림포장', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:39', '코드': 'A011280', '종목명': '태림포장', '특이사항': '[취소]RSI(14) 매도-Signal(9) 하향돌파'}
# {'시간': '10:39', '코드': 'A011280', '종목명': '태림포장', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:40', '코드': 'A003000', '종목명': '부광약품', '특이사항': '[취소]캔들패턴-상승반전형'}
# marketwatch
# {'시간': '09:17', '코드': 'A153490', '종목명': '우리이앤엘', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:44', '코드': 'A153490', '종목명': '우리이앤엘', '특이사항': '주가 5MA 하향돌파'}
# marketwatch
# {'시간': '09:09', '코드': 'A375270', '종목명': 'KBSTAR 글로벌데이터센터리츠나스닥(합성)', '특이사항': '[취소]주가 5MA 하향돌파'}
# {'시간': '10:40', '코드': 'A375270', '종목명': 'KBSTAR 글로벌데이터센터리츠나스닥(합성)', '특이사항': '[취소]CCI 매도-기준선(100) 하향돌파'}
# {'시간': '10:40', '코드': 'A375270', '종목명': 'KBSTAR 글로벌데이터센터리츠나스닥(합성)', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# {'시간': '10:40', '코드': 'A375270', '종목명': 'KBSTAR 글로벌데이터센터리츠나스닥(합성)', '특이사항': '[취소]삼선전환도-음전환'}
# marketwatch
# {'시간': '10:44', '코드': 'A011320', '종목명': '유니크', '특이사항': 'Price roc 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:34', '코드': 'A034310', '종목명': 'NICE', '특이사항': '[취소]RSI(14) 매수-Signal(9) 상향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A154040', '종목명': '다산솔루에타', '특이사항': 'RSI(14) 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A011330', '종목명': '유니켐', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:44', '코드': 'A03473K', '종목명': 'SK우', '특이사항': '캔들패턴-상승반전형'}
# marketwatch
# {'시간': '10:36', '코드': 'A155660', '종목명': 'DSR', '특이사항': '[취소]일목균형표매수-주가가선행스팬상향돌파'}
# {'시간': '10:44', '코드': 'A155660', '종목명': 'DSR', '특이사항': '일목균형표매도-주가가선행스팬하향돌파'}
# marketwatch
# {'시간': '10:41', '코드': 'A399720', '종목명': '가온칩스', '특이사항': '[취소]삼선전환도-음전환'}
# marketwatch
# {'시간': '10:44', '코드': 'A375760', '종목명': 'HANARO 탄소효율그린뉴딜', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A208370', '종목명': '셀바스헬스케어', '특이사항': 'CCI 매수-기준선(-100) 상향돌파'}
# marketwatch
# {'시간': '10:12', '코드': 'A400570', '종목명': 'KODEX 유럽탄소배출권선물ICE(H)', '특이사항': '[취소]최근5일매물대돌파'}
# {'시간': '10:44', '코드': 'A400570', '종목명': 'KODEX 유럽탄소배출권선물ICE(H)', '특이사항': '캔들패턴-하락반전형'}
# marketwatch
# {'시간': '10:44', '코드': 'A060480', '종목명': '국일신동', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:44', '코드': 'A060480', '종목명': '국일신동', '특이사항': 'RSI(14) 매수-Signal(9) 상향돌파'}
# {'시간': '10:44', '코드': 'A060480', '종목명': '국일신동', '특이사항': '주가이동평균밀집-5%이내'}
# marketwatch
# {'시간': '10:44', '코드': 'A303030', '종목명': '지니틱스', '특이사항': '주가골든크로스(5MA > 20MA)'}
# {'시간': '10:40', '코드': 'A303030', '종목명': '지니틱스', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A011500', '종목명': '한농화성', '특이사항': 'Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:39', '코드': 'A060540', '종목명': '에스에이티', '특이사항': '[취소]Momentum 매도-기준선(100) 하향돌파'}
# marketwatch
# {'시간': '10:44', '코드': 'A208710', '종목명': '바이오로그디바이스', '특이사항': '최근5일매물대돌파'}
# {'시간': '10:44', '코드': 'A208710', '종목명': '바이오로그디바이스', '특이사항': '최근5일신고가갱신'}
# marketwatch
# {'시간': '10:44', '코드': 'A011690', '종목명': '와이투솔루션', '특이사항': '주가 5MA 하향돌파'}
# {'시간': '10:39', '코드': 'A011690', '종목명': '와이투솔루션', '특이사항': '[취소]Stochastic(10,5,5)매수- 기준선상향돌파'}
# marketwatch
# {'시간': '09:35', '코드': 'A060590', '종목명': '씨티씨바이오', '특이사항': '[취소]최근5일매물대돌파'}
# marketnews
# {'코드': 'A030200', '시간': '10:43', '종목명': 'KT', '특이사항': '"AI 대전환 시대에 경쟁력 강화" KT, AI 기술 개발에 5년간 7조 투자'}
# marketwatch
# {'시간': '10:40', '코드': 'A304360', '종목명': '에스바이오메딕스', '특이사항': '[취소]최근5일매물대돌파'}
# marketwatch
# {'시간': '10:39', '코드': 'A035150', '종목명': '백산', '특이사항': '[취소]Price roc 매도-Signal(9) 하향돌파'}
# {'시간': '10:44', '코드': 'A035150', '종목명': '백산', '특이사항': '삼선전환도-음전환'}
# marketwatch
# {'시간': '10:44', '코드': 'A400970', '종목명': 'TIGER Fn메타버스', '특이사항': 'Sonar 매도-Signal(9) 하향돌파'}
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다. 셀의 코드를 검토하여 오류의 가능한 원인을 식별하세요. 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'> 여기 </a> 를 클릭하세요. 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
