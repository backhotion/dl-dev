# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np

# %%
fdr.__version__
# Out:
# '0.9.50'

# %%
# 한국 거래소 자료 가져오기 
krx = fdr.StockListing('KRX')
krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          71300          1
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         569000          1
# 2     000660  KR7000660001    SK하이닉스  KOSPI         114000          2
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         756000          2
# 4     051910  KR7051910008      LG화학  KOSPI         721000          2
# ...      ...           ...       ...    ...    ...     ...        ...
# 2720  245450  KR7245450002    씨앤에스링크  KONEX  일반기업부    1598          2
# 2721  000547  KR7000542001   흥국화재2우B  KOSPI          12680          4
# 2722  288490  KR7288490006     나라소프트  KONEX  일반기업부      51          1
# 2723  322190  KR7322190000        베른  KONEX  일반기업부     205          1
# 2724  308700  KR7308700004       테크엔  KONEX  일반기업부     293          4
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# ...

# %%
# 한국 거래소 주식 종목별 자료 가져오기 
stock_info = ['뷰노', '에스에너지', '셀바스AI']
krx[krx['Name'].isin(stock_info)]
# Out:
#         Code        ISU_CD   Name  Market     Dept  Close ChangeCode  Changes  \
# 521   108860  KR7108860008  셀바스AI  KOSDAQ    벤처기업부  17710          2      -50
# 542   338220  KR7338220007     뷰노  KOSDAQ  기술성장기업부  32900          2      -50
# 2175  095910  KR7095910006  에스에너지  KOSDAQ    중견기업부   2730          2      -15
#
#       ChagesRatio   Open   High    Low  Volume       Amount        Marcap  \
# 521         -0.28  17760  17980  17550  365949   6501930070  398656704600
# 542         -0.15  32150  34100  30950  874409  28629849050  375785642400
# 2175        -0.55   2735   2760   2705   55259    150978640   53247293190
#
#         Stocks MarketId
# 521   22510260      KSQ
# 542   11422056      KSQ
# 2175  19504503      KSQ

# %%
# kospi 지수 가져오기_일자별 확인가능
kospi = fdr.DataReader('KS11')
kospi
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1996-12-11   705.989990   709.479980   704.429993   704.679993   704.679993
# 1996-12-12   705.109985   706.010010   688.739990   689.380005   689.380005
# 1996-12-13   690.440002   695.719971   677.640015   689.070007   689.070007
# 1996-12-16   686.969971   686.969971   667.710022   673.919983   673.919983
# 1996-12-17   675.349976   680.090027   660.390015   663.349976   663.349976
# ...                 ...          ...          ...          ...          ...
# 2023-06-16  2623.570068  2625.790039  2612.209961  2625.790039  2625.790039
# 2023-06-19  2618.060059  2619.439941  2600.489990  2609.500000  2609.500000
# 2023-06-20  2602.830078  2610.030029  2596.820068  2604.909912  2604.909912
# 2023-06-21  2599.189941  2600.969971  2579.520020  2582.629883  2582.629883
# 2023-06-22  2575.649902  2597.760010  2575.649902  2593.699951  2593.699951
#
#               Volume
# Date
# ...

# %%
# 코스닥 지수 전체 데이터 가져오기_일자별 확인가능
kosdaq = fdr.DataReader('KQ11')
kosdaq
# Out:
# Date
# 2000-10-16    867.099976
# 2000-10-17    804.000000
# 2000-10-18    802.599976
# 2000-10-19    798.400024
# 2000-10-20    826.200012
#                  ...
# 2023-06-16    887.950012
# 2023-06-19    888.609985
# 2023-06-20    886.409973
# 2023-06-21    875.700012
# 2023-06-22    876.380005
# Name: Close, Length: 5685, dtype: float64

# %%
# 데이터 저장 하기 
krx.to_csv('KRX2_data.csv')
kospi.to_csv('KOSPI_data.csv')
kosdaq.to_csv('KOSDAQ_data.csv')
