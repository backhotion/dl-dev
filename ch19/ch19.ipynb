# %%
# # 생성자 모델을 만듭니다.
# generator = Sequential() # 순차적으로 신경망 구성 -> 순차적 학습
# generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2))) # 크기 배수 조정
# generator.add(BatchNormalization()) # 출력값 정규화
# generator.add(Reshape((7, 7, 128))) # 크기 배수 조정
# generator.add(UpSampling2D()) # 데이터 확장
# generator.add(Conv2D(64, kernel_size=5, padding='same'))
# generator.add(BatchNormalization()) # 출력값 정규화
# generator.add(Activation(LeakyReLU(0.2)))
# generator.add(UpSampling2D()) # 데이터 확장
# generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model


import numpy as np
import matplotlib.pyplot as plt


# 예제 파일에서 data 폴더 아래에 이미지가 저장될 gan_images 폴더가 함께 제공됩니다.
# 만약 이미지가 저장될 폴더가 없다면 아래 코드의 주석을 해제해 gan_images 폴더를 만듭니다.
# import os
# if not os.path.exists("./data/gan_images"):
#    os.makedirs("./data/gan_images")


# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))


# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False


# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()


# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):


  # MNIST 데이터를 불러옵니다.


  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape


  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))


  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)


          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)


          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)


          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)


        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)


              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5


              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("../data/gan_images/gan_mnist_%d.png" % i)


gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 100)]             0
#
#  sequential_2 (Sequential)   (None, 28, 28, 1)         865281
#
#  sequential_3 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# 1/1 [==============================] - 0s 127ms/step
# epoch:0  d_loss:0.6848  g_loss:0.4652
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 48ms/step
# epoch:1  d_loss:0.4975  g_loss:0.1573
# 1/1 [==============================] - 0s 46ms/step
# epoch:2  d_loss:0.5016  g_loss:0.0444
# 1/1 [==============================] - 0s 48ms/step
# epoch:3  d_loss:0.5371  g_loss:0.0380
# 1/1 [==============================] - 0s 43ms/step
# epoch:4  d_loss:0.5362  g_loss:0.0894
# 1/1 [==============================] - 0s 45ms/step
# epoch:5  d_loss:0.4908  g_loss:0.2261
# 1/1 [==============================] - 0s 52ms/step
# epoch:6  d_loss:0.4652  g_loss:0.4512
# 1/1 [==============================] - 0s 51ms/step
# epoch:7  d_loss:0.4764  g_loss:0.6224
# 1/1 [==============================] - 0s 53ms/step
# epoch:8  d_loss:0.4857  g_loss:0.6830
# 1/1 [==============================] - 0s 44ms/step
# epoch:9  d_loss:0.4737  g_loss:0.6839
# 1/1 [==============================] - 0s 44ms/step
# epoch:10  d_loss:0.5483  g_loss:0.6228
# 1/1 [==============================] - 0s 46ms/step
# epoch:11  d_loss:0.6244  g_loss:0.5366
# 1/1 [==============================] - 0s 55ms/step
# epoch:12  d_loss:0.6923  g_loss:0.3462
# 1/1 [==============================] - 0s 52ms/step
# epoch:13  d_loss:0.5634  g_loss:0.2672
# 1/1 [==============================] - 0s 56ms/step
# epoch:14  d_loss:0.4781  g_loss:0.2575
# 1/1 [==============================] - 0s 57ms/step
# epoch:15  d_loss:0.3824  g_loss:0.2212
# 1/1 [==============================] - 0s 52ms/step
# epoch:16  d_loss:0.3264  g_loss:0.1692
# 1/1 [==============================] - 0s 47ms/step
# epoch:17  d_loss:0.2840  g_loss:0.1108
# 1/1 [==============================] - 0s 59ms/step
# epoch:18  d_loss:0.2456  g_loss:0.0909
# 1/1 [==============================] - 0s 51ms/step
# epoch:19  d_loss:0.1989  g_loss:0.0928
# 1/1 [==============================] - 0s 42ms/step
# epoch:20  d_loss:0.1559  g_loss:0.1799
# 1/1 [==============================] - 0s 49ms/step
# epoch:21  d_loss:0.1667  g_loss:0.1076
# 1/1 [==============================] - 0s 48ms/step
# epoch:22  d_loss:0.1758  g_loss:0.1435
# 1/1 [==============================] - 0s 45ms/step
# epoch:23  d_loss:0.3399  g_loss:0.1950
# 1/1 [==============================] - 0s 46ms/step
# epoch:24  d_loss:0.3782  g_loss:0.4745
# 1/1 [==============================] - 0s 46ms/step
# epoch:25  d_loss:0.8446  g_loss:0.0328
# 1/1 [==============================] - 0s 48ms/step
# epoch:26  d_loss:0.7435  g_loss:0.2829
# 1/1 [==============================] - 0s 47ms/step
# epoch:27  d_loss:0.5184  g_loss:0.9778
# 1/1 [==============================] - 0s 50ms/step
# epoch:28  d_loss:1.3596  g_loss:0.2017
# 1/1 [==============================] - 0s 44ms/step
# epoch:29  d_loss:0.9654  g_loss:0.3459
# 1/1 [==============================] - 0s 50ms/step
# epoch:30  d_loss:0.6411  g_loss:0.7932
# 1/1 [==============================] - 0s 45ms/step
# epoch:31  d_loss:0.5505  g_loss:0.7365
# 1/1 [==============================] - 0s 48ms/step
# epoch:32  d_loss:0.4340  g_loss:0.6212
# 1/1 [==============================] - 0s 46ms/step
# epoch:33  d_loss:0.2475  g_loss:0.9752
# 1/1 [==============================] - 0s 47ms/step
# epoch:34  d_loss:0.1374  g_loss:1.4405
# 1/1 [==============================] - 0s 51ms/step
# epoch:35  d_loss:0.1199  g_loss:2.0981
# 1/1 [==============================] - 0s 49ms/step
# epoch:36  d_loss:0.1187  g_loss:1.9049
# 1/1 [==============================] - 0s 45ms/step
# epoch:37  d_loss:0.0878  g_loss:1.6717
# 1/1 [==============================] - 0s 55ms/step
# epoch:38  d_loss:0.0618  g_loss:1.4702
# 1/1 [==============================] - 0s 61ms/step
# epoch:39  d_loss:0.0696  g_loss:1.5125
# 1/1 [==============================] - 0s 50ms/step
# epoch:40  d_loss:0.0916  g_loss:1.9650
# 1/1 [==============================] - 0s 49ms/step
# epoch:41  d_loss:0.1973  g_loss:2.6152
# 1/1 [==============================] - 0s 45ms/step
# epoch:42  d_loss:0.0658  g_loss:3.0218
# 1/1 [==============================] - 0s 43ms/step
# epoch:43  d_loss:0.1131  g_loss:3.6215
# 1/1 [==============================] - 0s 45ms/step
# epoch:44  d_loss:0.2489  g_loss:2.9405
# 1/1 [==============================] - 0s 45ms/step
# epoch:45  d_loss:0.3296  g_loss:2.2270
# 1/1 [==============================] - 0s 45ms/step
# epoch:46  d_loss:0.4276  g_loss:2.9521
# 1/1 [==============================] - 0s 44ms/step
# epoch:47  d_loss:0.4232  g_loss:3.9295
# 1/1 [==============================] - 0s 47ms/step
# epoch:48  d_loss:0.1953  g_loss:4.2123
# 1/1 [==============================] - 0s 58ms/step
# epoch:49  d_loss:0.5158  g_loss:3.1620
# 1/1 [==============================] - 0s 46ms/step
# epoch:50  d_loss:0.4756  g_loss:2.4968
# 1/1 [==============================] - 0s 57ms/step
# epoch:51  d_loss:0.5366  g_loss:1.9557
# 1/1 [==============================] - 0s 47ms/step
# epoch:52  d_loss:0.2461  g_loss:2.3400
# 1/1 [==============================] - 0s 52ms/step
# epoch:53  d_loss:0.2486  g_loss:2.9734
# 1/1 [==============================] - 0s 46ms/step
# epoch:54  d_loss:0.4533  g_loss:2.4787
# 1/1 [==============================] - 0s 89ms/step
# epoch:55  d_loss:0.4856  g_loss:2.0865
# 1/1 [==============================] - 0s 45ms/step
# epoch:56  d_loss:0.3643  g_loss:1.6593
# 1/1 [==============================] - 0s 46ms/step
# epoch:57  d_loss:0.3817  g_loss:1.7280
# 1/1 [==============================] - 0s 47ms/step
# epoch:58  d_loss:0.3136  g_loss:1.9352
# 1/1 [==============================] - 0s 50ms/step
# epoch:59  d_loss:0.3353  g_loss:2.2576
# 1/1 [==============================] - 0s 48ms/step
# epoch:60  d_loss:0.3795  g_loss:2.2432
# 1/1 [==============================] - 0s 42ms/step
# epoch:61  d_loss:0.3654  g_loss:1.9025
# 1/1 [==============================] - 0s 47ms/step
# epoch:62  d_loss:0.3914  g_loss:1.7049
# 1/1 [==============================] - 0s 57ms/step
# epoch:63  d_loss:0.3588  g_loss:1.7019
# 1/1 [==============================] - 0s 48ms/step
# epoch:64  d_loss:0.2323  g_loss:2.8639
# 1/1 [==============================] - 0s 47ms/step
# epoch:65  d_loss:0.2773  g_loss:2.8976
# 1/1 [==============================] - 0s 48ms/step
# epoch:66  d_loss:0.2863  g_loss:2.8263
# 1/1 [==============================] - 0s 46ms/step
# epoch:67  d_loss:0.2394  g_loss:2.8143
# 1/1 [==============================] - 0s 48ms/step
# epoch:68  d_loss:0.3330  g_loss:2.3493
# 1/1 [==============================] - 0s 50ms/step
# epoch:69  d_loss:0.3749  g_loss:2.6507
# 1/1 [==============================] - 0s 47ms/step
# epoch:70  d_loss:0.4138  g_loss:2.5931
# 1/1 [==============================] - 0s 47ms/step
# epoch:71  d_loss:0.3341  g_loss:2.2056
# 1/1 [==============================] - 0s 50ms/step
# epoch:72  d_loss:0.3294  g_loss:2.3033
# 1/1 [==============================] - 0s 46ms/step
# epoch:73  d_loss:0.3951  g_loss:1.9136
# 1/1 [==============================] - 0s 54ms/step
# epoch:74  d_loss:0.5659  g_loss:2.0052
# 1/1 [==============================] - 0s 47ms/step
# epoch:75  d_loss:0.3739  g_loss:2.1149
# 1/1 [==============================] - 0s 65ms/step
# epoch:76  d_loss:0.4116  g_loss:2.0983
# 1/1 [==============================] - 0s 47ms/step
# epoch:77  d_loss:0.5672  g_loss:1.5228
# 1/1 [==============================] - 0s 49ms/step
# epoch:78  d_loss:0.4729  g_loss:1.5637
# 1/1 [==============================] - 0s 62ms/step
# epoch:79  d_loss:0.3882  g_loss:1.8738
# 1/1 [==============================] - 0s 51ms/step
# epoch:80  d_loss:0.4292  g_loss:1.9237
# 1/1 [==============================] - 0s 76ms/step
# epoch:81  d_loss:0.4414  g_loss:1.8468
# 1/1 [==============================] - 0s 72ms/step
# epoch:82  d_loss:0.5168  g_loss:1.5389
# 1/1 [==============================] - 0s 69ms/step
# epoch:83  d_loss:0.3469  g_loss:1.2789
# 1/1 [==============================] - 0s 62ms/step
# epoch:84  d_loss:0.4889  g_loss:1.3621
# 1/1 [==============================] - 0s 65ms/step
# epoch:85  d_loss:0.2443  g_loss:1.9438
# 1/1 [==============================] - 0s 74ms/step
# epoch:86  d_loss:0.4093  g_loss:1.8340
# 1/1 [==============================] - 0s 79ms/step
# epoch:87  d_loss:0.5527  g_loss:1.3895
# 1/1 [==============================] - 0s 77ms/step
# epoch:88  d_loss:0.7525  g_loss:1.0410
# 1/1 [==============================] - 0s 102ms/step
# epoch:89  d_loss:0.7936  g_loss:1.1029
# 1/1 [==============================] - 0s 88ms/step
# epoch:90  d_loss:0.4095  g_loss:1.9143
# 1/1 [==============================] - 0s 96ms/step
# epoch:91  d_loss:0.8068  g_loss:1.7488
# 1/1 [==============================] - 0s 77ms/step
# epoch:92  d_loss:0.6350  g_loss:1.7596
# 1/1 [==============================] - 0s 82ms/step
# epoch:93  d_loss:0.7780  g_loss:1.7113
# 1/1 [==============================] - 0s 76ms/step
# epoch:94  d_loss:0.6171  g_loss:2.0458
# 1/1 [==============================] - 0s 74ms/step
# epoch:95  d_loss:0.4637  g_loss:2.8919
# 1/1 [==============================] - 0s 71ms/step
# epoch:96  d_loss:0.3736  g_loss:3.4592
# 1/1 [==============================] - 0s 102ms/step
# epoch:97  d_loss:0.4203  g_loss:3.7129
# 1/1 [==============================] - 0s 83ms/step
# epoch:98  d_loss:0.5363  g_loss:3.1768
# 1/1 [==============================] - 0s 82ms/step
# epoch:99  d_loss:0.6543  g_loss:2.4352
# 1/1 [==============================] - 0s 84ms/step
# epoch:100  d_loss:0.9295  g_loss:2.8138
# 1/1 [==============================] - 0s 68ms/step
# epoch:101  d_loss:0.8316  g_loss:2.5222
# 1/1 [==============================] - 0s 81ms/step
# epoch:102  d_loss:0.6282  g_loss:3.0056
# 1/1 [==============================] - 0s 58ms/step
# epoch:103  d_loss:0.8884  g_loss:2.3144
# 1/1 [==============================] - 0s 57ms/step
# epoch:104  d_loss:0.9605  g_loss:1.5960
# 1/1 [==============================] - 0s 54ms/step
# epoch:105  d_loss:0.6795  g_loss:1.5469
# 1/1 [==============================] - 0s 64ms/step
# epoch:106  d_loss:0.6888  g_loss:1.5653
# 1/1 [==============================] - 0s 68ms/step
# epoch:107  d_loss:0.7156  g_loss:1.3769
# 1/1 [==============================] - 0s 56ms/step
# epoch:108  d_loss:0.5592  g_loss:1.6212
# 1/1 [==============================] - 0s 61ms/step
# epoch:109  d_loss:0.7528  g_loss:1.3963
# 1/1 [==============================] - 0s 67ms/step
# epoch:110  d_loss:0.6054  g_loss:1.4355
# 1/1 [==============================] - 0s 73ms/step
# epoch:111  d_loss:0.5063  g_loss:1.1567
# 1/1 [==============================] - 0s 77ms/step
# epoch:112  d_loss:0.6303  g_loss:1.1017
# 1/1 [==============================] - 0s 65ms/step
# epoch:113  d_loss:0.5773  g_loss:1.0390
# 1/1 [==============================] - 0s 52ms/step
# epoch:114  d_loss:0.6993  g_loss:1.0039
# 1/1 [==============================] - 0s 55ms/step
# epoch:115  d_loss:0.6028  g_loss:0.9903
# 1/1 [==============================] - 0s 61ms/step
# epoch:116  d_loss:0.6020  g_loss:1.0465
# 1/1 [==============================] - 0s 53ms/step
# epoch:117  d_loss:0.4999  g_loss:1.2332
# 1/1 [==============================] - 0s 61ms/step
# epoch:118  d_loss:0.5656  g_loss:1.0697
# 1/1 [==============================] - 0s 58ms/step
# epoch:119  d_loss:0.4728  g_loss:1.1871
# 1/1 [==============================] - 0s 51ms/step
# epoch:120  d_loss:0.6890  g_loss:1.0194
# 1/1 [==============================] - 0s 66ms/step
# epoch:121  d_loss:0.5626  g_loss:1.2286
# 1/1 [==============================] - 0s 60ms/step
# epoch:122  d_loss:0.6565  g_loss:1.0475
# 1/1 [==============================] - 0s 68ms/step
# epoch:123  d_loss:0.6217  g_loss:0.9654
# 1/1 [==============================] - 0s 56ms/step
# epoch:124  d_loss:0.6244  g_loss:1.0105
# 1/1 [==============================] - 0s 65ms/step
# epoch:125  d_loss:0.5426  g_loss:1.2615
# 1/1 [==============================] - 0s 55ms/step
# epoch:126  d_loss:0.5139  g_loss:1.4781
# 1/1 [==============================] - 0s 55ms/step
# epoch:127  d_loss:0.5389  g_loss:1.3691
# 1/1 [==============================] - 0s 57ms/step
# epoch:128  d_loss:0.4137  g_loss:1.4878
# 1/1 [==============================] - 0s 51ms/step
# epoch:129  d_loss:0.4261  g_loss:1.6522
# 1/1 [==============================] - 0s 55ms/step
# epoch:130  d_loss:0.4321  g_loss:1.6447
# 1/1 [==============================] - 0s 54ms/step
# epoch:131  d_loss:0.4020  g_loss:2.0589
# 1/1 [==============================] - 0s 71ms/step
# epoch:132  d_loss:0.4488  g_loss:1.9331
# 1/1 [==============================] - 0s 54ms/step
# epoch:133  d_loss:0.3860  g_loss:1.8474
# 1/1 [==============================] - 0s 63ms/step
# epoch:134  d_loss:0.3610  g_loss:2.1127
# 1/1 [==============================] - 0s 82ms/step
# epoch:135  d_loss:0.3650  g_loss:2.1272
# 1/1 [==============================] - 0s 73ms/step
# epoch:136  d_loss:0.5731  g_loss:2.0985
# 1/1 [==============================] - 0s 72ms/step
# epoch:137  d_loss:0.5266  g_loss:2.5425
# 1/1 [==============================] - 0s 82ms/step
# epoch:138  d_loss:0.4441  g_loss:2.3884
# 1/1 [==============================] - 0s 61ms/step
# epoch:139  d_loss:0.9712  g_loss:1.7329
# 1/1 [==============================] - 0s 77ms/step
# epoch:140  d_loss:0.7611  g_loss:1.4432
# 1/1 [==============================] - 0s 59ms/step
# epoch:141  d_loss:0.6912  g_loss:1.3967
# 1/1 [==============================] - 0s 54ms/step
# epoch:142  d_loss:0.7471  g_loss:1.5474
# 1/1 [==============================] - 0s 51ms/step
# epoch:143  d_loss:0.9194  g_loss:1.5326
# 1/1 [==============================] - 0s 52ms/step
# epoch:144  d_loss:0.7946  g_loss:1.5258
# 1/1 [==============================] - 0s 57ms/step
# epoch:145  d_loss:0.6741  g_loss:1.2082
# 1/1 [==============================] - 0s 53ms/step
# epoch:146  d_loss:0.6593  g_loss:1.3110
# 1/1 [==============================] - 0s 55ms/step
# epoch:147  d_loss:0.5506  g_loss:1.3723
# 1/1 [==============================] - 0s 61ms/step
# epoch:148  d_loss:0.4944  g_loss:1.2501
# 1/1 [==============================] - 0s 50ms/step
# epoch:149  d_loss:0.4802  g_loss:1.1705
# 1/1 [==============================] - 0s 89ms/step
# epoch:150  d_loss:0.5014  g_loss:1.3128
# 1/1 [==============================] - 0s 53ms/step
# epoch:151  d_loss:0.3980  g_loss:1.2735
# 1/1 [==============================] - 0s 53ms/step
# epoch:152  d_loss:0.4107  g_loss:1.2096
# 1/1 [==============================] - 0s 52ms/step
# epoch:153  d_loss:0.3782  g_loss:1.3994
# 1/1 [==============================] - 0s 50ms/step
# epoch:154  d_loss:0.3379  g_loss:1.3715
# 1/1 [==============================] - 0s 64ms/step
# epoch:155  d_loss:0.3433  g_loss:1.3642
# 1/1 [==============================] - 0s 52ms/step
# epoch:156  d_loss:0.4608  g_loss:1.1953
# 1/1 [==============================] - 0s 51ms/step
# epoch:157  d_loss:0.3881  g_loss:1.1044
# 1/1 [==============================] - 0s 54ms/step
# epoch:158  d_loss:0.3211  g_loss:1.1542
# 1/1 [==============================] - 0s 57ms/step
# epoch:159  d_loss:0.4046  g_loss:1.1670
# 1/1 [==============================] - 0s 73ms/step
# epoch:160  d_loss:0.4583  g_loss:0.9771
# 1/1 [==============================] - 0s 67ms/step
# epoch:161  d_loss:0.3368  g_loss:1.0743
# 1/1 [==============================] - 0s 65ms/step
# epoch:162  d_loss:0.6242  g_loss:0.9084
# 1/1 [==============================] - 0s 67ms/step
# epoch:163  d_loss:0.6224  g_loss:1.0567
# 1/1 [==============================] - 0s 79ms/step
# epoch:164  d_loss:0.9509  g_loss:0.8338
# 1/1 [==============================] - 0s 67ms/step
# epoch:165  d_loss:0.7244  g_loss:0.7210
# 1/1 [==============================] - 0s 65ms/step
# epoch:166  d_loss:0.7266  g_loss:0.6994
# 1/1 [==============================] - 0s 55ms/step
# epoch:167  d_loss:0.7323  g_loss:0.6941
# 1/1 [==============================] - 0s 66ms/step
# epoch:168  d_loss:0.7871  g_loss:0.9332
# 1/1 [==============================] - 0s 55ms/step
# epoch:169  d_loss:0.5655  g_loss:0.9043
# 1/1 [==============================] - 0s 52ms/step
# epoch:170  d_loss:0.6175  g_loss:1.0447
# 1/1 [==============================] - 0s 48ms/step
# epoch:171  d_loss:0.5413  g_loss:1.1293
# 1/1 [==============================] - 0s 58ms/step
# epoch:172  d_loss:0.5629  g_loss:1.0988
# 1/1 [==============================] - 0s 53ms/step
# epoch:173  d_loss:0.7987  g_loss:1.0859
# 1/1 [==============================] - 0s 53ms/step
# epoch:174  d_loss:0.5898  g_loss:0.9871
# 1/1 [==============================] - 0s 51ms/step
# epoch:175  d_loss:0.5879  g_loss:1.0249
# 1/1 [==============================] - 0s 58ms/step
# epoch:176  d_loss:0.4533  g_loss:1.2096
# 1/1 [==============================] - 0s 52ms/step
# epoch:177  d_loss:0.5183  g_loss:1.2022
# 1/1 [==============================] - 0s 68ms/step
# epoch:178  d_loss:0.4674  g_loss:1.3790
# 1/1 [==============================] - 0s 63ms/step
# epoch:179  d_loss:0.4344  g_loss:1.5944
# 1/1 [==============================] - 0s 60ms/step
# epoch:180  d_loss:0.3785  g_loss:1.7952
# 1/1 [==============================] - 0s 84ms/step
# epoch:181  d_loss:0.3098  g_loss:2.0799
# 1/1 [==============================] - 0s 62ms/step
# epoch:182  d_loss:0.2735  g_loss:2.4045
# 1/1 [==============================] - 0s 51ms/step
# epoch:183  d_loss:0.3009  g_loss:2.5113
# 1/1 [==============================] - 0s 58ms/step
# epoch:184  d_loss:0.2769  g_loss:2.7138
# 1/1 [==============================] - 0s 55ms/step
# epoch:185  d_loss:0.2906  g_loss:2.4668
# 1/1 [==============================] - 0s 48ms/step
# epoch:186  d_loss:0.2201  g_loss:2.8223
# 1/1 [==============================] - 0s 49ms/step
# epoch:187  d_loss:0.2327  g_loss:2.8273
# 1/1 [==============================] - 0s 48ms/step
# epoch:188  d_loss:0.2811  g_loss:2.9156
# 1/1 [==============================] - 0s 55ms/step
# epoch:189  d_loss:0.5198  g_loss:2.2628
# 1/1 [==============================] - 0s 66ms/step
# epoch:190  d_loss:0.5755  g_loss:2.4324
# 1/1 [==============================] - 0s 88ms/step
# epoch:191  d_loss:0.3905  g_loss:2.4317
# 1/1 [==============================] - 0s 53ms/step
# epoch:192  d_loss:0.6126  g_loss:2.7476
# 1/1 [==============================] - 0s 75ms/step
# epoch:193  d_loss:0.6302  g_loss:2.5730
# 1/1 [==============================] - 0s 54ms/step
# epoch:194  d_loss:0.7566  g_loss:2.2994
# 1/1 [==============================] - 0s 54ms/step
# epoch:195  d_loss:0.7930  g_loss:1.7509
# 1/1 [==============================] - 0s 55ms/step
# epoch:196  d_loss:0.7777  g_loss:1.3651
# 1/1 [==============================] - 0s 50ms/step
# epoch:197  d_loss:1.0081  g_loss:1.2952
# 1/1 [==============================] - 0s 55ms/step
# epoch:198  d_loss:0.7922  g_loss:1.3327
# 1/1 [==============================] - 0s 49ms/step
# epoch:199  d_loss:0.7559  g_loss:1.8080
# 1/1 [==============================] - 0s 67ms/step
# epoch:200  d_loss:0.7323  g_loss:1.8450
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# epoch:201  d_loss:0.7369  g_loss:1.8852
# 1/1 [==============================] - 0s 53ms/step
# epoch:202  d_loss:0.6976  g_loss:1.5308
# 1/1 [==============================] - 0s 58ms/step
# epoch:203  d_loss:0.4882  g_loss:1.6359
# 1/1 [==============================] - 0s 59ms/step
# epoch:204  d_loss:0.6202  g_loss:1.6310
# 1/1 [==============================] - 0s 64ms/step
# epoch:205  d_loss:0.5284  g_loss:1.5326
# 1/1 [==============================] - 0s 53ms/step
# epoch:206  d_loss:0.4753  g_loss:1.5009
# 1/1 [==============================] - 0s 53ms/step
# epoch:207  d_loss:0.4956  g_loss:1.5415
# 1/1 [==============================] - 0s 65ms/step
# epoch:208  d_loss:0.4719  g_loss:1.6782
# 1/1 [==============================] - 0s 55ms/step
# epoch:209  d_loss:0.3887  g_loss:1.8119
# 1/1 [==============================] - 0s 61ms/step
# epoch:210  d_loss:0.3955  g_loss:1.9724
# 1/1 [==============================] - 0s 51ms/step
# epoch:211  d_loss:0.4277  g_loss:1.8160
# 1/1 [==============================] - 0s 76ms/step
# epoch:212  d_loss:0.4038  g_loss:1.8883
# 1/1 [==============================] - 0s 46ms/step
# epoch:213  d_loss:0.4146  g_loss:1.7997
# 1/1 [==============================] - 0s 47ms/step
# epoch:214  d_loss:0.4782  g_loss:1.6410
# 1/1 [==============================] - 0s 46ms/step
# epoch:215  d_loss:0.4321  g_loss:1.6427
# 1/1 [==============================] - 0s 50ms/step
# epoch:216  d_loss:0.4097  g_loss:1.7627
# 1/1 [==============================] - 0s 53ms/step
# epoch:217  d_loss:0.3943  g_loss:1.7624
# 1/1 [==============================] - 0s 54ms/step
# epoch:218  d_loss:0.3597  g_loss:1.7976
# 1/1 [==============================] - 0s 51ms/step
# epoch:219  d_loss:0.2782  g_loss:1.8768
# 1/1 [==============================] - 0s 50ms/step
# epoch:220  d_loss:0.3885  g_loss:1.9253
# 1/1 [==============================] - 0s 55ms/step
# epoch:221  d_loss:0.4038  g_loss:1.8064
# 1/1 [==============================] - 0s 55ms/step
# epoch:222  d_loss:0.4436  g_loss:1.5216
# 1/1 [==============================] - 0s 52ms/step
# epoch:223  d_loss:0.4650  g_loss:1.4441
# 1/1 [==============================] - 0s 46ms/step
# epoch:224  d_loss:0.5247  g_loss:1.5965
# 1/1 [==============================] - 0s 53ms/step
# epoch:225  d_loss:0.4278  g_loss:1.4525
# 1/1 [==============================] - 0s 59ms/step
# epoch:226  d_loss:0.6082  g_loss:1.3853
# 1/1 [==============================] - 0s 52ms/step
# epoch:227  d_loss:0.7215  g_loss:1.0150
# 1/1 [==============================] - 0s 57ms/step
# epoch:228  d_loss:0.7059  g_loss:1.2807
# 1/1 [==============================] - 0s 47ms/step
# epoch:229  d_loss:0.6781  g_loss:1.2271
# 1/1 [==============================] - 0s 60ms/step
# epoch:230  d_loss:0.5661  g_loss:1.2512
# 1/1 [==============================] - 0s 70ms/step
# epoch:231  d_loss:0.5860  g_loss:1.0846
# 1/1 [==============================] - 0s 54ms/step
# epoch:232  d_loss:0.5713  g_loss:1.1220
# 1/1 [==============================] - 0s 80ms/step
# epoch:233  d_loss:0.6592  g_loss:1.3328
# 1/1 [==============================] - 0s 59ms/step
# epoch:234  d_loss:0.6571  g_loss:1.1010
# 1/1 [==============================] - 0s 58ms/step
# epoch:235  d_loss:0.8639  g_loss:0.9563
# 1/1 [==============================] - 0s 59ms/step
# epoch:236  d_loss:0.6363  g_loss:1.0806
# 1/1 [==============================] - 0s 48ms/step
# epoch:237  d_loss:0.6394  g_loss:1.1178
# 1/1 [==============================] - 0s 101ms/step
# epoch:238  d_loss:0.6377  g_loss:1.1132
# 1/1 [==============================] - 0s 65ms/step
# epoch:239  d_loss:0.5066  g_loss:1.4834
# 1/1 [==============================] - 0s 62ms/step
# epoch:240  d_loss:0.5143  g_loss:1.7976
# 1/1 [==============================] - 0s 67ms/step
# epoch:241  d_loss:0.5345  g_loss:1.7011
# 1/1 [==============================] - 0s 61ms/step
# epoch:242  d_loss:0.4321  g_loss:1.7650
# 1/1 [==============================] - 0s 62ms/step
# epoch:243  d_loss:0.3845  g_loss:1.8919
# 1/1 [==============================] - 0s 85ms/step
# epoch:244  d_loss:0.3411  g_loss:1.9803
# 1/1 [==============================] - 0s 71ms/step
# epoch:245  d_loss:0.2880  g_loss:2.4225
# 1/1 [==============================] - 0s 56ms/step
# epoch:246  d_loss:0.2462  g_loss:3.3089
# 1/1 [==============================] - 0s 55ms/step
# epoch:247  d_loss:0.2973  g_loss:3.0001
# 1/1 [==============================] - 0s 51ms/step
# epoch:248  d_loss:0.2274  g_loss:2.9830
# 1/1 [==============================] - 0s 50ms/step
# epoch:249  d_loss:0.2065  g_loss:2.7759
# 1/1 [==============================] - 0s 67ms/step
# epoch:250  d_loss:0.2550  g_loss:2.6606
# 1/1 [==============================] - 0s 61ms/step
# epoch:251  d_loss:0.4285  g_loss:2.9421
# 1/1 [==============================] - 0s 53ms/step
# epoch:252  d_loss:0.2013  g_loss:4.0591
# 1/1 [==============================] - 0s 51ms/step
# epoch:253  d_loss:0.5011  g_loss:3.8787
# 1/1 [==============================] - 0s 60ms/step
# epoch:254  d_loss:0.6094  g_loss:2.8761
# 1/1 [==============================] - 0s 53ms/step
# epoch:255  d_loss:0.6120  g_loss:2.6818
# 1/1 [==============================] - 0s 49ms/step
# epoch:256  d_loss:0.8809  g_loss:1.7929
# 1/1 [==============================] - 0s 53ms/step
# epoch:257  d_loss:1.0070  g_loss:1.7185
# 1/1 [==============================] - 0s 53ms/step
# epoch:258  d_loss:0.5615  g_loss:2.1496
# 1/1 [==============================] - 0s 46ms/step
# epoch:259  d_loss:0.6633  g_loss:2.0159
# 1/1 [==============================] - 0s 51ms/step
# epoch:260  d_loss:0.6440  g_loss:2.0922
# 1/1 [==============================] - 0s 52ms/step
# epoch:261  d_loss:0.8931  g_loss:1.4836
# 1/1 [==============================] - 0s 58ms/step
# epoch:262  d_loss:0.5821  g_loss:1.8329
# 1/1 [==============================] - 0s 60ms/step
# epoch:263  d_loss:0.6258  g_loss:1.5979
# 1/1 [==============================] - 0s 61ms/step
# epoch:264  d_loss:0.6490  g_loss:1.6301
# 1/1 [==============================] - 0s 54ms/step
# epoch:265  d_loss:0.5450  g_loss:1.7556
# 1/1 [==============================] - 0s 53ms/step
# epoch:266  d_loss:0.4541  g_loss:1.9130
# 1/1 [==============================] - 0s 51ms/step
# epoch:267  d_loss:0.6138  g_loss:1.5333
# 1/1 [==============================] - 0s 47ms/step
# epoch:268  d_loss:0.5431  g_loss:1.6057
# 1/1 [==============================] - 0s 47ms/step
# epoch:269  d_loss:0.5839  g_loss:1.5164
# 1/1 [==============================] - 0s 47ms/step
# epoch:270  d_loss:0.5132  g_loss:1.5668
# 1/1 [==============================] - 0s 49ms/step
# epoch:271  d_loss:0.4831  g_loss:1.7367
# 1/1 [==============================] - 0s 48ms/step
# epoch:272  d_loss:0.5532  g_loss:1.4097
# 1/1 [==============================] - 0s 58ms/step
# epoch:273  d_loss:0.4884  g_loss:1.4647
# 1/1 [==============================] - 0s 48ms/step
# epoch:274  d_loss:0.5083  g_loss:1.5652
# 1/1 [==============================] - 0s 51ms/step
# epoch:275  d_loss:0.3955  g_loss:1.8403
# 1/1 [==============================] - 0s 53ms/step
# epoch:276  d_loss:0.3694  g_loss:1.8027
# 1/1 [==============================] - 0s 51ms/step
# epoch:277  d_loss:0.4020  g_loss:1.9256
# 1/1 [==============================] - 0s 59ms/step
# epoch:278  d_loss:0.3793  g_loss:1.6740
# 1/1 [==============================] - 0s 49ms/step
# epoch:279  d_loss:0.4200  g_loss:1.6499
# 1/1 [==============================] - 0s 48ms/step
# epoch:280  d_loss:0.4057  g_loss:1.7844
# 1/1 [==============================] - 0s 56ms/step
# epoch:281  d_loss:0.5181  g_loss:1.5556
# 1/1 [==============================] - 0s 47ms/step
# epoch:282  d_loss:0.3415  g_loss:1.4637
# 1/1 [==============================] - 0s 49ms/step
# epoch:283  d_loss:0.3823  g_loss:1.6478
# 1/1 [==============================] - 0s 52ms/step
# epoch:284  d_loss:0.3520  g_loss:1.5171
# 1/1 [==============================] - 0s 47ms/step
# epoch:285  d_loss:0.4467  g_loss:1.6085
# 1/1 [==============================] - 0s 55ms/step
# epoch:286  d_loss:0.3630  g_loss:1.5356
# 1/1 [==============================] - 0s 51ms/step
# epoch:287  d_loss:0.5244  g_loss:1.6083
# 1/1 [==============================] - 0s 57ms/step
# epoch:288  d_loss:0.4232  g_loss:1.6224
# 1/1 [==============================] - 0s 65ms/step
# epoch:289  d_loss:0.3965  g_loss:1.9010
# 1/1 [==============================] - 0s 132ms/step
# epoch:290  d_loss:0.5069  g_loss:1.5819
# 1/1 [==============================] - 0s 74ms/step
# epoch:291  d_loss:0.3551  g_loss:1.4478
# 1/1 [==============================] - 0s 82ms/step
# epoch:292  d_loss:0.3786  g_loss:1.5327
# 1/1 [==============================] - 0s 58ms/step
# epoch:293  d_loss:0.4710  g_loss:1.6570
# 1/1 [==============================] - 0s 110ms/step
# epoch:294  d_loss:0.3319  g_loss:1.7690
# 1/1 [==============================] - 0s 63ms/step
# epoch:295  d_loss:0.4500  g_loss:1.3714
# 1/1 [==============================] - 0s 70ms/step
# epoch:296  d_loss:0.4535  g_loss:1.4202
# 1/1 [==============================] - 0s 56ms/step
# epoch:297  d_loss:0.3378  g_loss:1.6592
# 1/1 [==============================] - 0s 67ms/step
# epoch:298  d_loss:0.4001  g_loss:1.9292
# 1/1 [==============================] - 0s 80ms/step
# epoch:299  d_loss:0.4269  g_loss:1.7547
# 1/1 [==============================] - 0s 74ms/step
# epoch:300  d_loss:0.4001  g_loss:1.6530
# 1/1 [==============================] - 0s 62ms/step
# epoch:301  d_loss:0.5758  g_loss:1.4365
# 1/1 [==============================] - 0s 64ms/step
# epoch:302  d_loss:0.4583  g_loss:1.3559
# 1/1 [==============================] - 0s 65ms/step
# epoch:303  d_loss:0.3412  g_loss:1.3571
# 1/1 [==============================] - 0s 103ms/step
# epoch:304  d_loss:0.3926  g_loss:1.1827
# 1/1 [==============================] - 0s 50ms/step
# epoch:305  d_loss:0.6372  g_loss:1.1970
# 1/1 [==============================] - 0s 71ms/step
# epoch:306  d_loss:0.6532  g_loss:1.3761
# 1/1 [==============================] - 0s 48ms/step
# epoch:307  d_loss:0.3466  g_loss:1.7774
# 1/1 [==============================] - 0s 48ms/step
# epoch:308  d_loss:0.4096  g_loss:1.7071
# 1/1 [==============================] - 0s 51ms/step
# epoch:309  d_loss:0.5734  g_loss:1.9062
# 1/1 [==============================] - 0s 56ms/step
# epoch:310  d_loss:0.4831  g_loss:1.7421
# 1/1 [==============================] - 0s 56ms/step
# epoch:311  d_loss:0.5673  g_loss:1.6131
# 1/1 [==============================] - 0s 68ms/step
# epoch:312  d_loss:0.5389  g_loss:1.5031
# 1/1 [==============================] - 0s 73ms/step
# epoch:313  d_loss:0.5557  g_loss:1.0750
# 1/1 [==============================] - 0s 55ms/step
# epoch:314  d_loss:0.6075  g_loss:1.3324
# 1/1 [==============================] - 0s 47ms/step
# epoch:315  d_loss:0.4906  g_loss:1.4068
# 1/1 [==============================] - 0s 51ms/step
# epoch:316  d_loss:0.4865  g_loss:1.7550
# 1/1 [==============================] - 0s 51ms/step
# epoch:317  d_loss:0.4543  g_loss:1.6065
# 1/1 [==============================] - 0s 47ms/step
# epoch:318  d_loss:0.4566  g_loss:1.4964
# 1/1 [==============================] - 0s 55ms/step
# epoch:319  d_loss:0.6740  g_loss:1.5383
# 1/1 [==============================] - 0s 60ms/step
# epoch:320  d_loss:0.5029  g_loss:1.6132
# 1/1 [==============================] - 0s 178ms/step
# epoch:321  d_loss:0.5094  g_loss:1.5470
# 1/1 [==============================] - 0s 109ms/step
# epoch:322  d_loss:0.4258  g_loss:1.2707
# 1/1 [==============================] - 0s 119ms/step
# epoch:323  d_loss:0.4790  g_loss:1.9467
# 1/1 [==============================] - 0s 72ms/step
# epoch:324  d_loss:0.4020  g_loss:1.7918
# 1/1 [==============================] - 0s 89ms/step
# epoch:325  d_loss:0.3462  g_loss:1.9588
# 1/1 [==============================] - 0s 117ms/step
# epoch:326  d_loss:0.4956  g_loss:2.1028
# 1/1 [==============================] - 0s 84ms/step
# epoch:327  d_loss:0.4246  g_loss:2.0319
# 1/1 [==============================] - 0s 92ms/step
# epoch:328  d_loss:0.3733  g_loss:2.1926
# 1/1 [==============================] - 0s 86ms/step
# epoch:329  d_loss:0.4344  g_loss:1.9594
# 1/1 [==============================] - 0s 86ms/step
# epoch:330  d_loss:0.3666  g_loss:1.7425
# 1/1 [==============================] - 0s 71ms/step
# epoch:331  d_loss:0.4625  g_loss:1.5782
# 1/1 [==============================] - 0s 71ms/step
# epoch:332  d_loss:0.3526  g_loss:1.7010
# 1/1 [==============================] - 0s 90ms/step
# epoch:333  d_loss:0.3343  g_loss:1.7080
# 1/1 [==============================] - 0s 70ms/step
# epoch:334  d_loss:0.3940  g_loss:1.5270
# 1/1 [==============================] - 0s 56ms/step
# epoch:335  d_loss:0.3780  g_loss:2.0851
# 1/1 [==============================] - 0s 53ms/step
# epoch:336  d_loss:0.3343  g_loss:2.0891
# 1/1 [==============================] - 0s 51ms/step
# epoch:337  d_loss:0.2825  g_loss:2.7898
# 1/1 [==============================] - 0s 53ms/step
# epoch:338  d_loss:0.4203  g_loss:2.3959
# 1/1 [==============================] - 0s 57ms/step
# epoch:339  d_loss:0.6214  g_loss:1.9841
# 1/1 [==============================] - 0s 60ms/step
# epoch:340  d_loss:0.5601  g_loss:1.8871
# 1/1 [==============================] - 0s 54ms/step
# epoch:341  d_loss:0.4582  g_loss:1.4788
# 1/1 [==============================] - 0s 53ms/step
# epoch:342  d_loss:0.3868  g_loss:2.0540
# 1/1 [==============================] - 0s 49ms/step
# epoch:343  d_loss:0.4916  g_loss:2.1084
# 1/1 [==============================] - 0s 50ms/step
# epoch:344  d_loss:0.4032  g_loss:2.6294
# 1/1 [==============================] - 0s 55ms/step
# epoch:345  d_loss:0.5671  g_loss:2.0632
# 1/1 [==============================] - 0s 53ms/step
# epoch:346  d_loss:0.4825  g_loss:2.1899
# 1/1 [==============================] - 0s 50ms/step
# epoch:347  d_loss:0.4137  g_loss:1.8396
# 1/1 [==============================] - 0s 55ms/step
# epoch:348  d_loss:0.4339  g_loss:1.9417
# 1/1 [==============================] - 0s 48ms/step
# epoch:349  d_loss:0.4005  g_loss:2.1848
# 1/1 [==============================] - 0s 50ms/step
# epoch:350  d_loss:0.4008  g_loss:2.1523
# 1/1 [==============================] - 0s 47ms/step
# epoch:351  d_loss:0.4338  g_loss:1.9267
# 1/1 [==============================] - 0s 66ms/step
# epoch:352  d_loss:0.4625  g_loss:1.7887
# 1/1 [==============================] - 0s 51ms/step
# epoch:353  d_loss:0.5465  g_loss:1.5594
# 1/1 [==============================] - 0s 50ms/step
# epoch:354  d_loss:0.4879  g_loss:1.5083
# 1/1 [==============================] - 0s 58ms/step
# epoch:355  d_loss:0.4406  g_loss:1.7889
# 1/1 [==============================] - 0s 51ms/step
# epoch:356  d_loss:0.4356  g_loss:1.4728
# 1/1 [==============================] - 0s 73ms/step
# epoch:357  d_loss:0.4700  g_loss:1.3543
# 1/1 [==============================] - 0s 52ms/step
# epoch:358  d_loss:0.3860  g_loss:1.8189
# 1/1 [==============================] - 0s 45ms/step
# epoch:359  d_loss:0.5183  g_loss:1.7187
# 1/1 [==============================] - 0s 60ms/step
# epoch:360  d_loss:0.4676  g_loss:1.8636
# 1/1 [==============================] - 0s 53ms/step
# epoch:361  d_loss:0.5777  g_loss:1.8092
# 1/1 [==============================] - 0s 53ms/step
# epoch:362  d_loss:0.6026  g_loss:1.4702
# 1/1 [==============================] - 0s 49ms/step
# epoch:363  d_loss:0.4227  g_loss:1.5295
# 1/1 [==============================] - 0s 52ms/step
# epoch:364  d_loss:0.4821  g_loss:1.6033
# 1/1 [==============================] - 0s 56ms/step
# epoch:365  d_loss:0.4891  g_loss:1.7110
# 1/1 [==============================] - 0s 50ms/step
# epoch:366  d_loss:0.4359  g_loss:1.6428
# 1/1 [==============================] - 0s 55ms/step
# epoch:367  d_loss:0.3868  g_loss:1.6427
# 1/1 [==============================] - 0s 51ms/step
# epoch:368  d_loss:0.3326  g_loss:1.7270
# 1/1 [==============================] - 0s 54ms/step
# epoch:369  d_loss:0.3476  g_loss:1.8470
# 1/1 [==============================] - 0s 50ms/step
# epoch:370  d_loss:0.4120  g_loss:1.9587
# 1/1 [==============================] - 0s 55ms/step
# epoch:371  d_loss:0.4079  g_loss:1.8084
# 1/1 [==============================] - 0s 55ms/step
# epoch:372  d_loss:0.5279  g_loss:1.7910
# 1/1 [==============================] - 0s 59ms/step
# epoch:373  d_loss:0.3088  g_loss:1.9061
# 1/1 [==============================] - 0s 52ms/step
# epoch:374  d_loss:0.4717  g_loss:1.5487
# 1/1 [==============================] - 0s 68ms/step
# epoch:375  d_loss:0.3475  g_loss:1.8159
# 1/1 [==============================] - 0s 67ms/step
# epoch:376  d_loss:0.5030  g_loss:1.9419
# 1/1 [==============================] - 0s 55ms/step
# epoch:377  d_loss:0.4714  g_loss:1.7143
# 1/1 [==============================] - 0s 48ms/step
# epoch:378  d_loss:0.3162  g_loss:1.9642
# 1/1 [==============================] - 0s 62ms/step
# epoch:379  d_loss:0.4379  g_loss:1.8340
# 1/1 [==============================] - 0s 53ms/step
# epoch:380  d_loss:0.4321  g_loss:1.7953
# 1/1 [==============================] - 0s 57ms/step
# epoch:381  d_loss:0.3540  g_loss:1.5856
# 1/1 [==============================] - 0s 50ms/step
# epoch:382  d_loss:0.3514  g_loss:1.3679
# 1/1 [==============================] - 0s 45ms/step
# epoch:383  d_loss:0.3905  g_loss:1.6561
# 1/1 [==============================] - 0s 58ms/step
# epoch:384  d_loss:0.4373  g_loss:1.9227
# 1/1 [==============================] - 0s 57ms/step
# epoch:385  d_loss:0.3410  g_loss:2.0190
# 1/1 [==============================] - 0s 73ms/step
# epoch:386  d_loss:0.4011  g_loss:2.0005
# 1/1 [==============================] - 0s 64ms/step
# epoch:387  d_loss:0.3856  g_loss:2.1827
# 1/1 [==============================] - 0s 79ms/step
# epoch:388  d_loss:0.4035  g_loss:1.7499
# 1/1 [==============================] - 0s 75ms/step
# epoch:389  d_loss:0.3722  g_loss:1.7463
# 1/1 [==============================] - 0s 69ms/step
# epoch:390  d_loss:0.4871  g_loss:1.7784
# 1/1 [==============================] - 0s 73ms/step
# epoch:391  d_loss:0.4760  g_loss:1.7314
# 1/1 [==============================] - 0s 183ms/step
# epoch:392  d_loss:0.5269  g_loss:1.7139
# 1/1 [==============================] - 0s 92ms/step
# epoch:393  d_loss:0.3255  g_loss:2.1904
# 1/1 [==============================] - 0s 67ms/step
# epoch:394  d_loss:0.4193  g_loss:2.2737
# 1/1 [==============================] - 0s 69ms/step
# epoch:395  d_loss:0.5613  g_loss:1.8991
# 1/1 [==============================] - 0s 89ms/step
# epoch:396  d_loss:0.3945  g_loss:1.5241
# 1/1 [==============================] - 0s 71ms/step
# epoch:397  d_loss:0.3876  g_loss:1.4601
# 1/1 [==============================] - 0s 67ms/step
# epoch:398  d_loss:0.4371  g_loss:1.6604
# 1/1 [==============================] - 0s 68ms/step
# epoch:399  d_loss:0.3263  g_loss:1.9220
# 1/1 [==============================] - 0s 60ms/step
# epoch:400  d_loss:0.4111  g_loss:1.6554
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 97ms/step
# epoch:401  d_loss:0.3646  g_loss:1.7638
# 1/1 [==============================] - 0s 85ms/step
# epoch:402  d_loss:0.3598  g_loss:1.8429
# 1/1 [==============================] - 0s 46ms/step
# epoch:403  d_loss:0.3145  g_loss:1.9054
# 1/1 [==============================] - 0s 63ms/step
# epoch:404  d_loss:0.3781  g_loss:1.7067
# 1/1 [==============================] - 0s 49ms/step
# epoch:405  d_loss:0.3759  g_loss:2.0026
# 1/1 [==============================] - 0s 58ms/step
# epoch:406  d_loss:0.3744  g_loss:2.0161
# 1/1 [==============================] - 0s 61ms/step
# epoch:407  d_loss:0.4489  g_loss:2.3005
# 1/1 [==============================] - 0s 71ms/step
# epoch:408  d_loss:0.3101  g_loss:2.0973
# 1/1 [==============================] - 0s 66ms/step
# epoch:409  d_loss:0.4239  g_loss:1.8434
# 1/1 [==============================] - 0s 59ms/step
# epoch:410  d_loss:0.3563  g_loss:1.9061
# 1/1 [==============================] - 0s 84ms/step
# epoch:411  d_loss:0.2846  g_loss:1.8432
# 1/1 [==============================] - 0s 66ms/step
# epoch:412  d_loss:0.4449  g_loss:2.0366
# 1/1 [==============================] - 0s 57ms/step
# epoch:413  d_loss:0.3578  g_loss:1.7535
# 1/1 [==============================] - 0s 85ms/step
# epoch:414  d_loss:0.4064  g_loss:2.0696
# 1/1 [==============================] - 0s 75ms/step
# epoch:415  d_loss:0.2699  g_loss:2.6038
# 1/1 [==============================] - 0s 59ms/step
# epoch:416  d_loss:0.2859  g_loss:2.6475
# 1/1 [==============================] - 0s 47ms/step
# epoch:417  d_loss:0.2833  g_loss:2.3570
# 1/1 [==============================] - 0s 111ms/step
# epoch:418  d_loss:0.2643  g_loss:3.0195
# 1/1 [==============================] - 0s 69ms/step
# epoch:419  d_loss:0.3424  g_loss:1.9974
# 1/1 [==============================] - 0s 55ms/step
# epoch:420  d_loss:0.3189  g_loss:2.0009
# 1/1 [==============================] - 0s 67ms/step
# epoch:421  d_loss:0.4465  g_loss:1.9360
# 1/1 [==============================] - 0s 57ms/step
# epoch:422  d_loss:0.2218  g_loss:2.3887
# 1/1 [==============================] - 0s 52ms/step
# epoch:423  d_loss:0.3579  g_loss:2.3898
# 1/1 [==============================] - 0s 74ms/step
# epoch:424  d_loss:0.3637  g_loss:1.9714
# 1/1 [==============================] - 0s 64ms/step
# epoch:425  d_loss:0.3021  g_loss:2.5199
# 1/1 [==============================] - 0s 184ms/step
# epoch:426  d_loss:0.2675  g_loss:2.2133
# 1/1 [==============================] - 0s 78ms/step
# epoch:427  d_loss:0.3629  g_loss:2.7841
# 1/1 [==============================] - 0s 94ms/step
# epoch:428  d_loss:0.2999  g_loss:2.1614
# 1/1 [==============================] - 0s 93ms/step
# epoch:429  d_loss:0.3213  g_loss:2.1952
# 1/1 [==============================] - 0s 92ms/step
# epoch:430  d_loss:0.3576  g_loss:2.1985
# 1/1 [==============================] - 0s 89ms/step
# epoch:431  d_loss:0.3260  g_loss:2.3808
# 1/1 [==============================] - 0s 69ms/step
# epoch:432  d_loss:0.3420  g_loss:2.7323
# 1/1 [==============================] - 0s 77ms/step
# epoch:433  d_loss:0.2789  g_loss:2.2070
# 1/1 [==============================] - 0s 71ms/step
# epoch:434  d_loss:0.3128  g_loss:1.9469
# 1/1 [==============================] - 0s 45ms/step
# epoch:435  d_loss:0.3117  g_loss:2.0793
# 1/1 [==============================] - 0s 55ms/step
# epoch:436  d_loss:0.4016  g_loss:1.9472
# 1/1 [==============================] - 0s 54ms/step
# epoch:437  d_loss:0.3433  g_loss:1.9798
# 1/1 [==============================] - 0s 60ms/step
# epoch:438  d_loss:0.3275  g_loss:2.6960
# 1/1 [==============================] - 0s 70ms/step
# epoch:439  d_loss:0.2977  g_loss:2.2088
# 1/1 [==============================] - 0s 77ms/step
# epoch:440  d_loss:0.4116  g_loss:2.1321
# 1/1 [==============================] - 0s 85ms/step
# epoch:441  d_loss:0.4570  g_loss:2.3773
# 1/1 [==============================] - 0s 69ms/step
# epoch:442  d_loss:0.2792  g_loss:3.0724
# 1/1 [==============================] - 0s 63ms/step
# epoch:443  d_loss:0.5822  g_loss:2.5282
# 1/1 [==============================] - 0s 68ms/step
# epoch:444  d_loss:0.5287  g_loss:1.8573
# 1/1 [==============================] - 0s 51ms/step
# epoch:445  d_loss:0.4963  g_loss:1.3429
# 1/1 [==============================] - 0s 55ms/step
# epoch:446  d_loss:0.4172  g_loss:1.9242
# 1/1 [==============================] - 0s 55ms/step
# epoch:447  d_loss:0.2481  g_loss:2.1274
# 1/1 [==============================] - 0s 56ms/step
# epoch:448  d_loss:0.2499  g_loss:2.4099
# 1/1 [==============================] - 0s 52ms/step
# epoch:449  d_loss:0.4175  g_loss:2.0247
# 1/1 [==============================] - 0s 63ms/step
# epoch:450  d_loss:0.3077  g_loss:2.0846
# 1/1 [==============================] - 0s 70ms/step
# epoch:451  d_loss:0.3557  g_loss:1.9880
# 1/1 [==============================] - 0s 54ms/step
# epoch:452  d_loss:0.2713  g_loss:2.0213
# 1/1 [==============================] - 0s 62ms/step
# epoch:453  d_loss:0.3328  g_loss:2.1129
# 1/1 [==============================] - 0s 55ms/step
# epoch:454  d_loss:0.3096  g_loss:2.5367
# 1/1 [==============================] - 0s 55ms/step
# epoch:455  d_loss:0.3053  g_loss:2.2084
# 1/1 [==============================] - 0s 68ms/step
# epoch:456  d_loss:0.2837  g_loss:2.4865
# 1/1 [==============================] - 0s 51ms/step
# epoch:457  d_loss:0.3076  g_loss:2.3700
# 1/1 [==============================] - 0s 63ms/step
# epoch:458  d_loss:0.3411  g_loss:2.4747
# 1/1 [==============================] - 0s 49ms/step
# epoch:459  d_loss:0.2385  g_loss:2.6346
# 1/1 [==============================] - 0s 56ms/step
# epoch:460  d_loss:0.3264  g_loss:2.4280
# 1/1 [==============================] - 0s 51ms/step
# epoch:461  d_loss:0.2651  g_loss:2.5895
# 1/1 [==============================] - 0s 75ms/step
# epoch:462  d_loss:0.2726  g_loss:2.3408
# 1/1 [==============================] - 0s 79ms/step
# epoch:463  d_loss:0.3471  g_loss:2.1205
# 1/1 [==============================] - 0s 58ms/step
# epoch:464  d_loss:0.2563  g_loss:2.7263
# 1/1 [==============================] - 0s 66ms/step
# epoch:465  d_loss:0.2196  g_loss:3.0425
# 1/1 [==============================] - 0s 73ms/step
# epoch:466  d_loss:0.2523  g_loss:2.6433
# 1/1 [==============================] - 0s 59ms/step
# epoch:467  d_loss:0.1787  g_loss:2.4830
# 1/1 [==============================] - 0s 67ms/step
# epoch:468  d_loss:0.2423  g_loss:2.5295
# 1/1 [==============================] - 0s 57ms/step
# epoch:469  d_loss:0.1778  g_loss:2.3659
# 1/1 [==============================] - 0s 67ms/step
# epoch:470  d_loss:0.2391  g_loss:2.5345
# 1/1 [==============================] - 0s 64ms/step
# epoch:471  d_loss:0.2260  g_loss:2.3343
# 1/1 [==============================] - 0s 65ms/step
# epoch:472  d_loss:0.2350  g_loss:2.9803
# 1/1 [==============================] - 0s 103ms/step
# epoch:473  d_loss:0.1917  g_loss:2.6799
# 1/1 [==============================] - 0s 75ms/step
# epoch:474  d_loss:0.1755  g_loss:2.9095
# 1/1 [==============================] - 0s 56ms/step
# epoch:475  d_loss:0.1807  g_loss:2.1535
# 1/1 [==============================] - 0s 58ms/step
# epoch:476  d_loss:0.2951  g_loss:2.1307
# 1/1 [==============================] - 0s 58ms/step
# epoch:477  d_loss:0.2327  g_loss:2.6418
# 1/1 [==============================] - 0s 66ms/step
# epoch:478  d_loss:0.1568  g_loss:2.2263
# 1/1 [==============================] - 0s 56ms/step
# epoch:479  d_loss:0.2207  g_loss:2.1926
# 1/1 [==============================] - 0s 88ms/step
# epoch:480  d_loss:0.1866  g_loss:2.4491
# 1/1 [==============================] - 0s 68ms/step
# epoch:481  d_loss:0.2101  g_loss:2.1910
# 1/1 [==============================] - 0s 56ms/step
# epoch:482  d_loss:0.2282  g_loss:2.9459
# 1/1 [==============================] - 0s 56ms/step
# epoch:483  d_loss:0.2282  g_loss:2.7063
# 1/1 [==============================] - 0s 60ms/step
# epoch:484  d_loss:0.2069  g_loss:3.0934
# 1/1 [==============================] - 0s 63ms/step
# epoch:485  d_loss:0.3991  g_loss:2.7684
# 1/1 [==============================] - 0s 79ms/step
# epoch:486  d_loss:0.3088  g_loss:2.1439
# 1/1 [==============================] - 0s 54ms/step
# epoch:487  d_loss:0.3286  g_loss:2.2470
# 1/1 [==============================] - 0s 59ms/step
# epoch:488  d_loss:0.1699  g_loss:2.8318
# 1/1 [==============================] - 0s 50ms/step
# epoch:489  d_loss:0.3472  g_loss:3.1979
# 1/1 [==============================] - 0s 51ms/step
# epoch:490  d_loss:0.3174  g_loss:3.0692
# 1/1 [==============================] - 0s 62ms/step
# epoch:491  d_loss:0.4227  g_loss:1.9451
# 1/1 [==============================] - 0s 50ms/step
# epoch:492  d_loss:0.2473  g_loss:1.8933
# 1/1 [==============================] - 0s 65ms/step
# epoch:493  d_loss:0.2772  g_loss:2.5323
# 1/1 [==============================] - 0s 54ms/step
# epoch:494  d_loss:0.2468  g_loss:2.7821
# 1/1 [==============================] - 0s 57ms/step
# epoch:495  d_loss:0.2305  g_loss:3.1533
# 1/1 [==============================] - 0s 64ms/step
# epoch:496  d_loss:0.2084  g_loss:3.2190
# 1/1 [==============================] - 0s 71ms/step
# epoch:497  d_loss:0.2195  g_loss:2.7276
# 1/1 [==============================] - 0s 73ms/step
# epoch:498  d_loss:0.3105  g_loss:2.4001
# 1/1 [==============================] - 0s 69ms/step
# epoch:499  d_loss:0.2130  g_loss:2.6287
# 1/1 [==============================] - 0s 56ms/step
# epoch:500  d_loss:0.2268  g_loss:2.7066
# 1/1 [==============================] - 0s 59ms/step
# epoch:501  d_loss:0.2052  g_loss:2.6468
# 1/1 [==============================] - 0s 56ms/step
# epoch:502  d_loss:0.2130  g_loss:2.8767
# 1/1 [==============================] - 0s 102ms/step
# epoch:503  d_loss:0.3289  g_loss:2.5156
# 1/1 [==============================] - 0s 65ms/step
# epoch:504  d_loss:0.2018  g_loss:3.2481
# 1/1 [==============================] - 0s 68ms/step
# epoch:505  d_loss:0.1313  g_loss:2.8438
# 1/1 [==============================] - 0s 55ms/step
# epoch:506  d_loss:0.1994  g_loss:2.8733
# 1/1 [==============================] - 0s 64ms/step
# epoch:507  d_loss:0.3193  g_loss:2.2431
# 1/1 [==============================] - 0s 65ms/step
# epoch:508  d_loss:0.1271  g_loss:2.7088
# 1/1 [==============================] - 0s 70ms/step
# epoch:509  d_loss:0.2040  g_loss:2.9815
# 1/1 [==============================] - 0s 61ms/step
# epoch:510  d_loss:0.1995  g_loss:2.8877
# 1/1 [==============================] - 0s 56ms/step
# epoch:511  d_loss:0.2169  g_loss:3.0574
# ...
# 1/1 [==============================] - 0s 100ms/step
# epoch:1830  d_loss:0.4523  g_loss:1.9754
# 1/1 [==============================] - 0s 92ms/step
# epoch:1831  d_loss:0.6003  g_loss:1.8722
# 1/1 [==============================] - 0s 79ms/step
# epoch:1832  d_loss:0.5551  g_loss:1.8268
# 1/1 [==============================] - 0s 98ms/step
# epoch:1833  d_loss:0.6920  g_loss:1.1730
# 1/1 [==============================] - 0s 117ms/step
# epoch:1834  d_loss:0.5050  g_loss:1.2999
# 1/1 [==============================] - 0s 86ms/step
# epoch:1835  d_loss:0.4981  g_loss:1.0413
# 1/1 [==============================] - 0s 110ms/step
# epoch:1836  d_loss:0.4638  g_loss:1.5517
# 1/1 [==============================] - 0s 104ms/step
# epoch:1837  d_loss:0.4067  g_loss:1.8995
# 1/1 [==============================] - 0s 119ms/step
# epoch:1838  d_loss:0.3563  g_loss:2.1851
# 1/1 [==============================] - 0s 93ms/step
# epoch:1839  d_loss:0.5661  g_loss:2.3535
# 1/1 [==============================] - 0s 110ms/step
# epoch:1840  d_loss:0.4621  g_loss:1.8810
# 1/1 [==============================] - 0s 89ms/step
# epoch:1841  d_loss:0.5431  g_loss:1.9215
# 1/1 [==============================] - 0s 125ms/step
# epoch:1842  d_loss:0.4337  g_loss:1.6662
# 1/1 [==============================] - 0s 83ms/step
# epoch:1843  d_loss:0.5586  g_loss:1.2834
# 1/1 [==============================] - 0s 68ms/step
# epoch:1844  d_loss:0.5087  g_loss:1.5413
# 1/1 [==============================] - 0s 73ms/step
# epoch:1845  d_loss:0.4587  g_loss:1.7628
# 1/1 [==============================] - 0s 67ms/step
# epoch:1846  d_loss:0.4807  g_loss:1.7478
# 1/1 [==============================] - 0s 62ms/step
# epoch:1847  d_loss:0.4232  g_loss:2.0501
# 1/1 [==============================] - 0s 69ms/step
# epoch:1848  d_loss:0.4178  g_loss:1.8175
# 1/1 [==============================] - 0s 83ms/step
# epoch:1849  d_loss:0.5302  g_loss:1.6550
# 1/1 [==============================] - 0s 77ms/step
# epoch:1850  d_loss:0.5142  g_loss:1.6280
# 1/1 [==============================] - 0s 83ms/step
# epoch:1851  d_loss:0.4977  g_loss:1.8118
# 1/1 [==============================] - 0s 77ms/step
# epoch:1852  d_loss:0.3689  g_loss:2.2019
# 1/1 [==============================] - 0s 67ms/step
# epoch:1853  d_loss:0.4954  g_loss:2.1812
# 1/1 [==============================] - 0s 84ms/step
# epoch:1854  d_loss:0.3833  g_loss:2.0266
# 1/1 [==============================] - 0s 81ms/step
# epoch:1855  d_loss:0.3823  g_loss:1.6196
# 1/1 [==============================] - 0s 87ms/step
# epoch:1856  d_loss:0.3816  g_loss:1.9643
# 1/1 [==============================] - 0s 129ms/step
# epoch:1857  d_loss:0.4258  g_loss:1.9904
# 1/1 [==============================] - 0s 91ms/step
# epoch:1858  d_loss:0.3995  g_loss:1.9352
# 1/1 [==============================] - 0s 78ms/step
# epoch:1859  d_loss:0.5311  g_loss:1.5928
# 1/1 [==============================] - 0s 146ms/step
# epoch:1860  d_loss:0.4995  g_loss:1.6525
# 1/1 [==============================] - 0s 92ms/step
# epoch:1861  d_loss:0.4104  g_loss:2.1855
# 1/1 [==============================] - 0s 81ms/step
# epoch:1862  d_loss:0.5419  g_loss:1.7069
# 1/1 [==============================] - 0s 72ms/step
# epoch:1863  d_loss:0.5127  g_loss:1.7939
# 1/1 [==============================] - 0s 112ms/step
# epoch:1864  d_loss:0.4949  g_loss:1.5284
# 1/1 [==============================] - 0s 67ms/step
# epoch:1865  d_loss:0.6135  g_loss:1.2086
# 1/1 [==============================] - 0s 145ms/step
# epoch:1866  d_loss:0.5591  g_loss:1.1450
# 1/1 [==============================] - 0s 128ms/step
# epoch:1867  d_loss:0.5198  g_loss:1.6114
# 1/1 [==============================] - 0s 141ms/step
# epoch:1868  d_loss:0.4392  g_loss:1.4775
# 1/1 [==============================] - 0s 224ms/step
# epoch:1869  d_loss:0.5422  g_loss:1.7309
# 1/1 [==============================] - 0s 110ms/step
# epoch:1870  d_loss:0.6233  g_loss:1.4370
# 1/1 [==============================] - 0s 113ms/step
# epoch:1871  d_loss:0.5652  g_loss:1.5799
# 1/1 [==============================] - 0s 77ms/step
# epoch:1872  d_loss:0.6792  g_loss:1.3766
# 1/1 [==============================] - 0s 88ms/step
# epoch:1873  d_loss:0.5918  g_loss:1.5189
# 1/1 [==============================] - 0s 61ms/step
# epoch:1874  d_loss:0.5067  g_loss:1.5541
# 1/1 [==============================] - 0s 90ms/step
# epoch:1875  d_loss:0.4326  g_loss:1.5314
# 1/1 [==============================] - 0s 66ms/step
# epoch:1876  d_loss:0.5548  g_loss:1.1719
# 1/1 [==============================] - 0s 71ms/step
# epoch:1877  d_loss:0.5312  g_loss:1.1445
# 1/1 [==============================] - 0s 68ms/step
# epoch:1878  d_loss:0.5013  g_loss:1.6162
# 1/1 [==============================] - 0s 76ms/step
# epoch:1879  d_loss:0.5550  g_loss:1.6675
# 1/1 [==============================] - 0s 77ms/step
# epoch:1880  d_loss:0.3931  g_loss:1.6987
# 1/1 [==============================] - 0s 74ms/step
# epoch:1881  d_loss:0.4133  g_loss:1.9344
# 1/1 [==============================] - 0s 79ms/step
# epoch:1882  d_loss:0.4857  g_loss:1.7588
# 1/1 [==============================] - 0s 76ms/step
# epoch:1883  d_loss:0.5231  g_loss:1.8667
# 1/1 [==============================] - 0s 68ms/step
# epoch:1884  d_loss:0.5049  g_loss:1.6912
# 1/1 [==============================] - 0s 89ms/step
# epoch:1885  d_loss:0.5457  g_loss:1.6118
# 1/1 [==============================] - 0s 78ms/step
# epoch:1886  d_loss:0.5465  g_loss:1.3235
# 1/1 [==============================] - 0s 70ms/step
# epoch:1887  d_loss:0.4167  g_loss:1.6204
# 1/1 [==============================] - 0s 93ms/step
# epoch:1888  d_loss:0.4081  g_loss:1.8896
# 1/1 [==============================] - 0s 86ms/step
# epoch:1889  d_loss:0.4233  g_loss:1.6848
# 1/1 [==============================] - 0s 62ms/step
# epoch:1890  d_loss:0.3798  g_loss:1.7775
# 1/1 [==============================] - 0s 73ms/step
# epoch:1891  d_loss:0.3702  g_loss:2.0724
# 1/1 [==============================] - 0s 64ms/step
# epoch:1892  d_loss:0.3646  g_loss:2.2117
# 1/1 [==============================] - 0s 80ms/step
# epoch:1893  d_loss:0.4663  g_loss:1.6278
# 1/1 [==============================] - 0s 62ms/step
# epoch:1894  d_loss:0.4343  g_loss:1.7120
# 1/1 [==============================] - 0s 60ms/step
# epoch:1895  d_loss:0.4027  g_loss:1.5039
# 1/1 [==============================] - 0s 94ms/step
# epoch:1896  d_loss:0.4555  g_loss:1.2804
# 1/1 [==============================] - 0s 81ms/step
# epoch:1897  d_loss:0.3902  g_loss:1.4504
# 1/1 [==============================] - 0s 70ms/step
# epoch:1898  d_loss:0.5233  g_loss:1.6386
# 1/1 [==============================] - 0s 85ms/step
# epoch:1899  d_loss:0.5042  g_loss:1.4689
# 1/1 [==============================] - 0s 80ms/step
# epoch:1900  d_loss:0.4696  g_loss:1.8377
# 1/1 [==============================] - 0s 74ms/step
# epoch:1901  d_loss:0.4870  g_loss:1.6831
# 1/1 [==============================] - 0s 69ms/step
# epoch:1902  d_loss:0.6780  g_loss:1.4329
# 1/1 [==============================] - 0s 76ms/step
# epoch:1903  d_loss:0.5564  g_loss:1.5788
# 1/1 [==============================] - 0s 81ms/step
# epoch:1904  d_loss:0.5517  g_loss:1.5412
# 1/1 [==============================] - 0s 75ms/step
# epoch:1905  d_loss:0.6134  g_loss:1.4703
# 1/1 [==============================] - 0s 74ms/step
# epoch:1906  d_loss:0.5636  g_loss:1.5491
# 1/1 [==============================] - 0s 69ms/step
# epoch:1907  d_loss:0.5963  g_loss:1.5637
# 1/1 [==============================] - 0s 76ms/step
# epoch:1908  d_loss:0.6231  g_loss:1.6717
# 1/1 [==============================] - 0s 97ms/step
# epoch:1909  d_loss:0.5400  g_loss:1.8578
# 1/1 [==============================] - 0s 99ms/step
# epoch:1910  d_loss:0.5180  g_loss:1.3758
# 1/1 [==============================] - 0s 99ms/step
# epoch:1911  d_loss:0.7492  g_loss:1.2000
# 1/1 [==============================] - 0s 78ms/step
# epoch:1912  d_loss:0.6372  g_loss:0.9373
# 1/1 [==============================] - 0s 85ms/step
# epoch:1913  d_loss:0.6019  g_loss:1.1379
# 1/1 [==============================] - 0s 82ms/step
# epoch:1914  d_loss:0.4294  g_loss:1.5006
# 1/1 [==============================] - 0s 75ms/step
# epoch:1915  d_loss:0.4551  g_loss:2.0406
# 1/1 [==============================] - 0s 92ms/step
# epoch:1916  d_loss:0.5261  g_loss:1.8226
# 1/1 [==============================] - 0s 116ms/step
# epoch:1917  d_loss:0.5144  g_loss:1.7853
# 1/1 [==============================] - 0s 105ms/step
# epoch:1918  d_loss:0.5411  g_loss:1.4506
# 1/1 [==============================] - 0s 113ms/step
# epoch:1919  d_loss:0.4532  g_loss:1.2761
# 1/1 [==============================] - 0s 102ms/step
# epoch:1920  d_loss:0.3582  g_loss:1.2324
# 1/1 [==============================] - 0s 91ms/step
# epoch:1921  d_loss:0.4956  g_loss:1.3892
# 1/1 [==============================] - 0s 88ms/step
# epoch:1922  d_loss:0.5057  g_loss:1.4053
# 1/1 [==============================] - 0s 73ms/step
# epoch:1923  d_loss:0.3993  g_loss:2.0859
# 1/1 [==============================] - 0s 75ms/step
# epoch:1924  d_loss:0.3050  g_loss:1.8978
# 1/1 [==============================] - 0s 68ms/step
# epoch:1925  d_loss:0.3625  g_loss:2.0383
# 1/1 [==============================] - 0s 64ms/step
# epoch:1926  d_loss:0.5106  g_loss:1.7396
# 1/1 [==============================] - 0s 70ms/step
# epoch:1927  d_loss:0.3696  g_loss:1.7521
# 1/1 [==============================] - 0s 76ms/step
# epoch:1928  d_loss:0.2736  g_loss:1.8360
# 1/1 [==============================] - 0s 95ms/step
# epoch:1929  d_loss:0.4320  g_loss:1.8402
# 1/1 [==============================] - 0s 102ms/step
# epoch:1930  d_loss:0.3966  g_loss:1.9972
# 1/1 [==============================] - 0s 103ms/step
# epoch:1931  d_loss:0.3648  g_loss:2.3106
# 1/1 [==============================] - 0s 84ms/step
# epoch:1932  d_loss:0.4704  g_loss:2.0735
# 1/1 [==============================] - 0s 85ms/step
# epoch:1933  d_loss:0.4890  g_loss:1.9466
# 1/1 [==============================] - 0s 84ms/step
# epoch:1934  d_loss:0.4977  g_loss:1.9084
# 1/1 [==============================] - 0s 91ms/step
# epoch:1935  d_loss:0.5160  g_loss:1.4487
# 1/1 [==============================] - 0s 92ms/step
# epoch:1936  d_loss:0.4337  g_loss:1.7082
# 1/1 [==============================] - 0s 90ms/step
# epoch:1937  d_loss:0.5092  g_loss:1.8915
# 1/1 [==============================] - 0s 102ms/step
# epoch:1938  d_loss:0.4180  g_loss:2.1709
# 1/1 [==============================] - 0s 79ms/step
# epoch:1939  d_loss:0.4717  g_loss:1.8335
# 1/1 [==============================] - 0s 89ms/step
# epoch:1940  d_loss:0.3982  g_loss:1.8979
# 1/1 [==============================] - 0s 86ms/step
# epoch:1941  d_loss:0.3873  g_loss:1.7294
# 1/1 [==============================] - 0s 77ms/step
# epoch:1942  d_loss:0.4848  g_loss:1.3316
# 1/1 [==============================] - 0s 76ms/step
# epoch:1943  d_loss:0.6520  g_loss:1.2771
# 1/1 [==============================] - 0s 75ms/step
# epoch:1944  d_loss:0.6250  g_loss:1.2583
# 1/1 [==============================] - 0s 75ms/step
# epoch:1945  d_loss:0.5439  g_loss:1.5063
# 1/1 [==============================] - 0s 101ms/step
# epoch:1946  d_loss:0.7168  g_loss:1.1294
# 1/1 [==============================] - 0s 62ms/step
# epoch:1947  d_loss:0.5586  g_loss:1.7839
# 1/1 [==============================] - 0s 79ms/step
# epoch:1948  d_loss:0.5111  g_loss:1.9083
# 1/1 [==============================] - 0s 72ms/step
# epoch:1949  d_loss:0.6048  g_loss:1.4304
# 1/1 [==============================] - 0s 73ms/step
# epoch:1950  d_loss:0.5505  g_loss:1.3078
# 1/1 [==============================] - 0s 70ms/step
# epoch:1951  d_loss:0.5245  g_loss:1.5782
# 1/1 [==============================] - 0s 56ms/step
# epoch:1952  d_loss:0.5192  g_loss:1.4299
# 1/1 [==============================] - 0s 89ms/step
# epoch:1953  d_loss:0.5492  g_loss:1.3699
# 1/1 [==============================] - 0s 90ms/step
# epoch:1954  d_loss:0.4962  g_loss:1.4807
# 1/1 [==============================] - 0s 99ms/step
# epoch:1955  d_loss:0.5748  g_loss:1.5417
# 1/1 [==============================] - 0s 77ms/step
# epoch:1956  d_loss:0.4704  g_loss:1.5522
# 1/1 [==============================] - 0s 131ms/step
# epoch:1957  d_loss:0.4252  g_loss:1.9228
# 1/1 [==============================] - 0s 125ms/step
# epoch:1958  d_loss:0.5316  g_loss:1.8928
# 1/1 [==============================] - 0s 84ms/step
# epoch:1959  d_loss:0.4593  g_loss:1.5768
# 1/1 [==============================] - 0s 105ms/step
# epoch:1960  d_loss:0.4665  g_loss:1.6785
# 1/1 [==============================] - 0s 107ms/step
# epoch:1961  d_loss:0.4852  g_loss:1.4849
# 1/1 [==============================] - 0s 79ms/step
# epoch:1962  d_loss:0.3177  g_loss:1.9366
# 1/1 [==============================] - 0s 163ms/step
# epoch:1963  d_loss:0.3771  g_loss:2.3209
# 1/1 [==============================] - 0s 74ms/step
# epoch:1964  d_loss:0.5159  g_loss:1.7306
# 1/1 [==============================] - 0s 91ms/step
# epoch:1965  d_loss:0.3756  g_loss:1.5620
# 1/1 [==============================] - 0s 108ms/step
# epoch:1966  d_loss:0.4277  g_loss:1.5417
# 1/1 [==============================] - 0s 78ms/step
# epoch:1967  d_loss:0.4673  g_loss:1.6421
# 1/1 [==============================] - 0s 78ms/step
# epoch:1968  d_loss:0.2989  g_loss:1.9984
# 1/1 [==============================] - 0s 93ms/step
# epoch:1969  d_loss:0.4233  g_loss:2.0074
# 1/1 [==============================] - 0s 79ms/step
# epoch:1970  d_loss:0.3791  g_loss:1.7090
# 1/1 [==============================] - 0s 90ms/step
# epoch:1971  d_loss:0.4541  g_loss:2.1545
# 1/1 [==============================] - 0s 80ms/step
# epoch:1972  d_loss:0.4232  g_loss:1.6076
# 1/1 [==============================] - 0s 95ms/step
# epoch:1973  d_loss:0.5173  g_loss:1.7652
# 1/1 [==============================] - 0s 89ms/step
# epoch:1974  d_loss:0.3805  g_loss:1.4655
# 1/1 [==============================] - 0s 72ms/step
# epoch:1975  d_loss:0.4823  g_loss:1.6442
# 1/1 [==============================] - 0s 63ms/step
# epoch:1976  d_loss:0.4779  g_loss:1.6877
# 1/1 [==============================] - 0s 54ms/step
# epoch:1977  d_loss:0.4539  g_loss:1.3433
# 1/1 [==============================] - 0s 60ms/step
# epoch:1978  d_loss:0.6492  g_loss:1.3008
# 1/1 [==============================] - 0s 56ms/step
# epoch:1979  d_loss:0.4999  g_loss:1.5614
# 1/1 [==============================] - 0s 73ms/step
# epoch:1980  d_loss:0.4309  g_loss:1.8699
# 1/1 [==============================] - 0s 58ms/step
# epoch:1981  d_loss:0.6330  g_loss:1.6778
# 1/1 [==============================] - 0s 63ms/step
# epoch:1982  d_loss:0.4023  g_loss:1.8772
# 1/1 [==============================] - 0s 57ms/step
# epoch:1983  d_loss:0.5891  g_loss:1.7145
# 1/1 [==============================] - 0s 64ms/step
# epoch:1984  d_loss:0.4994  g_loss:1.6096
# 1/1 [==============================] - 0s 58ms/step
# epoch:1985  d_loss:0.5799  g_loss:1.4024
# 1/1 [==============================] - 0s 69ms/step
# epoch:1986  d_loss:0.5410  g_loss:1.2208
# 1/1 [==============================] - 0s 59ms/step
# epoch:1987  d_loss:0.5199  g_loss:1.4807
# 1/1 [==============================] - 0s 55ms/step
# epoch:1988  d_loss:0.6799  g_loss:1.3295
# 1/1 [==============================] - 0s 72ms/step
# epoch:1989  d_loss:0.5139  g_loss:1.3963
# 1/1 [==============================] - 0s 78ms/step
# epoch:1990  d_loss:0.5650  g_loss:1.6142
# 1/1 [==============================] - 0s 69ms/step
# epoch:1991  d_loss:0.5913  g_loss:1.5941
# 1/1 [==============================] - 0s 146ms/step
# epoch:1992  d_loss:0.4801  g_loss:1.3552
# 1/1 [==============================] - 0s 84ms/step
# epoch:1993  d_loss:0.5179  g_loss:1.5349
# 1/1 [==============================] - 0s 75ms/step
# epoch:1994  d_loss:0.4685  g_loss:1.5847
# 1/1 [==============================] - 0s 73ms/step
# epoch:1995  d_loss:0.4925  g_loss:1.3593
# 1/1 [==============================] - 0s 109ms/step
# epoch:1996  d_loss:0.4844  g_loss:1.6953
# 1/1 [==============================] - 0s 66ms/step
# epoch:1997  d_loss:0.4919  g_loss:1.4644
# 1/1 [==============================] - 0s 70ms/step
# epoch:1998  d_loss:0.4254  g_loss:1.6077
# 1/1 [==============================] - 0s 64ms/step
# epoch:1999  d_loss:0.3943  g_loss:1.6921
# 1/1 [==============================] - 0s 108ms/step
# epoch:2000  d_loss:0.3954  g_loss:1.6045
# 1/1 [==============================] - 0s 62ms/step
